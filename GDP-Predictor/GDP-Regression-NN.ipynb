# %% [markdown]
# # GDP Growth Rate Regression
#
# This notebook utilizes a neural network to predict the GDP growth rate based on transportation freight data that is published by the US Department of Transportation Bureau of Transportation Statistics.
#
# An accompanying report for this notebook is available at:<br/>
# https://github.com/schkotty/Data-Science/blob/master/GDP-Predictor/GDP-Regression-NN-Report.pdf

# %% [markdown]
# ## Setup the Environment

# %%
#Import needed libraries
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
from sklearn.metrics import mean_absolute_error
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
from keras import regularizers
from keras import models
from keras import layers
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Get and Prep the Data
#
# I am using transportation data and GDP data that is published by the US government.  This step produces a data set that has transporation inputs and GDP data.

# %%
#Read in the transportation data, monthly seasonally adjusted
tsi_data = pd.read_excel(".\data\Input_SeasonalData_TSI.xlsx", header=2)

#look at the data types that were inferred by Pandas during import.
tsi_data.dtypes
# Out:
# OBS_DATE                   datetime64[ns]
# RAIL_FRT_CARLOADS_D11               int64
# RAIL_FRT_INTERMODAL_D11             int64
# WATERBORNE_D11                    float64
# TRUCK_D11                         float64
# AIR_RTMFM_D11                       int64
# TSI                               float64
# dtype: object

# %%
#Return a listing of the data
tsi_data.head()
# Out:
#     OBS_DATE  RAIL_FRT_CARLOADS_D11  RAIL_FRT_INTERMODAL_D11  WATERBORNE_D11  \
# 0 2000-01-01                1422442                   764756            55.4
# 1 2000-02-01                1425882                   767958            48.6
# 2 2000-03-01                1411458                   763858            52.5
# 3 2000-04-01                1400311                   764144            50.8
# 4 2000-05-01                1405169                   763843            52.5
#
#    TRUCK_D11  AIR_RTMFM_D11    TSI
# 0       80.3        2466950  105.3
# 1       79.8        2521852  104.4
# 2       74.1        2489787   99.2
# 3       72.8        2557332   98.1
# 4       73.0        2527821   98.6

# %%
#Read in the real gdp growth rates,seasonally adjusted, quarterly data with quarterly growth rates
gdp_data = pd.read_excel(".\data\Input_GDP_st_louis_fed_quarterly_change.xlsx")

# The gdp qtr growth rate from the file is in the format of 10% = 10.  We need to format it like
# the data below, with a format of 10% = 0.10.  Divide by 100 so the format will be consistent.
# This calculation should be kept in the same code block as the read from the file to ensure that
# this calculation is idempotent.
gdp_data.Real_gdp_qtr_growth = gdp_data.Real_gdp_qtr_growth/100.0

#look at the data types that were inferred by Pandas during import.
gdp_data.dtypes
# Out:
# observation_date       datetime64[ns]
# Real_gdp_qtr_growth           float64
# dtype: object

# %%
#Disply a listing of the data
gdp_data.head()
# Out:
#   observation_date  Real_gdp_qtr_growth
# 0       2000-01-01                0.015
# 1       2000-04-01                0.075
# 2       2000-07-01                0.005
# 3       2000-10-01                0.025
# 4       2001-01-01               -0.011

# %%
# Create a merged dataset based on the date, bringing together the transportation and GDP data. 
merged_data = pd.merge(tsi_data, gdp_data, how='left', left_on='OBS_DATE', right_on='observation_date')

# We now have 2 date columns with different names. Drop one of the date columns.
merged_data = merged_data.drop(['observation_date'], axis=1) #pandas can drop rows or columns, axis=1 indicates columns

#Forward fill the gdp data so that a quarterly gdp value will be used for 3 rows, with each row being a month.
#limit it only fill in 2 consective missing values.
merged_data['Real_gdp_qtr_growth'] = merged_data['Real_gdp_qtr_growth'].fillna(method='ffill', limit=2)

#drop rows where we don't have a gdp value
merged_data = merged_data.dropna(subset=['Real_gdp_qtr_growth'])

#Create a boolean column to indicate if gdp growth was positive or negative.
#merged_data['gdp_is_increasing'] = merged_data.apply(lambda x: True if x['Real_gdp_qtr_growth'] > 0.0 else False, axis=1)
merged_data['gdp_is_increasing'] = merged_data.apply(lambda x: 1 if x['Real_gdp_qtr_growth'] > 0.0 else 0, axis=1)

# Add columns for the freight data to calculate the percent change from the previous month.
# This will leave them in a format such as 10% = 0.10.
merged_data['RAIL_FRT_PCT'] = merged_data['RAIL_FRT_CARLOADS_D11'].pct_change()
merged_data['RAIL_INTERMOD_PCT'] = merged_data['RAIL_FRT_INTERMODAL_D11'].pct_change()
merged_data['WATERBORNE_PCT'] = merged_data['WATERBORNE_D11'].pct_change()
merged_data['TRUCK_PCT'] = merged_data['TRUCK_D11'].pct_change()
merged_data['AIR_RTMFM_PCT'] = merged_data['AIR_RTMFM_D11'].pct_change()
merged_data['TSI_PCT'] = merged_data['TSI'].pct_change()

# %% [markdown]
# ## Create the Training, Validation, and Test Data Sets

# %%
# Setup the split of the data.

validation_data_split = 0.2 # this is the percentage of the training set for validation
# the remainder of the data will be in the training data set.
test_data_split = 230  # this will be the number of weeks in the test data set

#Calculate the split date to use
max_obs_date = merged_data['OBS_DATE'].max()
print('Max Obs Date: {0}'.format(max_obs_date))
split_date = max_obs_date - timedelta(weeks=test_data_split) 
print('Test Split Date: {0}'.format(split_date))
print('Validation Split: {0:0.2f}'.format(validation_data_split))
# Out:
# Max Obs Date: 2019-12-01 00:00:00
# Test Split Date: 2015-07-05 00:00:00
# Validation Split: 0.20

# %%
# Create training, validation, and test dataframes
x_train = merged_data.loc[merged_data['OBS_DATE'] < split_date, 'RAIL_FRT_PCT':'TSI_PCT']
x_train = x_train.drop([0]) #drop first row as it will have NA for pct_change values

total_row_count = len(x_train)
val_row_count = round(total_row_count*validation_data_split) 
train_row_count = total_row_count - val_row_count

x_val = x_train.iloc[train_row_count:]
x_train = x_train.iloc[:train_row_count]
print('x_train row count: {0}'.format(len(x_train.index)))
print('x_val row count: {0}'.format(len(x_val.index)))

y_train_class = merged_data.iloc[1:train_row_count+1]['gdp_is_increasing'] #ignore first row as it wont have pct_change values
y_val_class = merged_data.iloc[train_row_count+1:total_row_count+1]['gdp_is_increasing']
print('y_train_class row count: {0}'.format(len(y_train_class.index)))
print('y_val_class row count: {0}'.format(len(y_val_class.index)))

y_train_rate = merged_data.iloc[1:train_row_count+1]['Real_gdp_qtr_growth'] #ignore first row as it wont have pct_change values
y_val_rate = merged_data.iloc[train_row_count+1:total_row_count+1]['Real_gdp_qtr_growth']

print('y_train_rate row count: {0}'.format(len(y_train_rate.index)))
print('y_val_rate row count: {0}'.format(len(y_val_rate.index)))

# Test sets
x_test = merged_data.loc[merged_data['OBS_DATE'] >= split_date, 'RAIL_FRT_PCT':'TSI_PCT']
y_test_class = merged_data.loc[merged_data['OBS_DATE'] >= split_date, 'gdp_is_increasing']
y_test_rate = merged_data.loc[merged_data['OBS_DATE'] >= split_date, 'Real_gdp_qtr_growth']

print('x_test row count: {0}'.format(len(x_test.index)))
print('y_test_class row count: {0}'.format(len(y_test_class.index)))
print('y_test_rate row count: {0}'.format(len(y_test_rate.index)))
# Out:
# x_train row count: 149
# x_val row count: 37
# y_train_class row count: 149
# y_val_class row count: 37
# y_train_rate row count: 149
# y_val_rate row count: 37
# x_test row count: 53
# y_test_class row count: 53
# y_test_rate row count: 53

# %% [markdown]
# ## Check Out the Data

# %%
x_train.describe()
# Out:
#        RAIL_FRT_PCT  RAIL_INTERMOD_PCT  WATERBORNE_PCT   TRUCK_PCT  \
# count    149.000000         149.000000      149.000000  149.000000
# mean      -0.000753           0.002298        0.000192    0.000864
# std        0.019283           0.020187        0.055002    0.016473
# min       -0.064277          -0.089458       -0.148492   -0.071429
# 25%       -0.010147          -0.006948       -0.032381   -0.008197
# 50%       -0.000677           0.004158        0.002273    0.000000
# 75%        0.009911           0.012970        0.023196    0.011299
# max        0.049698           0.098418        0.158960    0.040047
#
#        AIR_RTMFM_PCT     TSI_PCT
# count     149.000000  149.000000
# mean        0.002237    0.000605
# std         0.038921    0.013436
# min        -0.116712   -0.050495
# 25%        -0.014782   -0.007951
# 50%        -0.001036    0.001791
# 75%         0.018707    0.008937
# max         0.276234    0.031022

# %%
# Plot some of the data.  You can add in different columns from the dataset by uncommenting.
#plt.plot(merged_data['OBS_DATE'], merged_data['RAIL_FRT_PCT']*100.0, label='Rail Frt')
plt.plot(merged_data['OBS_DATE'], merged_data['Real_gdp_qtr_growth']*100.0, label='GDP')
#plt.plot(merged_data['OBS_DATE'], merged_data['RAIL_INTERMOD_PCT']*100.0, label='Rail Intermod')
#plt.plot(merged_data['OBS_DATE'], merged_data['WATERBORNE_PCT']*100.0, label='Water')
#plt.plot(merged_data['OBS_DATE'], merged_data['TRUCK_PCT']*100.0, label='Truck')
#plt.plot(merged_data['OBS_DATE'], merged_data['AIR_RTMFM_PCT']*100.0, label='Air and Mail Frt')
plt.plot(merged_data['OBS_DATE'], merged_data['TSI_PCT']*100.0, label='TSI')
plt.title('GDP and TSI Growth Rates')
plt.ylabel('Growth Rate (%)')
plt.xlabel('Time Period')
plt.legend()
plt.axhline(-4, 0, 250, c='lightgrey')
plt.axhline(-2, 0, 250, c='lightgrey')
plt.axhline(0, 0, 250, c='lightgrey')
plt.axhline(2, 0, 250, c='lightgrey')
plt.axhline(4, 0, 250, c='lightgrey')
fig = plt.gcf()
fig.set_size_inches(16,10)

# %%
# Examine the GDP growth rate over all of our data. Color code the values that are in the
# training, validation, and test data sets.

plt.plot(merged_data.iloc[:train_row_count]['OBS_DATE'], 
         merged_data.iloc[:train_row_count]['Real_gdp_qtr_growth']*100.0, Label="Train")
plt.plot(merged_data.iloc[train_row_count:train_row_count + val_row_count]['OBS_DATE'], 
         merged_data.iloc[train_row_count:train_row_count + val_row_count]['Real_gdp_qtr_growth']*100.0, Label="Validation")
plt.plot(merged_data.iloc[train_row_count + val_row_count:]['OBS_DATE'], 
        merged_data.iloc[train_row_count + val_row_count:]['Real_gdp_qtr_growth']*100.0, Label="Test")
plt.title('GDP Growth Rates Across Datasets')
plt.ylabel('Growth Rate (%)')
plt.xlabel('Time Period')
#plt.xticks(np.arange(2000, 2020,step=2))
plt.legend()
plt.axhline(-4, 0, 250, c='lightgrey')
plt.axhline(-2, 0, 250, c='lightgrey')
plt.axhline(0, 0, 250, c='lightgrey')
plt.axhline(2, 0, 250, c='lightgrey')
plt.axhline(4, 0, 250, c='lightgrey')
fig = plt.gcf()
fig.set_size_inches(16,10)
#merged_data

# %% [markdown]
# We can see in the chart above that the GDP growth rate varies a lot more in the training data set then it does in the validation set.  And, the validation set has more variance then the test set.
#
# Below, we calculate the standard deviation for the output values for each data set.

# %%
y_train_std = merged_data.iloc[:train_row_count]['Real_gdp_qtr_growth'].std(axis=0)
print('y_train_std: {0:0.3f}'.format(y_train_std))

y_val_std = merged_data.iloc[train_row_count:train_row_count + val_row_count]['Real_gdp_qtr_growth'].std(axis=0)
print('y_val_std: {0:0.3f}'.format(y_val_std))

y_test_std = merged_data.iloc[train_row_count + val_row_count:]['Real_gdp_qtr_growth'].std(axis=0)
print('y_test_std: {0:0.3f}'.format(y_test_std))
# Out:
# y_train_std: 0.027
# y_val_std: 0.019
# y_test_std: 0.008

# %% [markdown]
# ## Normalize the Data

# %%
#Calculate the mean and standard deviation of the training data set.
mean = x_train.mean(axis=0)
std = x_train.std(axis=0)

#Normalize the training data set to have a mean of 0 and standard deviation of 1.
x_train_std = x_train - mean
x_train_std = x_train_std / std

#Normalize the validation data set to have a mean of 0 and standard deviation of 1.
x_val_std = x_val - mean
x_val_std = x_val_std / std

#Normalize the test data set to have a mean of 0 and standard deviation of 1.
x_test_std = x_test - mean
x_test_std = x_test_std / std

# %%
#Examine the stats on the normalized training set
x_train_std.describe()
# Out:
#        RAIL_FRT_PCT  RAIL_INTERMOD_PCT  WATERBORNE_PCT     TRUCK_PCT  \
# count  1.490000e+02       1.490000e+02    1.490000e+02  1.490000e+02
# mean  -1.490232e-18      -2.384372e-17    1.266697e-17  1.490232e-18
# std    1.000000e+00       1.000000e+00    1.000000e+00  1.000000e+00
# min   -3.294367e+00      -4.545280e+00   -2.703246e+00 -4.388498e+00
# 25%   -4.872035e-01      -4.580180e-01   -5.922187e-01 -5.500188e-01
# 50%    3.917056e-03       9.213551e-02    3.782409e-02 -5.243816e-02
# 75%    5.530022e-01       5.286379e-01    4.182304e-01  6.334922e-01
# max    2.616357e+00       4.761394e+00    2.886566e+00  2.378615e+00
#
#        AIR_RTMFM_PCT       TSI_PCT
# count   1.490000e+02  1.490000e+02
# mean    3.818720e-17  4.470697e-18
# std     1.000000e+00  1.000000e+00
# min    -3.056159e+00 -3.803338e+00
# 25%    -4.372516e-01 -6.368092e-01
# 50%    -8.407633e-02  8.820267e-02
# 75%     4.231870e-01  6.200724e-01
# max     7.039878e+00  2.263854e+00

# %% [markdown]
# ## Setup a Neural Network Model Using Keras

# %%
# We will use this to run the model multiple times with varying input parameters.
# The neural network has the following structure:

# Dense layer -> Batch Normalization Layer -> 
# Dense Layer -> Batch Normalization Layer -> 
# Dense Layer with linear activation

# This function has input parameters for different regularization factors (penalty),
# regularization types (L1 and L2 supported), and number of dense layers.

def get_nn_model(penalty, reg_type, dense_layers, stdinput, learning_rate, 
                 x_train, x_train_std, y_train, x_val, x_val_std, y_val, verbose):
        
    if stdinput:
        xinput = x_train_std
        xval = x_val_std
    else:
        xinput = x_train
        xval = x_val
    
    nn_model = models.Sequential()
    
    if reg_type == "L2":
        nn_model.add(layers.Dense(dense_layers, activation='relu', input_shape=(xinput.shape[1],), kernel_regularizer=regularizers.l2(penalty)))
    else:
        nn_model.add(layers.Dense(dense_layers, activation='relu', input_shape=(xinput.shape[1],), kernel_regularizer=regularizers.l1(penalty)))
        
    #nn_model.add(layers.BatchNormalization())

    if reg_type == "L2":
        nn_model.add(layers.Dense(dense_layers, activation='relu', kernel_regularizer=regularizers.l2(penalty)))
    else:
        nn_model.add(layers.Dense(dense_layers, activation='relu', kernel_regularizer=regularizers.l1(penalty)))

    #nn_model.add(layers.BatchNormalization())
    nn_model.add(layers.Dense(1, activation='linear'))
    
    nn_model.compile(optimizer='Adam', loss='mse', metrics=['mae'])
    nn_model.optimizer.lr = learning_rate
    
    run_history = nn_model.fit(x=xinput, y=y_train.to_numpy(), epochs=215, validation_data=(xval, y_val), verbose=verbose)
    
    # Make training predictions so that we can calculate the standard deviation. This is so we can monitor if the
    # neural network is outputing a constant value, which can happen if the regularization penalty is too high.
    predictions_training = nn_model.predict(xinput)
    training_std = (predictions_training.std(axis=0)[0])*100.0
    
    return (nn_model, run_history, training_std)

# %%
# This facilitates running the model on a subset of the input data columns.  Can set all datasets here.
columnset = ['WATERBORNE_PCT', 'RAIL_FRT_PCT', 'RAIL_INTERMOD_PCT', 'TRUCK_PCT', 'AIR_RTMFM_PCT', 'TSI_PCT']
x_train_input = x_train[columnset]
x_train_std_input = x_train_std[columnset]
x_val_input = x_val[columnset]
x_val_std_input = x_val_std[columnset]
x_test_input = x_test[columnset]
x_test_std_input = x_test_std[columnset]

# %%
# Inital run / single run of the model.

(trained_model, run_history, training_std) = get_nn_model(penalty=0.00001, reg_type='L2', dense_layers=32, stdinput=False, 
                                            learning_rate = 0.001, x_train=x_train_input, x_train_std=x_train_std_input, 
                                            y_train=y_train_rate, x_val=x_val_input, x_val_std=x_val_std_input, 
                                            y_val=y_val_rate, verbose=1)
# Out:
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 149 samples, validate on 37 samples
# Epoch 1/215
# 149/149 [==============================] - 0s 2ms/step - loss: 0.0015 - mean_absolute_error: 0.0253 - val_loss: 8.5904e-04 - val_mean_absolute_error: 0.0175
# Epoch 2/215
# 149/149 [==============================] - 0s 40us/step - loss: 0.0013 - mean_absolute_error: 0.0208 - val_loss: 8.3380e-04 - val_mean_absolute_error: 0.0172
# Epoch 3/215
# 149/149 [==============================] - 0s 40us/step - loss: 0.0012 - mean_absolute_error: 0.0204 - val_loss: 8.7192e-04 - val_mean_absolute_error: 0.0186
# Epoch 4/215
# 149/149 [==============================] - 0s 60us/step - loss: 0.0012 - mean_absolute_error: 0.0202 - val_loss: 8.4183e-04 - val_mean_absolute_error: 0.0181
# Epoch 5/215
# 149/149 [==============================] - 0s 47us/step - loss: 0.0011 - mean_absolute_error: 0.0190 - val_loss: 7.8118e-04 - val_mean_absolute_error: 0.0170
# Epoch 6/215
# 149/149 [==============================] - 0s 47us/step - loss: 0.0011 - mean_absolute_error: 0.0182 - val_loss: 7.7128e-04 - val_mean_absolute_error: 0.0169
# Epoch 7/215
# 149/149 [==============================] - 0s 47us/step - loss: 0.0010 - mean_absolute_error: 0.0181 - val_loss: 7.9653e-04 - val_mean_absolute_error: 0.0176
# Epoch 8/215
# 149/149 [==============================] - 0s 60us/step - loss: 0.0010 - mean_absolute_error: 0.0185 - val_loss: 7.8326e-04 - val_mean_absolute_error: 0.0174
# Epoch 9/215
# 149/149 [==============================] - 0s 40us/step - loss: 9.9482e-04 - mean_absolute_error: 0.0178 - val_loss: 7.5353e-04 - val_mean_absolute_error: 0.0170
# Epoch 10/215
# 149/149 [==============================] - 0s 54us/step - loss: 9.8774e-04 - mean_absolute_error: 0.0176 - val_loss: 7.6157e-04 - val_mean_absolute_error: 0.0173
# Epoch 11/215
# 149/149 [==============================] - 0s 40us/step - loss: 9.5656e-04 - mean_absolute_error: 0.0175 - val_loss: 7.8478e-04 - val_mean_absolute_error: 0.0179
# Epoch 12/215
# 149/149 [==============================] - 0s 54us/step - loss: 9.4789e-04 - mean_absolute_error: 0.0177 - val_loss: 7.6925e-04 - val_mean_absolute_error: 0.0177
# Epoch 13/215
# 149/149 [==============================] - 0s 47us/step - loss: 9.2818e-04 - mean_absolute_error: 0.0176 - val_loss: 7.6757e-04 - val_mean_absolute_error: 0.0178
# Epoch 14/215
# 149/149 [==============================] - 0s 47us/step - loss: 9.1268e-04 - mean_absolute_error: 0.0174 - val_loss: 7.4986e-04 - val_mean_absolute_error: 0.0175
# Epoch 15/215
# 149/149 [==============================] - 0s 54us/step - loss: 8.9820e-04 - mean_absolute_error: 0.0172 - val_loss: 7.5154e-04 - val_mean_absolute_error: 0.0177
# Epoch 16/215
# 149/149 [==============================] - 0s 47us/step - loss: 8.9213e-04 - mean_absolute_error: 0.0173 - val_loss: 7.6400e-04 - val_mean_absolute_error: 0.0181
# Epoch 17/215
# 149/149 [==============================] - 0s 54us/step - loss: 8.7547e-04 - mean_absolute_error: 0.0170 - val_loss: 7.3139e-04 - val_mean_absolute_error: 0.0174
# Epoch 18/215
# 149/149 [==============================] - 0s 40us/step - loss: 8.6614e-04 - mean_absolute_error: 0.0169 - val_loss: 7.5886e-04 - val_mean_absolute_error: 0.0182
# Epoch 19/215
# 149/149 [==============================] - 0s 67us/step - loss: 8.6209e-04 - mean_absolute_error: 0.0170 - val_loss: 7.3436e-04 - val_mean_absolute_error: 0.0178
# Epoch 20/215
# 149/149 [==============================] - 0s 40us/step - loss: 8.3636e-04 - mean_absolute_error: 0.0166 - val_loss: 7.4895e-04 - val_mean_absolute_error: 0.0182
# Epoch 21/215
# 149/149 [==============================] - 0s 60us/step - loss: 8.3052e-04 - mean_absolute_error: 0.0169 - val_loss: 7.4669e-04 - val_mean_absolute_error: 0.0182
# Epoch 22/215
# 149/149 [==============================] - 0s 34us/step - loss: 8.1754e-04 - mean_absolute_error: 0.0166 - val_loss: 7.1600e-04 - val_mean_absolute_error: 0.0176
# Epoch 23/215
# 149/149 [==============================] - 0s 60us/step - loss: 8.1702e-04 - mean_absolute_error: 0.0167 - val_loss: 7.1087e-04 - val_mean_absolute_error: 0.0176
# Epoch 24/215
# 149/149 [==============================] - 0s 47us/step - loss: 8.0585e-04 - mean_absolute_error: 0.0165 - val_loss: 7.1367e-04 - val_mean_absolute_error: 0.0178
# Epoch 25/215
# 149/149 [==============================] - 0s 60us/step - loss: 7.9377e-04 - mean_absolute_error: 0.0165 - val_loss: 7.0396e-04 - val_mean_absolute_error: 0.0176
# Epoch 26/215
# 149/149 [==============================] - 0s 40us/step - loss: 7.8969e-04 - mean_absolute_error: 0.0164 - val_loss: 6.9935e-04 - val_mean_absolute_error: 0.0176
# Epoch 27/215
# 149/149 [==============================] - 0s 40us/step - loss: 7.8744e-04 - mean_absolute_error: 0.0165 - val_loss: 7.3030e-04 - val_mean_absolute_error: 0.0182
# Epoch 28/215
# 149/149 [==============================] - 0s 60us/step - loss: 7.8092e-04 - mean_absolute_error: 0.0166 - val_loss: 6.7777e-04 - val_mean_absolute_error: 0.0171
# Epoch 29/215
# 149/149 [==============================] - 0s 40us/step - loss: 7.6985e-04 - mean_absolute_error: 0.0164 - val_loss: 6.8169e-04 - val_mean_absolute_error: 0.0174
# Epoch 30/215
# 149/149 [==============================] - 0s 60us/step - loss: 7.5812e-04 - mean_absolute_error: 0.0162 - val_loss: 6.8936e-04 - val_mean_absolute_error: 0.0177
# Epoch 31/215
# 149/149 [==============================] - 0s 47us/step - loss: 7.6026e-04 - mean_absolute_error: 0.0163 - val_loss: 6.7984e-04 - val_mean_absolute_error: 0.0176
# Epoch 32/215
# 149/149 [==============================] - 0s 54us/step - loss: 7.5251e-04 - mean_absolute_error: 0.0161 - val_loss: 6.6542e-04 - val_mean_absolute_error: 0.0172
# Epoch 33/215
# 149/149 [==============================] - 0s 47us/step - loss: 7.4839e-04 - mean_absolute_error: 0.0162 - val_loss: 6.6572e-04 - val_mean_absolute_error: 0.0173
# Epoch 34/215
# 149/149 [==============================] - 0s 47us/step - loss: 7.3337e-04 - mean_absolute_error: 0.0160 - val_loss: 7.0259e-04 - val_mean_absolute_error: 0.0182
# Epoch 35/215
# 149/149 [==============================] - 0s 54us/step - loss: 7.3695e-04 - mean_absolute_error: 0.0163 - val_loss: 6.6177e-04 - val_mean_absolute_error: 0.0174
# Epoch 36/215
# 149/149 [==============================] - 0s 47us/step - loss: 7.2782e-04 - mean_absolute_error: 0.0159 - val_loss: 6.3533e-04 - val_mean_absolute_error: 0.0167
# Epoch 37/215
# 149/149 [==============================] - 0s 54us/step - loss: 7.2645e-04 - mean_absolute_error: 0.0160 - val_loss: 6.7024e-04 - val_mean_absolute_error: 0.0177
# Epoch 38/215
# 149/149 [==============================] - 0s 54us/step - loss: 7.1847e-04 - mean_absolute_error: 0.0160 - val_loss: 6.5141e-04 - val_mean_absolute_error: 0.0173
# Epoch 39/215
# 149/149 [==============================] - 0s 47us/step - loss: 7.1259e-04 - mean_absolute_error: 0.0159 - val_loss: 6.5534e-04 - val_mean_absolute_error: 0.0174
# Epoch 40/215
# 149/149 [==============================] - 0s 54us/step - loss: 7.1482e-04 - mean_absolute_error: 0.0159 - val_loss: 6.3489e-04 - val_mean_absolute_error: 0.0170
# Epoch 41/215
# 149/149 [==============================] - 0s 47us/step - loss: 7.0534e-04 - mean_absolute_error: 0.0159 - val_loss: 6.7217e-04 - val_mean_absolute_error: 0.0180
# Epoch 42/215
# 149/149 [==============================] - 0s 40us/step - loss: 7.0834e-04 - mean_absolute_error: 0.0160 - val_loss: 6.2723e-04 - val_mean_absolute_error: 0.0170
# Epoch 43/215
# 149/149 [==============================] - 0s 34us/step - loss: 6.9742e-04 - mean_absolute_error: 0.0158 - val_loss: 6.4085e-04 - val_mean_absolute_error: 0.0173
# Epoch 44/215
# 149/149 [==============================] - 0s 67us/step - loss: 6.9807e-04 - mean_absolute_error: 0.0160 - val_loss: 6.4225e-04 - val_mean_absolute_error: 0.0173
# Epoch 45/215
# 149/149 [==============================] - 0s 40us/step - loss: 6.8943e-04 - mean_absolute_error: 0.0158 - val_loss: 6.1470e-04 - val_mean_absolute_error: 0.0167
# Epoch 46/215
# 149/149 [==============================] - 0s 54us/step - loss: 7.0184e-04 - mean_absolute_error: 0.0161 - val_loss: 6.3648e-04 - val_mean_absolute_error: 0.0175
# Epoch 47/215
# 149/149 [==============================] - 0s 40us/step - loss: 6.8476e-04 - mean_absolute_error: 0.0158 - val_loss: 6.0655e-04 - val_mean_absolute_error: 0.0168
# Epoch 48/215
# 149/149 [==============================] - 0s 54us/step - loss: 6.8138e-04 - mean_absolute_error: 0.0158 - val_loss: 6.2906e-04 - val_mean_absolute_error: 0.0174
# Epoch 49/215
# 149/149 [==============================] - 0s 54us/step - loss: 6.7623e-04 - mean_absolute_error: 0.0158 - val_loss: 6.2069e-04 - val_mean_absolute_error: 0.0171
# Epoch 50/215
# 149/149 [==============================] - 0s 54us/step - loss: 6.7082e-04 - mean_absolute_error: 0.0157 - val_loss: 6.1439e-04 - val_mean_absolute_error: 0.0170
# Epoch 51/215
# 149/149 [==============================] - 0s 40us/step - loss: 6.7170e-04 - mean_absolute_error: 0.0158 - val_loss: 6.2161e-04 - val_mean_absolute_error: 0.0172
# Epoch 52/215
# 149/149 [==============================] - 0s 54us/step - loss: 6.6565e-04 - mean_absolute_error: 0.0157 - val_loss: 6.0105e-04 - val_mean_absolute_error: 0.0167
# Epoch 53/215
# 149/149 [==============================] - 0s 40us/step - loss: 6.6895e-04 - mean_absolute_error: 0.0158 - val_loss: 6.1936e-04 - val_mean_absolute_error: 0.0172
# Epoch 54/215
# 149/149 [==============================] - 0s 47us/step - loss: 6.6299e-04 - mean_absolute_error: 0.0157 - val_loss: 6.0532e-04 - val_mean_absolute_error: 0.0169
# Epoch 55/215
# 149/149 [==============================] - 0s 40us/step - loss: 6.5511e-04 - mean_absolute_error: 0.0156 - val_loss: 6.2947e-04 - val_mean_absolute_error: 0.0177
# Epoch 56/215
# 149/149 [==============================] - 0s 54us/step - loss: 6.5514e-04 - mean_absolute_error: 0.0157 - val_loss: 6.0377e-04 - val_mean_absolute_error: 0.0170
# Epoch 57/215
# 149/149 [==============================] - 0s 54us/step - loss: 6.5556e-04 - mean_absolute_error: 0.0157 - val_loss: 6.0294e-04 - val_mean_absolute_error: 0.0169
# Epoch 58/215
# 149/149 [==============================] - 0s 60us/step - loss: 6.5463e-04 - mean_absolute_error: 0.0159 - val_loss: 6.2476e-04 - val_mean_absolute_error: 0.0176
# Epoch 59/215
# 149/149 [==============================] - 0s 54us/step - loss: 6.4624e-04 - mean_absolute_error: 0.0156 - val_loss: 5.9223e-04 - val_mean_absolute_error: 0.0168
# Epoch 60/215
# 149/149 [==============================] - 0s 47us/step - loss: 6.5040e-04 - mean_absolute_error: 0.0156 - val_loss: 6.0107e-04 - val_mean_absolute_error: 0.0172
# Epoch 61/215
# 149/149 [==============================] - 0s 60us/step - loss: 6.4342e-04 - mean_absolute_error: 0.0156 - val_loss: 5.9628e-04 - val_mean_absolute_error: 0.0169
# Epoch 62/215
# 149/149 [==============================] - 0s 47us/step - loss: 6.3894e-04 - mean_absolute_error: 0.0156 - val_loss: 6.2334e-04 - val_mean_absolute_error: 0.0176
# Epoch 63/215
# 149/149 [==============================] - 0s 54us/step - loss: 6.4005e-04 - mean_absolute_error: 0.0157 - val_loss: 5.9754e-04 - val_mean_absolute_error: 0.0171
# Epoch 64/215
# 149/149 [==============================] - 0s 40us/step - loss: 6.3077e-04 - mean_absolute_error: 0.0155 - val_loss: 5.7473e-04 - val_mean_absolute_error: 0.0164
# Epoch 65/215
# 149/149 [==============================] - 0s 47us/step - loss: 6.3709e-04 - mean_absolute_error: 0.0156 - val_loss: 5.8701e-04 - val_mean_absolute_error: 0.0170
# Epoch 66/215
# 149/149 [==============================] - 0s 47us/step - loss: 6.3160e-04 - mean_absolute_error: 0.0156 - val_loss: 5.8073e-04 - val_mean_absolute_error: 0.0169
# Epoch 67/215
# 149/149 [==============================] - 0s 47us/step - loss: 6.3247e-04 - mean_absolute_error: 0.0155 - val_loss: 5.7178e-04 - val_mean_absolute_error: 0.0166
# Epoch 68/215
# 149/149 [==============================] - 0s 47us/step - loss: 6.3458e-04 - mean_absolute_error: 0.0156 - val_loss: 6.1606e-04 - val_mean_absolute_error: 0.0178
# Epoch 69/215
# 149/149 [==============================] - 0s 47us/step - loss: 6.2551e-04 - mean_absolute_error: 0.0155 - val_loss: 5.7483e-04 - val_mean_absolute_error: 0.0164
# Epoch 70/215
# 149/149 [==============================] - 0s 40us/step - loss: 6.3197e-04 - mean_absolute_error: 0.0157 - val_loss: 5.9564e-04 - val_mean_absolute_error: 0.0172
# Epoch 71/215
# 149/149 [==============================] - 0s 54us/step - loss: 6.2016e-04 - mean_absolute_error: 0.0155 - val_loss: 5.8258e-04 - val_mean_absolute_error: 0.0169
# Epoch 72/215
# 149/149 [==============================] - 0s 54us/step - loss: 6.2082e-04 - mean_absolute_error: 0.0155 - val_loss: 5.6611e-04 - val_mean_absolute_error: 0.0165
# Epoch 73/215
# 149/149 [==============================] - 0s 47us/step - loss: 6.2103e-04 - mean_absolute_error: 0.0157 - val_loss: 5.9365e-04 - val_mean_absolute_error: 0.0174
# Epoch 74/215
# 149/149 [==============================] - 0s 54us/step - loss: 6.2003e-04 - mean_absolute_error: 0.0154 - val_loss: 5.6827e-04 - val_mean_absolute_error: 0.0166
# Epoch 75/215
# 149/149 [==============================] - 0s 40us/step - loss: 6.1614e-04 - mean_absolute_error: 0.0154 - val_loss: 5.8643e-04 - val_mean_absolute_error: 0.0172
# Epoch 76/215
# 149/149 [==============================] - 0s 47us/step - loss: 6.3707e-04 - mean_absolute_error: 0.0161 - val_loss: 6.1132e-04 - val_mean_absolute_error: 0.0178
# Epoch 77/215
# 149/149 [==============================] - 0s 40us/step - loss: 6.0811e-04 - mean_absolute_error: 0.0154 - val_loss: 5.5664e-04 - val_mean_absolute_error: 0.0160
# Epoch 78/215
# 149/149 [==============================] - 0s 47us/step - loss: 6.2675e-04 - mean_absolute_error: 0.0155 - val_loss: 5.7759e-04 - val_mean_absolute_error: 0.0170
# Epoch 79/215
# 149/149 [==============================] - 0s 47us/step - loss: 6.1538e-04 - mean_absolute_error: 0.0156 - val_loss: 5.8850e-04 - val_mean_absolute_error: 0.0174
# Epoch 80/215
# 149/149 [==============================] - 0s 47us/step - loss: 6.0307e-04 - mean_absolute_error: 0.0153 - val_loss: 5.5428e-04 - val_mean_absolute_error: 0.0163
# Epoch 81/215
# 149/149 [==============================] - 0s 54us/step - loss: 6.1018e-04 - mean_absolute_error: 0.0154 - val_loss: 5.7783e-04 - val_mean_absolute_error: 0.0171
# Epoch 82/215
# 149/149 [==============================] - 0s 47us/step - loss: 6.0289e-04 - mean_absolute_error: 0.0154 - val_loss: 5.7063e-04 - val_mean_absolute_error: 0.0169
# Epoch 83/215
# 149/149 [==============================] - 0s 47us/step - loss: 6.0513e-04 - mean_absolute_error: 0.0154 - val_loss: 5.8016e-04 - val_mean_absolute_error: 0.0172
# Epoch 84/215
# 149/149 [==============================] - 0s 54us/step - loss: 6.0072e-04 - mean_absolute_error: 0.0154 - val_loss: 5.6337e-04 - val_mean_absolute_error: 0.0166
# Epoch 85/215
# 149/149 [==============================] - 0s 54us/step - loss: 5.9948e-04 - mean_absolute_error: 0.0153 - val_loss: 5.5832e-04 - val_mean_absolute_error: 0.0164
# Epoch 86/215
# 149/149 [==============================] - 0s 40us/step - loss: 5.9652e-04 - mean_absolute_error: 0.0154 - val_loss: 5.8396e-04 - val_mean_absolute_error: 0.0173
# Epoch 87/215
# 149/149 [==============================] - 0s 54us/step - loss: 5.9960e-04 - mean_absolute_error: 0.0155 - val_loss: 5.6015e-04 - val_mean_absolute_error: 0.0167
# Epoch 88/215
# 149/149 [==============================] - 0s 47us/step - loss: 6.0279e-04 - mean_absolute_error: 0.0154 - val_loss: 5.5854e-04 - val_mean_absolute_error: 0.0166
# Epoch 89/215
# 149/149 [==============================] - 0s 47us/step - loss: 5.9003e-04 - mean_absolute_error: 0.0153 - val_loss: 5.8970e-04 - val_mean_absolute_error: 0.0175
# Epoch 90/215
# 149/149 [==============================] - 0s 54us/step - loss: 5.9723e-04 - mean_absolute_error: 0.0156 - val_loss: 5.5212e-04 - val_mean_absolute_error: 0.0164
# Epoch 91/215
# 149/149 [==============================] - 0s 47us/step - loss: 5.9566e-04 - mean_absolute_error: 0.0153 - val_loss: 5.5136e-04 - val_mean_absolute_error: 0.0166
# Epoch 92/215
# 149/149 [==============================] - 0s 54us/step - loss: 6.0554e-04 - mean_absolute_error: 0.0157 - val_loss: 5.8215e-04 - val_mean_absolute_error: 0.0175
# Epoch 93/215
# 149/149 [==============================] - 0s 47us/step - loss: 6.0153e-04 - mean_absolute_error: 0.0153 - val_loss: 5.4073e-04 - val_mean_absolute_error: 0.0160
# Epoch 94/215
# 149/149 [==============================] - 0s 40us/step - loss: 5.8070e-04 - mean_absolute_error: 0.0151 - val_loss: 6.0031e-04 - val_mean_absolute_error: 0.0178
# Epoch 95/215
# 149/149 [==============================] - 0s 47us/step - loss: 6.1464e-04 - mean_absolute_error: 0.0161 - val_loss: 5.8848e-04 - val_mean_absolute_error: 0.0176
# Epoch 96/215
# 149/149 [==============================] - 0s 40us/step - loss: 6.0332e-04 - mean_absolute_error: 0.0156 - val_loss: 5.3618e-04 - val_mean_absolute_error: 0.0159
# Epoch 97/215
# 149/149 [==============================] - 0s 47us/step - loss: 5.8615e-04 - mean_absolute_error: 0.0154 - val_loss: 6.0253e-04 - val_mean_absolute_error: 0.0179
# Epoch 98/215
# 149/149 [==============================] - 0s 40us/step - loss: 6.0139e-04 - mean_absolute_error: 0.0159 - val_loss: 5.5442e-04 - val_mean_absolute_error: 0.0167
# Epoch 99/215
# 149/149 [==============================] - 0s 54us/step - loss: 6.1385e-04 - mean_absolute_error: 0.0158 - val_loss: 5.3819e-04 - val_mean_absolute_error: 0.0162
# Epoch 100/215
# 149/149 [==============================] - 0s 40us/step - loss: 6.0801e-04 - mean_absolute_error: 0.0159 - val_loss: 6.0488e-04 - val_mean_absolute_error: 0.0180
# Epoch 101/215
# 149/149 [==============================] - 0s 54us/step - loss: 6.0197e-04 - mean_absolute_error: 0.0155 - val_loss: 5.3678e-04 - val_mean_absolute_error: 0.0160
# Epoch 102/215
# 149/149 [==============================] - 0s 47us/step - loss: 5.8304e-04 - mean_absolute_error: 0.0154 - val_loss: 5.7644e-04 - val_mean_absolute_error: 0.0175
# Epoch 103/215
# 149/149 [==============================] - 0s 54us/step - loss: 5.7867e-04 - mean_absolute_error: 0.0154 - val_loss: 5.4765e-04 - val_mean_absolute_error: 0.0167
# Epoch 104/215
# 149/149 [==============================] - 0s 47us/step - loss: 5.7454e-04 - mean_absolute_error: 0.0153 - val_loss: 5.4222e-04 - val_mean_absolute_error: 0.0164
# Epoch 105/215
# 149/149 [==============================] - 0s 54us/step - loss: 5.7349e-04 - mean_absolute_error: 0.0153 - val_loss: 5.7355e-04 - val_mean_absolute_error: 0.0173
# Epoch 106/215
# 149/149 [==============================] - 0s 47us/step - loss: 5.7619e-04 - mean_absolute_error: 0.0154 - val_loss: 5.6464e-04 - val_mean_absolute_error: 0.0170
# Epoch 107/215
# 149/149 [==============================] - 0s 40us/step - loss: 5.7183e-04 - mean_absolute_error: 0.0152 - val_loss: 5.4618e-04 - val_mean_absolute_error: 0.0166
# Epoch 108/215
# 149/149 [==============================] - 0s 47us/step - loss: 5.7905e-04 - mean_absolute_error: 0.0153 - val_loss: 5.5312e-04 - val_mean_absolute_error: 0.0168
# Epoch 109/215
# 149/149 [==============================] - 0s 40us/step - loss: 5.7381e-04 - mean_absolute_error: 0.0154 - val_loss: 5.5545e-04 - val_mean_absolute_error: 0.0170
# Epoch 110/215
# 149/149 [==============================] - 0s 47us/step - loss: 5.7398e-04 - mean_absolute_error: 0.0153 - val_loss: 5.4541e-04 - val_mean_absolute_error: 0.0165
# Epoch 111/215
# 149/149 [==============================] - ETA: 0s - loss: 5.2165e-04 - mean_absolute_error: 0.015 - 0s 47us/step - loss: 5.6686e-04 - mean_absolute_error: 0.0151 - val_loss: 5.5912e-04 - val_mean_absolute_error: 0.0170
# Epoch 112/215
# 149/149 [==============================] - 0s 40us/step - loss: 5.8016e-04 - mean_absolute_error: 0.0155 - val_loss: 5.5580e-04 - val_mean_absolute_error: 0.0171
# Epoch 113/215
# 149/149 [==============================] - 0s 47us/step - loss: 5.6232e-04 - mean_absolute_error: 0.0150 - val_loss: 5.2758e-04 - val_mean_absolute_error: 0.0161
# Epoch 114/215
# 149/149 [==============================] - 0s 54us/step - loss: 5.6712e-04 - mean_absolute_error: 0.0151 - val_loss: 5.4580e-04 - val_mean_absolute_error: 0.0168
# Epoch 115/215
# 149/149 [==============================] - 0s 40us/step - loss: 5.6168e-04 - mean_absolute_error: 0.0152 - val_loss: 5.5247e-04 - val_mean_absolute_error: 0.0169
# Epoch 116/215
# 149/149 [==============================] - 0s 54us/step - loss: 5.6010e-04 - mean_absolute_error: 0.0152 - val_loss: 5.3815e-04 - val_mean_absolute_error: 0.0165
# Epoch 117/215
# 149/149 [==============================] - 0s 40us/step - loss: 5.6380e-04 - mean_absolute_error: 0.0152 - val_loss: 5.4766e-04 - val_mean_absolute_error: 0.0168
# Epoch 118/215
# 149/149 [==============================] - 0s 54us/step - loss: 5.5846e-04 - mean_absolute_error: 0.0151 - val_loss: 5.4297e-04 - val_mean_absolute_error: 0.0167
# Epoch 119/215
# 149/149 [==============================] - 0s 47us/step - loss: 5.7152e-04 - mean_absolute_error: 0.0154 - val_loss: 5.3951e-04 - val_mean_absolute_error: 0.0166
# Epoch 120/215
# 149/149 [==============================] - 0s 47us/step - loss: 5.6303e-04 - mean_absolute_error: 0.0151 - val_loss: 5.3867e-04 - val_mean_absolute_error: 0.0164
# Epoch 121/215
# 149/149 [==============================] - 0s 47us/step - loss: 5.5974e-04 - mean_absolute_error: 0.0151 - val_loss: 5.5994e-04 - val_mean_absolute_error: 0.0170
# Epoch 122/215
# 149/149 [==============================] - 0s 47us/step - loss: 5.5978e-04 - mean_absolute_error: 0.0153 - val_loss: 5.4015e-04 - val_mean_absolute_error: 0.0165
# Epoch 123/215
# 149/149 [==============================] - 0s 47us/step - loss: 5.7460e-04 - mean_absolute_error: 0.0152 - val_loss: 5.4300e-04 - val_mean_absolute_error: 0.0166
# Epoch 124/215
# 149/149 [==============================] - 0s 54us/step - loss: 5.5071e-04 - mean_absolute_error: 0.0151 - val_loss: 5.6877e-04 - val_mean_absolute_error: 0.0174
# Epoch 125/215
# 149/149 [==============================] - 0s 47us/step - loss: 5.5903e-04 - mean_absolute_error: 0.0152 - val_loss: 5.3087e-04 - val_mean_absolute_error: 0.0165
# Epoch 126/215
# 149/149 [==============================] - 0s 47us/step - loss: 5.5602e-04 - mean_absolute_error: 0.0151 - val_loss: 5.4141e-04 - val_mean_absolute_error: 0.0167
# Epoch 127/215
# 149/149 [==============================] - 0s 40us/step - loss: 5.4922e-04 - mean_absolute_error: 0.0150 - val_loss: 5.5621e-04 - val_mean_absolute_error: 0.0172
# Epoch 128/215
# 149/149 [==============================] - 0s 47us/step - loss: 5.5454e-04 - mean_absolute_error: 0.0152 - val_loss: 5.5177e-04 - val_mean_absolute_error: 0.0170
# Epoch 129/215
# 149/149 [==============================] - 0s 60us/step - loss: 5.5867e-04 - mean_absolute_error: 0.0152 - val_loss: 5.3842e-04 - val_mean_absolute_error: 0.0165
# Epoch 130/215
# 149/149 [==============================] - 0s 47us/step - loss: 5.5783e-04 - mean_absolute_error: 0.0153 - val_loss: 5.6214e-04 - val_mean_absolute_error: 0.0172
# Epoch 131/215
# 149/149 [==============================] - 0s 60us/step - loss: 5.5010e-04 - mean_absolute_error: 0.0149 - val_loss: 5.2081e-04 - val_mean_absolute_error: 0.0162
# Epoch 132/215
# 149/149 [==============================] - 0s 47us/step - loss: 5.4855e-04 - mean_absolute_error: 0.0150 - val_loss: 5.4133e-04 - val_mean_absolute_error: 0.0168
# Epoch 133/215
# 149/149 [==============================] - 0s 54us/step - loss: 5.4800e-04 - mean_absolute_error: 0.0151 - val_loss: 5.4352e-04 - val_mean_absolute_error: 0.0168
# Epoch 134/215
# 149/149 [==============================] - 0s 54us/step - loss: 5.4606e-04 - mean_absolute_error: 0.0150 - val_loss: 5.2970e-04 - val_mean_absolute_error: 0.0163
# Epoch 135/215
# 149/149 [==============================] - 0s 47us/step - loss: 5.4668e-04 - mean_absolute_error: 0.0150 - val_loss: 5.4030e-04 - val_mean_absolute_error: 0.0167
# Epoch 136/215
# 149/149 [==============================] - 0s 60us/step - loss: 5.4910e-04 - mean_absolute_error: 0.0151 - val_loss: 5.3599e-04 - val_mean_absolute_error: 0.0167
# Epoch 137/215
# 149/149 [==============================] - 0s 54us/step - loss: 5.4596e-04 - mean_absolute_error: 0.0151 - val_loss: 5.5154e-04 - val_mean_absolute_error: 0.0170
# Epoch 138/215
# 149/149 [==============================] - 0s 54us/step - loss: 5.4227e-04 - mean_absolute_error: 0.0151 - val_loss: 5.3166e-04 - val_mean_absolute_error: 0.0165
# Epoch 139/215
# 149/149 [==============================] - 0s 47us/step - loss: 5.4365e-04 - mean_absolute_error: 0.0150 - val_loss: 5.3808e-04 - val_mean_absolute_error: 0.0166
# Epoch 140/215
# 149/149 [==============================] - 0s 47us/step - loss: 5.4825e-04 - mean_absolute_error: 0.0151 - val_loss: 5.4004e-04 - val_mean_absolute_error: 0.0167
# Epoch 141/215
# 149/149 [==============================] - 0s 54us/step - loss: 5.6671e-04 - mean_absolute_error: 0.0157 - val_loss: 5.6053e-04 - val_mean_absolute_error: 0.0173
# Epoch 142/215
# 149/149 [==============================] - 0s 47us/step - loss: 5.5160e-04 - mean_absolute_error: 0.0152 - val_loss: 5.1673e-04 - val_mean_absolute_error: 0.0161
# Epoch 143/215
# 149/149 [==============================] - 0s 54us/step - loss: 5.4269e-04 - mean_absolute_error: 0.0151 - val_loss: 5.4584e-04 - val_mean_absolute_error: 0.0170
# Epoch 144/215
# 149/149 [==============================] - 0s 47us/step - loss: 5.4033e-04 - mean_absolute_error: 0.0151 - val_loss: 5.3543e-04 - val_mean_absolute_error: 0.0167
# Epoch 145/215
# 149/149 [==============================] - 0s 47us/step - loss: 5.3879e-04 - mean_absolute_error: 0.0151 - val_loss: 5.3566e-04 - val_mean_absolute_error: 0.0166
# Epoch 146/215
# 149/149 [==============================] - 0s 40us/step - loss: 5.3760e-04 - mean_absolute_error: 0.0150 - val_loss: 5.3005e-04 - val_mean_absolute_error: 0.0164
# Epoch 147/215
# 149/149 [==============================] - 0s 47us/step - loss: 5.4023e-04 - mean_absolute_error: 0.0150 - val_loss: 5.4055e-04 - val_mean_absolute_error: 0.0167
# Epoch 148/215
# 149/149 [==============================] - 0s 47us/step - loss: 5.3861e-04 - mean_absolute_error: 0.0151 - val_loss: 5.4955e-04 - val_mean_absolute_error: 0.0169
# Epoch 149/215
# 149/149 [==============================] - 0s 47us/step - loss: 5.4137e-04 - mean_absolute_error: 0.0151 - val_loss: 5.2118e-04 - val_mean_absolute_error: 0.0162
# Epoch 150/215
# 149/149 [==============================] - 0s 54us/step - loss: 5.3319e-04 - mean_absolute_error: 0.0149 - val_loss: 5.5923e-04 - val_mean_absolute_error: 0.0173
# Epoch 151/215
# 149/149 [==============================] - 0s 47us/step - loss: 5.4409e-04 - mean_absolute_error: 0.0151 - val_loss: 5.2596e-04 - val_mean_absolute_error: 0.0164
# Epoch 152/215
# 149/149 [==============================] - 0s 54us/step - loss: 5.3685e-04 - mean_absolute_error: 0.0150 - val_loss: 5.3833e-04 - val_mean_absolute_error: 0.0168
# Epoch 153/215
# 149/149 [==============================] - 0s 47us/step - loss: 5.3130e-04 - mean_absolute_error: 0.0150 - val_loss: 5.3414e-04 - val_mean_absolute_error: 0.0166
# Epoch 154/215
# 149/149 [==============================] - 0s 47us/step - loss: 5.4041e-04 - mean_absolute_error: 0.0150 - val_loss: 5.4010e-04 - val_mean_absolute_error: 0.0167
# Epoch 155/215
# 149/149 [==============================] - 0s 47us/step - loss: 5.2866e-04 - mean_absolute_error: 0.0150 - val_loss: 5.6306e-04 - val_mean_absolute_error: 0.0174
# Epoch 156/215
# 149/149 [==============================] - 0s 54us/step - loss: 5.4710e-04 - mean_absolute_error: 0.0153 - val_loss: 5.2339e-04 - val_mean_absolute_error: 0.0164
# Epoch 157/215
# 149/149 [==============================] - 0s 47us/step - loss: 5.3359e-04 - mean_absolute_error: 0.0152 - val_loss: 5.6396e-04 - val_mean_absolute_error: 0.0174
# Epoch 158/215
# 149/149 [==============================] - 0s 47us/step - loss: 5.3292e-04 - mean_absolute_error: 0.0152 - val_loss: 5.2833e-04 - val_mean_absolute_error: 0.0165
# Epoch 159/215
# 149/149 [==============================] - 0s 54us/step - loss: 5.3273e-04 - mean_absolute_error: 0.0150 - val_loss: 5.4033e-04 - val_mean_absolute_error: 0.0168
# Epoch 160/215
# 149/149 [==============================] - 0s 54us/step - loss: 5.3538e-04 - mean_absolute_error: 0.0150 - val_loss: 5.2877e-04 - val_mean_absolute_error: 0.0166
# Epoch 161/215
# 149/149 [==============================] - 0s 54us/step - loss: 5.2235e-04 - mean_absolute_error: 0.0148 - val_loss: 5.5305e-04 - val_mean_absolute_error: 0.0172
# Epoch 162/215
# 149/149 [==============================] - 0s 47us/step - loss: 5.3880e-04 - mean_absolute_error: 0.0152 - val_loss: 5.3321e-04 - val_mean_absolute_error: 0.0167
# Epoch 163/215
# 149/149 [==============================] - 0s 54us/step - loss: 5.2881e-04 - mean_absolute_error: 0.0149 - val_loss: 5.5296e-04 - val_mean_absolute_error: 0.0172
# Epoch 164/215
# 149/149 [==============================] - 0s 40us/step - loss: 5.3334e-04 - mean_absolute_error: 0.0151 - val_loss: 5.3878e-04 - val_mean_absolute_error: 0.0167
# Epoch 165/215
# 149/149 [==============================] - 0s 54us/step - loss: 5.3206e-04 - mean_absolute_error: 0.0148 - val_loss: 5.2693e-04 - val_mean_absolute_error: 0.0165
# Epoch 166/215
# 149/149 [==============================] - 0s 54us/step - loss: 5.3071e-04 - mean_absolute_error: 0.0151 - val_loss: 5.6582e-04 - val_mean_absolute_error: 0.0175
# Epoch 167/215
# 149/149 [==============================] - 0s 47us/step - loss: 5.3743e-04 - mean_absolute_error: 0.0152 - val_loss: 5.2875e-04 - val_mean_absolute_error: 0.0165
# Epoch 168/215
# 149/149 [==============================] - 0s 54us/step - loss: 5.2545e-04 - mean_absolute_error: 0.0148 - val_loss: 5.6013e-04 - val_mean_absolute_error: 0.0173
# Epoch 169/215
# 149/149 [==============================] - 0s 60us/step - loss: 5.3506e-04 - mean_absolute_error: 0.0152 - val_loss: 5.4136e-04 - val_mean_absolute_error: 0.0169
# Epoch 170/215
# 149/149 [==============================] - 0s 47us/step - loss: 5.2630e-04 - mean_absolute_error: 0.0151 - val_loss: 5.4480e-04 - val_mean_absolute_error: 0.0169
# Epoch 171/215
# 149/149 [==============================] - 0s 47us/step - loss: 5.2281e-04 - mean_absolute_error: 0.0150 - val_loss: 5.2700e-04 - val_mean_absolute_error: 0.0165
# Epoch 172/215
# 149/149 [==============================] - 0s 47us/step - loss: 5.2388e-04 - mean_absolute_error: 0.0149 - val_loss: 5.2626e-04 - val_mean_absolute_error: 0.0164
# Epoch 173/215
# 149/149 [==============================] - 0s 34us/step - loss: 5.2831e-04 - mean_absolute_error: 0.0149 - val_loss: 5.5266e-04 - val_mean_absolute_error: 0.0170
# Epoch 174/215
# 149/149 [==============================] - 0s 60us/step - loss: 5.2140e-04 - mean_absolute_error: 0.0149 - val_loss: 5.1986e-04 - val_mean_absolute_error: 0.0162
# Epoch 175/215
# 149/149 [==============================] - 0s 47us/step - loss: 5.2239e-04 - mean_absolute_error: 0.0150 - val_loss: 5.4054e-04 - val_mean_absolute_error: 0.0169
# Epoch 176/215
# 149/149 [==============================] - 0s 47us/step - loss: 5.2170e-04 - mean_absolute_error: 0.0150 - val_loss: 5.3618e-04 - val_mean_absolute_error: 0.0167
# Epoch 177/215
# 149/149 [==============================] - 0s 34us/step - loss: 5.1985e-04 - mean_absolute_error: 0.0148 - val_loss: 5.3279e-04 - val_mean_absolute_error: 0.0167
# Epoch 178/215
# 149/149 [==============================] - 0s 54us/step - loss: 5.2216e-04 - mean_absolute_error: 0.0149 - val_loss: 5.3246e-04 - val_mean_absolute_error: 0.0167
# Epoch 179/215
# 149/149 [==============================] - 0s 54us/step - loss: 5.2202e-04 - mean_absolute_error: 0.0150 - val_loss: 5.2720e-04 - val_mean_absolute_error: 0.0166
# Epoch 180/215
# 149/149 [==============================] - 0s 54us/step - loss: 5.1642e-04 - mean_absolute_error: 0.0149 - val_loss: 5.3953e-04 - val_mean_absolute_error: 0.0169
# Epoch 181/215
# 149/149 [==============================] - 0s 54us/step - loss: 5.1766e-04 - mean_absolute_error: 0.0149 - val_loss: 5.3269e-04 - val_mean_absolute_error: 0.0167
# Epoch 182/215
# 149/149 [==============================] - 0s 47us/step - loss: 5.1719e-04 - mean_absolute_error: 0.0148 - val_loss: 5.2972e-04 - val_mean_absolute_error: 0.0166
# Epoch 183/215
# 149/149 [==============================] - 0s 54us/step - loss: 5.1598e-04 - mean_absolute_error: 0.0148 - val_loss: 5.5622e-04 - val_mean_absolute_error: 0.0172
# Epoch 184/215
# 149/149 [==============================] - 0s 47us/step - loss: 5.1878e-04 - mean_absolute_error: 0.0147 - val_loss: 5.2577e-04 - val_mean_absolute_error: 0.0164
# Epoch 185/215
# 149/149 [==============================] - 0s 54us/step - loss: 5.1306e-04 - mean_absolute_error: 0.0148 - val_loss: 5.4516e-04 - val_mean_absolute_error: 0.0170
# Epoch 186/215
# 149/149 [==============================] - 0s 47us/step - loss: 5.1411e-04 - mean_absolute_error: 0.0150 - val_loss: 5.2798e-04 - val_mean_absolute_error: 0.0166
# Epoch 187/215
# 149/149 [==============================] - 0s 47us/step - loss: 5.1293e-04 - mean_absolute_error: 0.0148 - val_loss: 5.2960e-04 - val_mean_absolute_error: 0.0167
# Epoch 188/215
# 149/149 [==============================] - 0s 40us/step - loss: 5.0949e-04 - mean_absolute_error: 0.0147 - val_loss: 5.5507e-04 - val_mean_absolute_error: 0.0171
# Epoch 189/215
# 149/149 [==============================] - 0s 47us/step - loss: 5.1220e-04 - mean_absolute_error: 0.0149 - val_loss: 5.3781e-04 - val_mean_absolute_error: 0.0168
# Epoch 190/215
# 149/149 [==============================] - 0s 40us/step - loss: 5.1492e-04 - mean_absolute_error: 0.0149 - val_loss: 5.3105e-04 - val_mean_absolute_error: 0.0168
# Epoch 191/215
# 149/149 [==============================] - 0s 60us/step - loss: 5.2134e-04 - mean_absolute_error: 0.0149 - val_loss: 5.3488e-04 - val_mean_absolute_error: 0.0166
# Epoch 192/215
# 149/149 [==============================] - 0s 47us/step - loss: 5.0539e-04 - mean_absolute_error: 0.0146 - val_loss: 5.5942e-04 - val_mean_absolute_error: 0.0173
# Epoch 193/215
# 149/149 [==============================] - 0s 60us/step - loss: 5.2002e-04 - mean_absolute_error: 0.0152 - val_loss: 5.3209e-04 - val_mean_absolute_error: 0.0165
# Epoch 194/215
# 149/149 [==============================] - 0s 54us/step - loss: 5.1454e-04 - mean_absolute_error: 0.0147 - val_loss: 5.2235e-04 - val_mean_absolute_error: 0.0163
# Epoch 195/215
# 149/149 [==============================] - 0s 60us/step - loss: 5.1392e-04 - mean_absolute_error: 0.0149 - val_loss: 5.3632e-04 - val_mean_absolute_error: 0.0169
# Epoch 196/215
# 149/149 [==============================] - 0s 54us/step - loss: 5.0639e-04 - mean_absolute_error: 0.0148 - val_loss: 5.1936e-04 - val_mean_absolute_error: 0.0163
# Epoch 197/215
# 149/149 [==============================] - 0s 47us/step - loss: 5.1967e-04 - mean_absolute_error: 0.0147 - val_loss: 5.2967e-04 - val_mean_absolute_error: 0.0167
# Epoch 198/215
# 149/149 [==============================] - 0s 54us/step - loss: 5.2878e-04 - mean_absolute_error: 0.0153 - val_loss: 5.4648e-04 - val_mean_absolute_error: 0.0170
# Epoch 199/215
# 149/149 [==============================] - 0s 47us/step - loss: 5.2538e-04 - mean_absolute_error: 0.0149 - val_loss: 5.2670e-04 - val_mean_absolute_error: 0.0163
# Epoch 200/215
# 149/149 [==============================] - 0s 54us/step - loss: 5.0801e-04 - mean_absolute_error: 0.0147 - val_loss: 5.6266e-04 - val_mean_absolute_error: 0.0174
# Epoch 201/215
# 149/149 [==============================] - 0s 47us/step - loss: 5.1239e-04 - mean_absolute_error: 0.0150 - val_loss: 5.1335e-04 - val_mean_absolute_error: 0.0163
# Epoch 202/215
# 149/149 [==============================] - 0s 47us/step - loss: 5.0858e-04 - mean_absolute_error: 0.0146 - val_loss: 5.3882e-04 - val_mean_absolute_error: 0.0170
# Epoch 203/215
# 149/149 [==============================] - 0s 60us/step - loss: 5.0565e-04 - mean_absolute_error: 0.0149 - val_loss: 5.3406e-04 - val_mean_absolute_error: 0.0168
# Epoch 204/215
# 149/149 [==============================] - 0s 60us/step - loss: 5.1131e-04 - mean_absolute_error: 0.0148 - val_loss: 5.2705e-04 - val_mean_absolute_error: 0.0167
# Epoch 205/215
# 149/149 [==============================] - 0s 40us/step - loss: 5.0646e-04 - mean_absolute_error: 0.0147 - val_loss: 5.4880e-04 - val_mean_absolute_error: 0.0170
# Epoch 206/215
# 149/149 [==============================] - 0s 54us/step - loss: 5.0134e-04 - mean_absolute_error: 0.0146 - val_loss: 5.5720e-04 - val_mean_absolute_error: 0.0171
# Epoch 207/215
# 149/149 [==============================] - 0s 54us/step - loss: 5.0806e-04 - mean_absolute_error: 0.0147 - val_loss: 5.2923e-04 - val_mean_absolute_error: 0.0165
# Epoch 208/215
# 149/149 [==============================] - 0s 47us/step - loss: 5.0057e-04 - mean_absolute_error: 0.0146 - val_loss: 5.5920e-04 - val_mean_absolute_error: 0.0173
# Epoch 209/215
# 149/149 [==============================] - 0s 60us/step - loss: 5.1259e-04 - mean_absolute_error: 0.0150 - val_loss: 5.3911e-04 - val_mean_absolute_error: 0.0169
# Epoch 210/215
# 149/149 [==============================] - 0s 47us/step - loss: 5.1360e-04 - mean_absolute_error: 0.0147 - val_loss: 5.2487e-04 - val_mean_absolute_error: 0.0164
# Epoch 211/215
# 149/149 [==============================] - 0s 47us/step - loss: 5.0515e-04 - mean_absolute_error: 0.0149 - val_loss: 5.6954e-04 - val_mean_absolute_error: 0.0176
# Epoch 212/215
# 149/149 [==============================] - 0s 54us/step - loss: 5.0268e-04 - mean_absolute_error: 0.0149 - val_loss: 5.2226e-04 - val_mean_absolute_error: 0.0163
# Epoch 213/215
# 149/149 [==============================] - 0s 40us/step - loss: 5.0751e-04 - mean_absolute_error: 0.0145 - val_loss: 5.4064e-04 - val_mean_absolute_error: 0.0169
# Epoch 214/215
# 149/149 [==============================] - 0s 47us/step - loss: 5.0186e-04 - mean_absolute_error: 0.0148 - val_loss: 5.4400e-04 - val_mean_absolute_error: 0.0169
# Epoch 215/215
# 149/149 [==============================] - 0s 54us/step - loss: 5.0804e-04 - mean_absolute_error: 0.0147 - val_loss: 5.3154e-04 - val_mean_absolute_error: 0.0165

# %% [markdown]
# ## Evaluate Model Results

# %%
# Plot the mean absolute error for the training data and validation data over the epochs.
plt.plot(run_history.history['mean_absolute_error'], label='MAE (training data)') 
plt.plot(run_history.history['val_mean_absolute_error'], label='MAE (validation data)') 
plt.title('MAE for GDP Neural Network Regression')
plt.ylabel('MAE value')
plt.xlabel('No. epoch')
plt.legend(loc="upper right")
fig = plt.gcf()
fig.set_size_inches(12,8)
plt.show()

# %%
# Make predictions using training data.
predictions_training = trained_model.predict(x_train_input)

# Measure the mean absolute error for the training data.
training_mean_abs_error = mean_absolute_error(y_train_rate, predictions_training)
print('Training mean abs error: {0:0.3f}'.format(training_mean_abs_error))

# Check the standard deviation of the training predictions to make sure it is not predicting
# a constant value for every input. It will do this if the regularization is to high.
print('Training predictions std: {0:0.3f}'.format(training_std))  #(predictions_training.std(axis=0)[0])*100.0))

# Make predictions using training data.
predictions_val = trained_model.predict(x_val_input)

# Measure the mean absolute error for the validation data.
val_mean_abs_error = mean_absolute_error(y_val_rate.to_numpy(), predictions_val)
print('Validation mean abs error: {0:0.3f}'.format(val_mean_abs_error))
# Out:
# Training mean abs error: 0.014
# Training predictions std: 1.586
# Validation mean abs error: 0.017

# %%
# Look at the predicted GDP growth rate vs the training growth rates
plt.plot(predictions_training*100.0, label='Training Predictions')
plt.plot(y_train_rate*100.0, label='Training Growth Rate')
plt.title('Predicted Training Growth Rate')
plt.ylabel('MAE value')
plt.xlabel('No. epoch')
plt.legend(loc="upper right")
fig = plt.gcf()
fig.set_size_inches(12,8)
plt.show()

# %%
# Look at the predicted GDP growth rate vs the training growth rates
plt.plot(predictions_val*100.0, label='Validation Set Predictions')
plt.plot((y_val_rate.to_numpy())*100.0, label='Validation Set Growth Rate')
plt.title('Predicted Validation Set Growth Rate')
plt.ylabel('MAE value')
plt.xlabel('No. epoch')
plt.legend(loc="upper right")
fig = plt.gcf()
fig.set_size_inches(12,8)
plt.show()

# %%
# Make predictions using test data.
predictions_test = trained_model.predict(x_test_input)

# Measure the mean absolute error for the test data.
test_mean_abs_error = mean_absolute_error(y_test_rate, predictions_test)
print('Test mean abs error: {0:0.3f}'.format(test_mean_abs_error))
# Out:
# Test mean abs error: 0.009

# %%
# Look at the predicted GDP growth rate vs the training growth rates
plt.plot(predictions_test*100.0, label='Test Set Predictions')
plt.plot((y_test_rate.to_numpy())*100.0, label='Test Set Growth Rate')
plt.title('Predicted Test Set Growth Rate')
plt.ylabel('MAE value')
plt.xlabel('No. epoch')
plt.legend(loc="upper right")
fig = plt.gcf()
fig.set_size_inches(12,8)
plt.show()

# %%
# Run a test case in the grid search.  This function will output a status update after each test case if
# print_real_time_output is True.  This function also appends a row to the "results" panda data frame 
# that is passed in for analysis later.

def run_test_case_nn(penalty, reg_type, dense_layers, stdinput, learning_rate, results, 
                     x_train, x_train_std, y_train, x_val, x_val_std, y_val, 
                     testcasecounter, print_real_time_output):
    
    test_case = '{6}: dense_layers={0}, reg={1}, penalty={2:0.07f}, lr={3:0.4f}, stdinput={4}, columns={5}'.format(
                                            in_dense_layers, in_reg_type, in_penalty, in_learning_rate, in_stdinput, columnset, testcasecounter)
    
    if print_real_time_output: print(test_case) # Print the test case if this indicator is True.

    (trained_model, run_history, training_std) = get_nn_model(penalty=penalty, reg_type=reg_type, dense_layers=dense_layers,
                                                stdinput=stdinput, learning_rate=learning_rate, 
                                                x_train=x_train[columnset],x_train_std=x_train_std[columnset], 
                                                y_train=y_train_rate, x_val=x_val[columnset], 
                                                x_val_std=x_val_std[columnset], y_val=y_val_rate, verbose=0)

    training_mae_min = np.min(run_history.history['mean_absolute_error']) # grab some min values from the run
    val_mae_min = np.min(run_history.history['val_mean_absolute_error'])

    test_case_result = 'Training mae min: {0:0.4f}, Val mae min: {1:0.4f}, Training std: {2:0.3f}\n'.format(
                                                                  training_mae_min, val_mae_min, training_std)
    if print_real_time_output: print(test_case_result)

    results = results.append(pd.Series([test_case, in_penalty, in_reg_type, in_dense_layers, in_learning_rate, columnset,
                                       in_stdinput, training_mae_min, val_mae_min, training_std], index=results.columns ), ignore_index=True)

    return (trained_model, results)

# %% [markdown]
# ## Setup a Hyperparameter Grid Search

# %%
# Run the neural network model repeatedly, doing a grid search of selected hyperparameter values.
# Results will be written to a pandas dataframe so that we can easily analyze the results.
# We will also write output messages to the screen to monitor progress, but go get a beverage 
# of your choice after kicking this off.

#results = []
results = pd.DataFrame(columns=['Desc','Penalty', 'Reg Type', 'Dense Layers', 'Learning Rate', 'Columns',
                                'StdInput', 'Training MAE Min', 'Val MAE Min', 'Training Std'])

columnsetall = ['WATERBORNE_PCT', 'RAIL_FRT_PCT', 'RAIL_INTERMOD_PCT', 'TRUCK_PCT', 'AIR_RTMFM_PCT', 'TSI_PCT']
columnset1 = ['RAIL_INTERMOD_PCT', 'AIR_RTMFM_PCT']
columnset2 = ['RAIL_INTERMOD_PCT', 'AIR_RTMFM_PCT', 'TSI_PCT']
columnset3 = ['TRUCK_PCT', 'RAIL_INTERMOD_PCT', 'AIR_RTMFM_PCT', 'TSI_PCT']
columnset4 = ['TSI_PCT']

testcasecounter = 0
print_real_time_output = True # Set this to false if you don't want output while the grid search is running.

for in_dense_layers in [32, 64]:  #16, 32, 64
    for in_reg_type in ["L1", "L2"]: #"L1", "L2"
        for in_penalty in [0.0001, 0.00001, 0.000001]:  # 0.0001, 0.0000001
            for in_learning_rate in [0.001]:  #0.01, 0.001, 0.0006
                for in_stdinput in [False]:
                    for columnset in [columnsetall, columnset1, columnset2]: #columnsetall, columnset1, columnset2, columnset3, columnset4]:
                        testcasecounter += 1
                        
                        (trained_model, results) = run_test_case_nn(penalty=in_penalty, reg_type=in_reg_type, dense_layers=in_dense_layers,
                                                                    stdinput=in_stdinput, learning_rate=in_learning_rate, results=results,
                                                                    x_train=x_train[columnset],x_train_std=x_train_std[columnset], 
                                                                    y_train=y_train_rate, x_val=x_val[columnset], 
                                                                    x_val_std=x_val_std[columnset], y_val=y_val_rate,
                                                                    testcasecounter=testcasecounter, print_real_time_output=print_real_time_output)
# Out:
# 1: dense_layers=32, reg=L1, penalty=0.0001000, lr=0.0010, stdinput=False, columns=['WATERBORNE_PCT', 'RAIL_FRT_PCT', 'RAIL_INTERMOD_PCT', 'TRUCK_PCT', 'AIR_RTMFM_PCT', 'TSI_PCT']
# Training mae min: 0.0180, Val mae min: 0.0159, Training std: 0.000
#
# 2: dense_layers=32, reg=L1, penalty=0.0001000, lr=0.0010, stdinput=False, columns=['RAIL_INTERMOD_PCT', 'AIR_RTMFM_PCT']
# Training mae min: 0.0177, Val mae min: 0.0160, Training std: 0.000
#
# 3: dense_layers=32, reg=L1, penalty=0.0001000, lr=0.0010, stdinput=False, columns=['RAIL_INTERMOD_PCT', 'AIR_RTMFM_PCT', 'TSI_PCT']
# Training mae min: 0.0178, Val mae min: 0.0160, Training std: 0.000
#
# 4: dense_layers=32, reg=L1, penalty=0.0000100, lr=0.0010, stdinput=False, columns=['WATERBORNE_PCT', 'RAIL_FRT_PCT', 'RAIL_INTERMOD_PCT', 'TRUCK_PCT', 'AIR_RTMFM_PCT', 'TSI_PCT']
# Training mae min: 0.0162, Val mae min: 0.0156, Training std: 1.252
#
# 5: dense_layers=32, reg=L1, penalty=0.0000100, lr=0.0010, stdinput=False, columns=['RAIL_INTERMOD_PCT', 'AIR_RTMFM_PCT']
# Training mae min: 0.0171, Val mae min: 0.0163, Training std: 1.152
#
# 6: dense_layers=32, reg=L1, penalty=0.0000100, lr=0.0010, stdinput=False, columns=['RAIL_INTERMOD_PCT', 'AIR_RTMFM_PCT', 'TSI_PCT']
# Training mae min: 0.0168, Val mae min: 0.0151, Training std: 1.211
#
# 7: dense_layers=32, reg=L1, penalty=0.0000010, lr=0.0010, stdinput=False, columns=['WATERBORNE_PCT', 'RAIL_FRT_PCT', 'RAIL_INTERMOD_PCT', 'TRUCK_PCT', 'AIR_RTMFM_PCT', 'TSI_PCT']
# Training mae min: 0.0110, Val mae min: 0.0173, Training std: 1.921
#
# 8: dense_layers=32, reg=L1, penalty=0.0000010, lr=0.0010, stdinput=False, columns=['RAIL_INTERMOD_PCT', 'AIR_RTMFM_PCT']
# Training mae min: 0.0160, Val mae min: 0.0171, Training std: 1.406
#
# 9: dense_layers=32, reg=L1, penalty=0.0000010, lr=0.0010, stdinput=False, columns=['RAIL_INTERMOD_PCT', 'AIR_RTMFM_PCT', 'TSI_PCT']
# Training mae min: 0.0148, Val mae min: 0.0162, Training std: 1.620
#
# 10: dense_layers=32, reg=L2, penalty=0.0001000, lr=0.0010, stdinput=False, columns=['WATERBORNE_PCT', 'RAIL_FRT_PCT', 'RAIL_INTERMOD_PCT', 'TRUCK_PCT', 'AIR_RTMFM_PCT', 'TSI_PCT']
# Training mae min: 0.0168, Val mae min: 0.0156, Training std: 1.055
#
# 11: dense_layers=32, reg=L2, penalty=0.0001000, lr=0.0010, stdinput=False, columns=['RAIL_INTERMOD_PCT', 'AIR_RTMFM_PCT']
# Training mae min: 0.0175, Val mae min: 0.0157, Training std: 0.869
#
# 12: dense_layers=32, reg=L2, penalty=0.0001000, lr=0.0010, stdinput=False, columns=['RAIL_INTERMOD_PCT', 'AIR_RTMFM_PCT', 'TSI_PCT']
# Training mae min: 0.0173, Val mae min: 0.0151, Training std: 0.903
#
# 13: dense_layers=32, reg=L2, penalty=0.0000100, lr=0.0010, stdinput=False, columns=['WATERBORNE_PCT', 'RAIL_FRT_PCT', 'RAIL_INTERMOD_PCT', 'TRUCK_PCT', 'AIR_RTMFM_PCT', 'TSI_PCT']
# Training mae min: 0.0130, Val mae min: 0.0157, Training std: 1.711
#
# 14: dense_layers=32, reg=L2, penalty=0.0000100, lr=0.0010, stdinput=False, columns=['RAIL_INTERMOD_PCT', 'AIR_RTMFM_PCT']
# Training mae min: 0.0162, Val mae min: 0.0154, Training std: 1.322
#
# 15: dense_layers=32, reg=L2, penalty=0.0000100, lr=0.0010, stdinput=False, columns=['RAIL_INTERMOD_PCT', 'AIR_RTMFM_PCT', 'TSI_PCT']
# Training mae min: 0.0157, Val mae min: 0.0166, Training std: 1.456
#
# 16: dense_layers=32, reg=L2, penalty=0.0000010, lr=0.0010, stdinput=False, columns=['WATERBORNE_PCT', 'RAIL_FRT_PCT', 'RAIL_INTERMOD_PCT', 'TRUCK_PCT', 'AIR_RTMFM_PCT', 'TSI_PCT']
# Training mae min: 0.0108, Val mae min: 0.0150, Training std: 1.964
#
# 17: dense_layers=32, reg=L2, penalty=0.0000010, lr=0.0010, stdinput=False, columns=['RAIL_INTERMOD_PCT', 'AIR_RTMFM_PCT']
# Training mae min: 0.0157, Val mae min: 0.0159, Training std: 1.495
#
# 18: dense_layers=32, reg=L2, penalty=0.0000010, lr=0.0010, stdinput=False, columns=['RAIL_INTERMOD_PCT', 'AIR_RTMFM_PCT', 'TSI_PCT']
# Training mae min: 0.0145, Val mae min: 0.0163, Training std: 1.617
#
# 19: dense_layers=64, reg=L1, penalty=0.0001000, lr=0.0010, stdinput=False, columns=['WATERBORNE_PCT', 'RAIL_FRT_PCT', 'RAIL_INTERMOD_PCT', 'TRUCK_PCT', 'AIR_RTMFM_PCT', 'TSI_PCT']
# Training mae min: 0.0175, Val mae min: 0.0153, Training std: 0.000
#
# 20: dense_layers=64, reg=L1, penalty=0.0001000, lr=0.0010, stdinput=False, columns=['RAIL_INTERMOD_PCT', 'AIR_RTMFM_PCT']
# Training mae min: 0.0178, Val mae min: 0.0158, Training std: 0.000
#
# 21: dense_layers=64, reg=L1, penalty=0.0001000, lr=0.0010, stdinput=False, columns=['RAIL_INTERMOD_PCT', 'AIR_RTMFM_PCT', 'TSI_PCT']
# Training mae min: 0.0177, Val mae min: 0.0157, Training std: 0.000
#
# 22: dense_layers=64, reg=L1, penalty=0.0000100, lr=0.0010, stdinput=False, columns=['WATERBORNE_PCT', 'RAIL_FRT_PCT', 'RAIL_INTERMOD_PCT', 'TRUCK_PCT', 'AIR_RTMFM_PCT', 'TSI_PCT']
# Training mae min: 0.0162, Val mae min: 0.0155, Training std: 1.313
#
# 23: dense_layers=64, reg=L1, penalty=0.0000100, lr=0.0010, stdinput=False, columns=['RAIL_INTERMOD_PCT', 'AIR_RTMFM_PCT']
# Training mae min: 0.0172, Val mae min: 0.0161, Training std: 1.091
#
# 24: dense_layers=64, reg=L1, penalty=0.0000100, lr=0.0010, stdinput=False, columns=['RAIL_INTERMOD_PCT', 'AIR_RTMFM_PCT', 'TSI_PCT']
# Training mae min: 0.0169, Val mae min: 0.0156, Training std: 1.172
#
# 25: dense_layers=64, reg=L1, penalty=0.0000010, lr=0.0010, stdinput=False, columns=['WATERBORNE_PCT', 'RAIL_FRT_PCT', 'RAIL_INTERMOD_PCT', 'TRUCK_PCT', 'AIR_RTMFM_PCT', 'TSI_PCT']
# Training mae min: 0.0105, Val mae min: 0.0162, Training std: 1.998
#
# 26: dense_layers=64, reg=L1, penalty=0.0000010, lr=0.0010, stdinput=False, columns=['RAIL_INTERMOD_PCT', 'AIR_RTMFM_PCT']
# Training mae min: 0.0160, Val mae min: 0.0165, Training std: 1.391
#
# 27: dense_layers=64, reg=L1, penalty=0.0000010, lr=0.0010, stdinput=False, columns=['RAIL_INTERMOD_PCT', 'AIR_RTMFM_PCT', 'TSI_PCT']
# Training mae min: 0.0149, Val mae min: 0.0158, Training std: 1.546
#
# 28: dense_layers=64, reg=L2, penalty=0.0001000, lr=0.0010, stdinput=False, columns=['WATERBORNE_PCT', 'RAIL_FRT_PCT', 'RAIL_INTERMOD_PCT', 'TRUCK_PCT', 'AIR_RTMFM_PCT', 'TSI_PCT']
# Training mae min: 0.0167, Val mae min: 0.0152, Training std: 1.115
#
# 29: dense_layers=64, reg=L2, penalty=0.0001000, lr=0.0010, stdinput=False, columns=['RAIL_INTERMOD_PCT', 'AIR_RTMFM_PCT']
# Training mae min: 0.0174, Val mae min: 0.0155, Training std: 0.768
#
# 30: dense_layers=64, reg=L2, penalty=0.0001000, lr=0.0010, stdinput=False, columns=['RAIL_INTERMOD_PCT', 'AIR_RTMFM_PCT', 'TSI_PCT']
# Training mae min: 0.0174, Val mae min: 0.0155, Training std: 0.943
#
# 31: dense_layers=64, reg=L2, penalty=0.0000100, lr=0.0010, stdinput=False, columns=['WATERBORNE_PCT', 'RAIL_FRT_PCT', 'RAIL_INTERMOD_PCT', 'TRUCK_PCT', 'AIR_RTMFM_PCT', 'TSI_PCT']
# Training mae min: 0.0120, Val mae min: 0.0152, Training std: 1.791
#
# 32: dense_layers=64, reg=L2, penalty=0.0000100, lr=0.0010, stdinput=False, columns=['RAIL_INTERMOD_PCT', 'AIR_RTMFM_PCT']
# Training mae min: 0.0162, Val mae min: 0.0155, Training std: 1.346
#
# 33: dense_layers=64, reg=L2, penalty=0.0000100, lr=0.0010, stdinput=False, columns=['RAIL_INTERMOD_PCT', 'AIR_RTMFM_PCT', 'TSI_PCT']
# Training mae min: 0.0154, Val mae min: 0.0160, Training std: 1.503
#
# 34: dense_layers=64, reg=L2, penalty=0.0000010, lr=0.0010, stdinput=False, columns=['WATERBORNE_PCT', 'RAIL_FRT_PCT', 'RAIL_INTERMOD_PCT', 'TRUCK_PCT', 'AIR_RTMFM_PCT', 'TSI_PCT']
# Training mae min: 0.0083, Val mae min: 0.0162, Training std: 2.208
#
# 35: dense_layers=64, reg=L2, penalty=0.0000010, lr=0.0010, stdinput=False, columns=['RAIL_INTERMOD_PCT', 'AIR_RTMFM_PCT']
# Training mae min: 0.0154, Val mae min: 0.0158, Training std: 1.408
#
# 36: dense_layers=64, reg=L2, penalty=0.0000010, lr=0.0010, stdinput=False, columns=['RAIL_INTERMOD_PCT', 'AIR_RTMFM_PCT', 'TSI_PCT']
# Training mae min: 0.0139, Val mae min: 0.0162, Training std: 1.740

# %% [markdown]
# ## Analyze the Hyperparameter Grid Search Results

# %%
# Sort the model runs in ascending order by the validation mean absolute value
results.sort_values('Training MAE Min', inplace=True)

# Take a look at the model configurations in order with best at the top. 
results[['Penalty', 'Reg Type', 'Dense Layers', 'Learning Rate', 'Columns', 'StdInput','Training MAE Min', 
         'Val MAE Min', 'Training Std']][results['Training MAE Min'] < 0.016]
# Out:
#      Penalty Reg Type Dense Layers  Learning Rate  \
# 33  0.000001       L2           64          0.001
# 24  0.000001       L1           64          0.001
# 15  0.000001       L2           32          0.001
# 6   0.000001       L1           32          0.001
# 30  0.000010       L2           64          0.001
# 12  0.000010       L2           32          0.001
# 35  0.000001       L2           64          0.001
# 17  0.000001       L2           32          0.001
# 8   0.000001       L1           32          0.001
# 26  0.000001       L1           64          0.001
# 34  0.000001       L2           64          0.001
# 32  0.000010       L2           64          0.001
# 16  0.000001       L2           32          0.001
# 14  0.000010       L2           32          0.001
# 7   0.000001       L1           32          0.001
# 25  0.000001       L1           64          0.001
#
#                                               Columns StdInput  \
# 33  [WATERBORNE_PCT, RAIL_FRT_PCT, RAIL_INTERMOD_P...    False
# 24  [WATERBORNE_PCT, RAIL_FRT_PCT, RAIL_INTERMOD_P...    False
# 15  [WATERBORNE_PCT, RAIL_FRT_PCT, RAIL_INTERMOD_P...    False
# 6   [WATERBORNE_PCT, RAIL_FRT_PCT, RAIL_INTERMOD_P...    False
# 30  [WATERBORNE_PCT, RAIL_FRT_PCT, RAIL_INTERMOD_P...    False
# 12  [WATERBORNE_PCT, RAIL_FRT_PCT, RAIL_INTERMOD_P...    False
# 35        [RAIL_INTERMOD_PCT, AIR_RTMFM_PCT, TSI_PCT]    False
# 17        [RAIL_INTERMOD_PCT, AIR_RTMFM_PCT, TSI_PCT]    False
# 8         [RAIL_INTERMOD_PCT, AIR_RTMFM_PCT, TSI_PCT]    False
# 26        [RAIL_INTERMOD_PCT, AIR_RTMFM_PCT, TSI_PCT]    False
# 34                 [RAIL_INTERMOD_PCT, AIR_RTMFM_PCT]    False
# 32        [RAIL_INTERMOD_PCT, AIR_RTMFM_PCT, TSI_PCT]    False
# 16                 [RAIL_INTERMOD_PCT, AIR_RTMFM_PCT]    False
# 14        [RAIL_INTERMOD_PCT, AIR_RTMFM_PCT, TSI_PCT]    False
# 7                  [RAIL_INTERMOD_PCT, AIR_RTMFM_PCT]    False
# 25                 [RAIL_INTERMOD_PCT, AIR_RTMFM_PCT]    False
#
#     Training MAE Min  Val MAE Min  Training Std
# 33          0.008256     0.016206      2.207711
# 24          0.010495     0.016243      1.997864
# 15          0.010792     0.015000      1.963859
# 6           0.011048     0.017257      1.920925
# 30          0.012038     0.015247      1.791485
# 12          0.013033     0.015658      1.710624
# 35          0.013894     0.016199      1.740143
# 17          0.014515     0.016294      1.617447
# 8           0.014756     0.016194      1.619956
# 26          0.014920     0.015836      1.546024
# 34          0.015362     0.015784      1.407584
# 32          0.015391     0.016023      1.503156
# 16          0.015660     0.015935      1.495060
# 14          0.015732     0.016603      1.455606
# 7           0.015966     0.017119      1.406176
# 25          0.015979     0.016539      1.391211

# %%
# Write the results to an Excel file.
#results.to_excel('gdp_output_20200703.xlsx')

# %%
# Create scatter plots for the hyperparameter values.  I am color coding the points for each parameter value on each plot.
# The x and y axis are both the validation mean absolute error.
# This is done to help with visualizing what parameter values scored better.

regcolors = ("red", "blue")
regtype = ("L1", "L2") 

fig, axs = plt.subplots(1, 4, sharex=True, sharey=True)

for ind in results.index:
    regtype_val = results['Reg Type'][ind]
    axs[0].scatter(results['Val MAE Min'][ind], results['Val MAE Min'][ind], 
               c=regcolors[regtype.index(regtype_val)],
               label=regtype_val, alpha=0.7, edgecolors='none')

handles, labels = axs[0].get_legend_handles_labels() #This section of code builds a
by_label = dict(zip(labels, handles))           #unique list of the labels and then uses 
axs[0].legend(by_label.values(), by_label.keys())  #them to build the legend. This is neccessary to
axs[0].set_title('Regularization Type')            #prevent duplicated labels in the legend.
    
densecolors = ("tab:red", "tab:olive", "tab:blue")
densetype = (16, 32, 64)
for ind in results.index:
    densetype_val = results['Dense Layers'][ind]
    #print(densetype_val)
    axs[1].scatter(results['Val MAE Min'][ind], results['Val MAE Min'][ind], 
               c=densecolors[densetype.index(densetype_val)], 
               label=densetype_val, alpha=0.8, edgecolors='none')
    
handles, labels = axs[1].get_legend_handles_labels() #This section of code builds a
by_label = dict(zip(labels, handles))           #unique list of the labels and then uses 
axs[1].legend(by_label.values(), by_label.keys())  #them to build the legend. This is neccessary to
                                               #prevent duplicated labels in the legend.
#https://stackoverflow.com/questions/13588920/stop-matplotlib-repeating-labels-in-legend
axs[1].set_title('Number of Dense Layers')

#Penalty
penaltycolors = ("tab:red", "tab:olive", "tab:blue") #, "tab:orange", "tab:green",
                 #"tab:purple", "tab:brown", "tab:pink", "tab:cyan")       #("tab:red", "tab:olive", "tab:blue")       
penaltytype = (0.0001, 0.00001, 0.000001) #(0.1, 0.01, 0.001)
for ind in results.index:
    penaltytype_val = results['Penalty'][ind]
    axs[2].scatter(results['Val MAE Min'][ind], results['Val MAE Min'][ind],
                   c=penaltycolors[penaltytype.index(penaltytype_val)],
                   label=penaltytype_val, alpha=0.8, edgecolors='none')

handles, labels = axs[2].get_legend_handles_labels() #This section of code builds a
by_label = dict(zip(labels, handles))           #unique list of the labels and then uses 
axs[2].legend(by_label.values(), by_label.keys())  #them to build the legend. This is neccessary to
                                               #prevent duplicated labels in the legend.
axs[2].set_title('Penalty')

#learninr Rate
# for in_learning_rate in [0.01, 0.001, 0.0006]
learnratecolors = ("tab:red", "tab:olive", "tab:blue")       
learnratetype = (0.01, 0.001, 0.0006)
for ind in results.index:
    learnratetype_val = results['Learning Rate'][ind]
    axs[3].scatter(results['Val MAE Min'][ind], results['Val MAE Min'][ind],
                   c=learnratecolors[learnratetype.index(learnratetype_val)],
                   label=learnratetype_val, alpha=0.8, edgecolors='none')

handles, labels = axs[3].get_legend_handles_labels() #This section of code builds a
by_label = dict(zip(labels, handles))           #unique list of the labels and then uses 
axs[3].legend(by_label.values(), by_label.keys())  #them to build the legend. This is neccessary to
                                               #prevent duplicated labels in the legend.
axs[3].set_title('Learning Rate')
    
#ax.legend(loc="upper left")
#fig = plt.gcf()
fig.set_size_inches(20,9)
#plt.show()

# %% [markdown]
# Based on the above charts and from looking at the data:
# -  Reg Type = L2
# -  Dense Layers = 32
# -  Penalty = 0.00001
# -  Learning Rate = 0.001
# -  Use raw data instead of normalize data
# -  For input features, use all columns, which were: "WATERBORNE_PCT", "RAIL_FRT_PCT", “TRUCK_PCT”, “RAIL_INTERMOD_PCT”, “AIR_RTMFM_PCT”, “TSI_PCT”
