# %% [markdown]
# # GDP Growth Rate Regression
#
# This notebook utilizes a neural network to predict the GDP growth rate based on transportation freight data that is published by the US Department of Transportation Bureau of Transportation Statistics.

# %% [markdown]
# ## Setup the Environment

# %%
#Import needed libraries
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
from sklearn.metrics import mean_absolute_error
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
from keras import regularizers
from keras import models
from keras import layers
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Get and Prep the Data
#
# I am using transportation data and GDP data that is published by the US government.  This step produces a data set that has transporation inputs and GDP data.

# %%
#Read in the transportation data, monthly seasonally adjusted
tsi_data = pd.read_excel(".\data\Input_SeasonalData_TSI.xlsx", header=2)

#look at the data types that were inferred by Pandas during import.
tsi_data.dtypes
# Out:
# OBS_DATE                   datetime64[ns]
# RAIL_FRT_CARLOADS_D11               int64
# RAIL_FRT_INTERMODAL_D11             int64
# WATERBORNE_D11                    float64
# TRUCK_D11                         float64
# AIR_RTMFM_D11                       int64
# TSI                               float64
# dtype: object

# %%
#Return a listing of the data
tsi_data.head()
# Out:
#     OBS_DATE  RAIL_FRT_CARLOADS_D11  RAIL_FRT_INTERMODAL_D11  WATERBORNE_D11  \
# 0 2000-01-01                1422442                   764756            55.4
# 1 2000-02-01                1425882                   767958            48.6
# 2 2000-03-01                1411458                   763858            52.5
# 3 2000-04-01                1400311                   764144            50.8
# 4 2000-05-01                1405169                   763843            52.5
#
#    TRUCK_D11  AIR_RTMFM_D11    TSI
# 0       80.3        2466950  105.3
# 1       79.8        2521852  104.4
# 2       74.1        2489787   99.2
# 3       72.8        2557332   98.1
# 4       73.0        2527821   98.6

# %%
#Read in the real gdp growth rates,seasonally adjusted, quarterly data with quarterly growth rates
gdp_data = pd.read_excel(".\data\Input_GDP_st_louis_fed_quarterly_change.xlsx")

# The gdp qtr growth rate from the file is in the format of 10% = 10.  We need to format it like
# the data below, with a format of 10% = 0.10.  Divide by 100 so the format will be consistent.
# This calculation should be kept in the same code block as the read from the file to ensure that
# this calculation is idempotent.
gdp_data.Real_gdp_qtr_growth = gdp_data.Real_gdp_qtr_growth/100.0

#look at the data types that were inferred by Pandas during import.
gdp_data.dtypes
# Out:
# observation_date       datetime64[ns]
# Real_gdp_qtr_growth           float64
# dtype: object

# %%
#Disply a listing of the data
gdp_data.head()
# Out:
#   observation_date  Real_gdp_qtr_growth
# 0       2000-01-01                0.015
# 1       2000-04-01                0.075
# 2       2000-07-01                0.005
# 3       2000-10-01                0.025
# 4       2001-01-01               -0.011

# %%
# Create a merged dataset based on the date, bringing together the transportation and GDP data. 
merged_data = pd.merge(tsi_data, gdp_data, how='left', left_on='OBS_DATE', right_on='observation_date')

# We now have 2 date columns with different names. Drop one of the date columns.
merged_data = merged_data.drop(['observation_date'], axis=1) #pandas can drop rows or columns, axis=1 indicates columns

#Forward fill the gdp data so that a quarterly gdp value will be used for 3 rows, with each row being a month.
#limit it only fill in 2 consective missing values.
merged_data['Real_gdp_qtr_growth'] = merged_data['Real_gdp_qtr_growth'].fillna(method='ffill', limit=2)

#drop rows where we don't have a gdp value
merged_data = merged_data.dropna(subset=['Real_gdp_qtr_growth'])

#Create a boolean column to indicate if gdp growth was positive or negative.
#merged_data['gdp_is_increasing'] = merged_data.apply(lambda x: True if x['Real_gdp_qtr_growth'] > 0.0 else False, axis=1)
merged_data['gdp_is_increasing'] = merged_data.apply(lambda x: 1 if x['Real_gdp_qtr_growth'] > 0.0 else 0, axis=1)

# Add columns for the freight data to calculate the percent change from the previous month.
# This will leave them in a format such as 10% = 0.10.
merged_data['RAIL_FRT_PCT'] = merged_data['RAIL_FRT_CARLOADS_D11'].pct_change()
merged_data['RAIL_INTERMOD_PCT'] = merged_data['RAIL_FRT_INTERMODAL_D11'].pct_change()
merged_data['WATERBORNE_PCT'] = merged_data['WATERBORNE_D11'].pct_change()
merged_data['TRUCK_PCT'] = merged_data['TRUCK_D11'].pct_change()
merged_data['AIR_RTMFM_PCT'] = merged_data['AIR_RTMFM_D11'].pct_change()
merged_data['TSI_PCT'] = merged_data['TSI'].pct_change()

# %% [markdown]
# ## Create the Training, Validation, and Test Data Sets

# %%
# Setup the split of the data between training and test data.  The test data will be split later into
# a validation set and test set.

validation_data_split = 0.2 # this is the percentage of the training set for validation
# the remainder of the data will be in the train data set.
test_data_split = 230  #this will be the number of weeks in the test data set, remainder of data in train data set

#Calculate the split date to use
max_obs_date = merged_data['OBS_DATE'].max()
print('Max Obs Date: {0}'.format(max_obs_date))
split_date = max_obs_date - timedelta(weeks=test_data_split) 
print('Split Date: {0}'.format(split_date))
print('Validation Split: {0:0.2f}'.format(validation_data_split))
# Out:
# Max Obs Date: 2019-12-01 00:00:00
# Split Date: 2015-07-05 00:00:00
# Validation Split: 0.20

# %%
# Create training, validation, and test dataframes
x_train = merged_data.loc[merged_data['OBS_DATE'] < split_date, 'RAIL_FRT_PCT':'TSI_PCT']
x_train = x_train.drop([0]) #drop first row as it will have NA for pct_change values

total_row_count = len(x_train)
val_row_count = round(total_row_count*validation_data_split) 
train_row_count = total_row_count - val_row_count

x_val = x_train.iloc[train_row_count:]
x_train = x_train.iloc[:train_row_count]
print('x_train row count: {0}'.format(len(x_train.index)))
print('x_val row count: {0}'.format(len(x_val.index)))

y_train_class = merged_data.iloc[1:train_row_count+1]['gdp_is_increasing'] #ignore first row as it wont have pct_change values
y_val_class = merged_data.iloc[train_row_count+1:total_row_count+1]['gdp_is_increasing']
print('y_train_class row count: {0}'.format(len(y_train_class.index)))
print('y_val_class row count: {0}'.format(len(y_val_class.index)))

y_train_rate = merged_data.iloc[1:train_row_count+1]['Real_gdp_qtr_growth'] #ignore first row as it wont have pct_change values
y_val_rate = merged_data.iloc[train_row_count+1:total_row_count+1]['Real_gdp_qtr_growth']

print('y_train_rate row count: {0}'.format(len(y_train_rate.index)))
print('y_val_rate row count: {0}'.format(len(y_val_rate.index)))

# Test sets
x_test = merged_data.loc[merged_data['OBS_DATE'] >= split_date, 'RAIL_FRT_PCT':'TSI_PCT']
y_test_class = merged_data.loc[merged_data['OBS_DATE'] >= split_date, 'gdp_is_increasing']
y_test_rate = merged_data.loc[merged_data['OBS_DATE'] >= split_date, 'Real_gdp_qtr_growth']

print('x_test row count: {0}'.format(len(x_test.index)))
print('y_test_class row count: {0}'.format(len(y_test_class.index)))
print('y_test_rate row count: {0}'.format(len(y_test_rate.index)))
# Out:
# x_train row count: 149
# x_val row count: 37
# y_train_class row count: 149
# y_val_class row count: 37
# y_train_rate row count: 149
# y_val_rate row count: 37
# x_test row count: 53
# y_test_class row count: 53
# y_test_rate row count: 53

# %% [markdown]
# ## Check Out the Data

# %%
x_train.describe()
# Out:
#        RAIL_FRT_PCT  RAIL_INTERMOD_PCT  WATERBORNE_PCT   TRUCK_PCT  \
# count    149.000000         149.000000      149.000000  149.000000
# mean      -0.000753           0.002298        0.000192    0.000864
# std        0.019283           0.020187        0.055002    0.016473
# min       -0.064277          -0.089458       -0.148492   -0.071429
# 25%       -0.010147          -0.006948       -0.032381   -0.008197
# 50%       -0.000677           0.004158        0.002273    0.000000
# 75%        0.009911           0.012970        0.023196    0.011299
# max        0.049698           0.098418        0.158960    0.040047
#
#        AIR_RTMFM_PCT     TSI_PCT
# count     149.000000  149.000000
# mean        0.002237    0.000605
# std         0.038921    0.013436
# min        -0.116712   -0.050495
# 25%        -0.014782   -0.007951
# 50%        -0.001036    0.001791
# 75%         0.018707    0.008937
# max         0.276234    0.031022

# %%
y_train_rate.describe()
# Out:
# count    149.000000
# mean       0.018906
# std        0.026905
# min       -0.084000
# 25%        0.009000
# 50%        0.022000
# 75%        0.035000
# max        0.075000
# Name: Real_gdp_qtr_growth, dtype: float64

# %%
# Plot some of the data.  You can add in different columns from the dataset by uncommenting.
#plt.plot(merged_data['OBS_DATE'], merged_data['RAIL_FRT_PCT']*100.0, label='Rail Frt')
plt.plot(merged_data['OBS_DATE'], merged_data['Real_gdp_qtr_growth']*100.0, label='GDP')
#plt.plot(merged_data['OBS_DATE'], merged_data['RAIL_INTERMOD_PCT']*100.0, label='Rail Intermod')
#plt.plot(merged_data['OBS_DATE'], merged_data['WATERBORNE_PCT']*100.0, label='Water')
#plt.plot(merged_data['OBS_DATE'], merged_data['TRUCK_PCT']*100.0, label='Truck')
#plt.plot(merged_data['OBS_DATE'], merged_data['AIR_RTMFM_PCT']*100.0, label='Air and Mail Frt')
plt.plot(merged_data['OBS_DATE'], merged_data['TSI_PCT']*100.0, label='TSI')
plt.title('GDP and TSI Growth Rates')
plt.ylabel('Growth Rate (%)')
plt.xlabel('Time Period')
plt.legend()
plt.axhline(-4, 0, 250, c='lightgrey')
plt.axhline(-2, 0, 250, c='lightgrey')
plt.axhline(0, 0, 250, c='lightgrey')
plt.axhline(2, 0, 250, c='lightgrey')
plt.axhline(4, 0, 250, c='lightgrey')
fig = plt.gcf()
fig.set_size_inches(16,10)

# %%
# Examine the GDP growth rate over all of our data. Color code the values that are in the
# training, validation, and test data sets.

plt.plot(merged_data.iloc[:train_row_count]['OBS_DATE'], 
         merged_data.iloc[:train_row_count]['Real_gdp_qtr_growth']*100.0, Label="Train")
plt.plot(merged_data.iloc[train_row_count:train_row_count + val_row_count]['OBS_DATE'], 
         merged_data.iloc[train_row_count:train_row_count + val_row_count]['Real_gdp_qtr_growth']*100.0, Label="Validation")
plt.plot(merged_data.iloc[train_row_count + val_row_count:]['OBS_DATE'], 
        merged_data.iloc[train_row_count + val_row_count:]['Real_gdp_qtr_growth']*100.0, Label="Test")
plt.title('GDP Growth Rates Across Datasets')
plt.ylabel('Growth Rate (%)')
plt.xlabel('Time Period')
#plt.xticks(np.arange(2000, 2020,step=2))
plt.legend()
plt.axhline(-4, 0, 250, c='lightgrey')
plt.axhline(-2, 0, 250, c='lightgrey')
plt.axhline(0, 0, 250, c='lightgrey')
plt.axhline(2, 0, 250, c='lightgrey')
plt.axhline(4, 0, 250, c='lightgrey')
fig = plt.gcf()
fig.set_size_inches(16,10)
#merged_data

# %% [markdown]
# We can see in the chart above that the GDP growth rate varies a lot more in the training data set then it does in the validation set.  And, the validation set has more variance then the test set.
#
# Below, we calculate the standard deviation for the output values for each data set.

# %%
y_train_std = merged_data.iloc[:train_row_count]['Real_gdp_qtr_growth'].std(axis=0)
print('y_train_std: {0:0.3f}'.format(y_train_std))

y_val_std = merged_data.iloc[train_row_count:train_row_count + val_row_count]['Real_gdp_qtr_growth'].std(axis=0)
print('y_val_std: {0:0.3f}'.format(y_val_std))

y_test_std = merged_data.iloc[train_row_count + val_row_count:]['Real_gdp_qtr_growth'].std(axis=0)
print('y_test_std: {0:0.3f}'.format(y_test_std))
# Out:
# y_train_std: 0.027
# y_val_std: 0.019
# y_test_std: 0.008

# %% [markdown]
# The below chart takes the gdp growth rate and adds in input columns.

# %% [markdown]
# ## Normalize the Data

# %%
#Calculate the mean and standard deviation of the training data set.
mean = x_train.mean(axis=0)
std = x_train.std(axis=0)

#Normalize the training data set to have a mean of 0 and standard deviation of 1.
x_train_std = x_train - mean
x_train_std = x_train_std / std

#Normalize the validation data set to have a mean of 0 and standard deviation of 1.
x_val_std = x_val - mean
x_val_std = x_val_std / std

#Normalize the test data set to have a mean of 0 and standard deviation of 1.
x_test_std = x_test - mean
x_test_std = x_test_std / std

# %%
#Examine the stats on the normalized training set
x_train_std.describe()
# Out:
#        RAIL_FRT_PCT  RAIL_INTERMOD_PCT  WATERBORNE_PCT     TRUCK_PCT  \
# count  1.490000e+02       1.490000e+02    1.490000e+02  1.490000e+02
# mean  -1.490232e-18      -2.384372e-17    1.266697e-17  1.490232e-18
# std    1.000000e+00       1.000000e+00    1.000000e+00  1.000000e+00
# min   -3.294367e+00      -4.545280e+00   -2.703246e+00 -4.388498e+00
# 25%   -4.872035e-01      -4.580180e-01   -5.922187e-01 -5.500188e-01
# 50%    3.917056e-03       9.213551e-02    3.782409e-02 -5.243816e-02
# 75%    5.530022e-01       5.286379e-01    4.182304e-01  6.334922e-01
# max    2.616357e+00       4.761394e+00    2.886566e+00  2.378615e+00
#
#        AIR_RTMFM_PCT       TSI_PCT
# count   1.490000e+02  1.490000e+02
# mean    3.818720e-17  4.470697e-18
# std     1.000000e+00  1.000000e+00
# min    -3.056159e+00 -3.803338e+00
# 25%    -4.372516e-01 -6.368092e-01
# 50%    -8.407633e-02  8.820267e-02
# 75%     4.231870e-01  6.200724e-01
# max     7.039878e+00  2.263854e+00

# %% [markdown]
# ## Setup a Neural Network Model Using Keras

# %%
# We will use this to run the model multiple times with varying input parameters.
# The neural network has the following structure:

# Dense layer -> Batch Normalization Layer -> 
# Dense Layer -> Batch Normalization Layer -> 
# Dense Layer with linear activation

# This function has input parameters for different regularization factors (penalty),
# regularization types (L1 and L2 supported), and number of dense layers.

def get_nn_model(penalty, reg_type, dense_layers, stdinput, learning_rate, 
                 x_train, x_train_std, y_train, x_val, x_val_std, y_val):
        
    if stdinput:
        xinput = x_train_std
        xval = x_val_std
    else:
        xinput = x_train
        xval = x_val
    
    nn_model = models.Sequential()
    
    if reg_type == "L2":
        nn_model.add(layers.Dense(dense_layers, activation='relu', input_shape=(xinput.shape[1],), kernel_regularizer=regularizers.l2(penalty)))
    else:
        nn_model.add(layers.Dense(dense_layers, activation='relu', input_shape=(xinput.shape[1],), kernel_regularizer=regularizers.l1(penalty)))
        
    #nn_model.add(layers.BatchNormalization())

    if reg_type == "L2":
        nn_model.add(layers.Dense(dense_layers, activation='relu', kernel_regularizer=regularizers.l2(penalty)))
    else:
        nn_model.add(layers.Dense(dense_layers, activation='relu', kernel_regularizer=regularizers.l1(penalty)))

    #nn_model.add(layers.BatchNormalization())
    nn_model.add(layers.Dense(1, activation='linear'))
    
    nn_model.compile(optimizer='Adam', loss='mse', metrics=['mae'])
    nn_model.optimizer.lr = learning_rate
    
    run_history = nn_model.fit(x=xinput, y=y_train.to_numpy(), epochs=300, validation_data=(xval, y_val)) #, verbose=0)
    
    return (nn_model, run_history)

# %%
# Run the model on a subset of the input data columns.
columnset = ['TRUCK_PCT', 'RAIL_INTERMOD_PCT', 'AIR_RTMFM_PCT', 'TSI_PCT']
x_train_input = x_train[columnset]
x_train_std_input = x_train_std[columnset]
x_val_input = x_val[columnset]
x_val_std_input = x_val_std[columnset]
x_test_input = x_test[columnset]
x_test_std_input = x_test_std[columnset]

# %%
# Inital run / single run of the model.

(trained_model, run_history) = get_nn_model(penalty=0.04, reg_type='L1', dense_layers=64, stdinput=False, learning_rate = 0.001, 
                                            x_train=x_train_input, x_train_std=x_train_std_input, y_train=y_train_rate, 
                                            x_val=x_val_input, x_val_std=x_val_std_input, y_val=y_val_rate)
# Out:
# Train on 149 samples, validate on 37 samples
# Epoch 1/300
# 149/149 [==============================] - 1s 7ms/step - loss: 20.5013 - mean_absolute_error: 0.8176 - val_loss: 20.2545 - val_mean_absolute_error: 0.5598
# Epoch 2/300
# 149/149 [==============================] - 0s 60us/step - loss: 19.1703 - mean_absolute_error: 0.4520 - val_loss: 19.3675 - val_mean_absolute_error: 0.7572
# Epoch 3/300
# 149/149 [==============================] - 0s 81us/step - loss: 18.5724 - mean_absolute_error: 0.3426 - val_loss: 18.8940 - val_mean_absolute_error: 0.7640
# Epoch 4/300
# 149/149 [==============================] - 0s 67us/step - loss: 18.0168 - mean_absolute_error: 0.2857 - val_loss: 17.9741 - val_mean_absolute_error: 0.4630
# Epoch 5/300
# 149/149 [==============================] - 0s 60us/step - loss: 17.4691 - mean_absolute_error: 0.2478 - val_loss: 17.4210 - val_mean_absolute_error: 0.4151
# Epoch 6/300
# 149/149 [==============================] - 0s 54us/step - loss: 16.9350 - mean_absolute_error: 0.2298 - val_loss: 16.8713 - val_mean_absolute_error: 0.4236
# Epoch 7/300
# 149/149 [==============================] - 0s 67us/step - loss: 16.3751 - mean_absolute_error: 0.1681 - val_loss: 16.3474 - val_mean_absolute_error: 0.4803
# Epoch 8/300
# 149/149 [==============================] - 0s 67us/step - loss: 15.8493 - mean_absolute_error: 0.1753 - val_loss: 15.8072 - val_mean_absolute_error: 0.5122
# Epoch 9/300
# 149/149 [==============================] - 0s 81us/step - loss: 15.3334 - mean_absolute_error: 0.1887 - val_loss: 15.2274 - val_mean_absolute_error: 0.4597
# Epoch 10/300
# 149/149 [==============================] - 0s 74us/step - loss: 14.7969 - mean_absolute_error: 0.1601 - val_loss: 14.6415 - val_mean_absolute_error: 0.3696
# Epoch 11/300
# 149/149 [==============================] - 0s 67us/step - loss: 14.2789 - mean_absolute_error: 0.1533 - val_loss: 14.0545 - val_mean_absolute_error: 0.2560
# Epoch 12/300
# 149/149 [==============================] - 0s 114us/step - loss: 13.7607 - mean_absolute_error: 0.1354 - val_loss: 13.4954 - val_mean_absolute_error: 0.2196
# Epoch 13/300
# 149/149 [==============================] - 0s 87us/step - loss: 13.2589 - mean_absolute_error: 0.1655 - val_loss: 13.0204 - val_mean_absolute_error: 0.2859
# Epoch 14/300
# 149/149 [==============================] - 0s 87us/step - loss: 12.7448 - mean_absolute_error: 0.1325 - val_loss: 12.5287 - val_mean_absolute_error: 0.2924
# Epoch 15/300
# 149/149 [==============================] - 0s 60us/step - loss: 12.2419 - mean_absolute_error: 0.1108 - val_loss: 12.0042 - val_mean_absolute_error: 0.2385
# Epoch 16/300
# 149/149 [==============================] - 0s 87us/step - loss: 11.7648 - mean_absolute_error: 0.1374 - val_loss: 11.4858 - val_mean_absolute_error: 0.1740
# Epoch 17/300
# 149/149 [==============================] - 0s 87us/step - loss: 11.2777 - mean_absolute_error: 0.1222 - val_loss: 11.0042 - val_mean_absolute_error: 0.1611
# Epoch 18/300
# 149/149 [==============================] - 0s 74us/step - loss: 10.8151 - mean_absolute_error: 0.1358 - val_loss: 10.5509 - val_mean_absolute_error: 0.1987
# Epoch 19/300
# 149/149 [==============================] - 0s 60us/step - loss: 10.3497 - mean_absolute_error: 0.1317 - val_loss: 10.0856 - val_mean_absolute_error: 0.1766
# Epoch 20/300
# 149/149 [==============================] - 0s 81us/step - loss: 9.8963 - mean_absolute_error: 0.1261 - val_loss: 9.6363 - val_mean_absolute_error: 0.1797
# Epoch 21/300
# 149/149 [==============================] - 0s 81us/step - loss: 9.4489 - mean_absolute_error: 0.1049 - val_loss: 9.1898 - val_mean_absolute_error: 0.1498
# Epoch 22/300
# 149/149 [==============================] - 0s 67us/step - loss: 9.0214 - mean_absolute_error: 0.1096 - val_loss: 8.7595 - val_mean_absolute_error: 0.1226
# Epoch 23/300
# 149/149 [==============================] - 0s 87us/step - loss: 8.6024 - mean_absolute_error: 0.1037 - val_loss: 8.3468 - val_mean_absolute_error: 0.1180
# Epoch 24/300
# 149/149 [==============================] - 0s 74us/step - loss: 8.1925 - mean_absolute_error: 0.1061 - val_loss: 7.9393 - val_mean_absolute_error: 0.0946
# Epoch 25/300
# 149/149 [==============================] - 0s 60us/step - loss: 7.7932 - mean_absolute_error: 0.1042 - val_loss: 7.5433 - val_mean_absolute_error: 0.1011
# Epoch 26/300
# 149/149 [==============================] - 0s 67us/step - loss: 7.4034 - mean_absolute_error: 0.1008 - val_loss: 7.1696 - val_mean_absolute_error: 0.1177
# Epoch 27/300
# 149/149 [==============================] - 0s 67us/step - loss: 7.0329 - mean_absolute_error: 0.1186 - val_loss: 6.7998 - val_mean_absolute_error: 0.1181
# Epoch 28/300
# 149/149 [==============================] - 0s 74us/step - loss: 6.6573 - mean_absolute_error: 0.0890 - val_loss: 6.4508 - val_mean_absolute_error: 0.1386
# Epoch 29/300
# 149/149 [==============================] - 0s 67us/step - loss: 6.3097 - mean_absolute_error: 0.0950 - val_loss: 6.1011 - val_mean_absolute_error: 0.1122
# Epoch 30/300
# 149/149 [==============================] - 0s 81us/step - loss: 5.9691 - mean_absolute_error: 0.0842 - val_loss: 5.7726 - val_mean_absolute_error: 0.1139
# Epoch 31/300
# 149/149 [==============================] - 0s 87us/step - loss: 5.6508 - mean_absolute_error: 0.0974 - val_loss: 5.4551 - val_mean_absolute_error: 0.1053
# Epoch 32/300
# 149/149 [==============================] - 0s 81us/step - loss: 5.3405 - mean_absolute_error: 0.0991 - val_loss: 5.1648 - val_mean_absolute_error: 0.1269
# Epoch 33/300
# 149/149 [==============================] - 0s 74us/step - loss: 5.0356 - mean_absolute_error: 0.0834 - val_loss: 4.8897 - val_mean_absolute_error: 0.1763
# Epoch 34/300
# 149/149 [==============================] - 0s 81us/step - loss: 4.7532 - mean_absolute_error: 0.1011 - val_loss: 4.6213 - val_mean_absolute_error: 0.1991
# Epoch 35/300
# 149/149 [==============================] - 0s 87us/step - loss: 4.4780 - mean_absolute_error: 0.0949 - val_loss: 4.3500 - val_mean_absolute_error: 0.1883
# Epoch 36/300
# 149/149 [==============================] - 0s 94us/step - loss: 4.2090 - mean_absolute_error: 0.0825 - val_loss: 4.0933 - val_mean_absolute_error: 0.1873
# Epoch 37/300
# 149/149 [==============================] - 0s 81us/step - loss: 3.9589 - mean_absolute_error: 0.0691 - val_loss: 3.8673 - val_mean_absolute_error: 0.2106
# Epoch 38/300
# 149/149 [==============================] - 0s 67us/step - loss: 3.7214 - mean_absolute_error: 0.0710 - val_loss: 3.6252 - val_mean_absolute_error: 0.1911
# Epoch 39/300
# 149/149 [==============================] - 0s 81us/step - loss: 3.5026 - mean_absolute_error: 0.0713 - val_loss: 3.4102 - val_mean_absolute_error: 0.1832
# Epoch 40/300
# 149/149 [==============================] - 0s 74us/step - loss: 3.2967 - mean_absolute_error: 0.0663 - val_loss: 3.2281 - val_mean_absolute_error: 0.1988
# Epoch 41/300
# 149/149 [==============================] - 0s 81us/step - loss: 3.1044 - mean_absolute_error: 0.0696 - val_loss: 3.0478 - val_mean_absolute_error: 0.2214
# Epoch 42/300
# 149/149 [==============================] - ETA: 0s - loss: 2.9915 - mean_absolute_error: 0.075 - 0s 74us/step - loss: 2.9277 - mean_absolute_error: 0.0893 - val_loss: 2.8680 - val_mean_absolute_error: 0.1969
# Epoch 43/300
# 149/149 [==============================] - 0s 74us/step - loss: 2.7555 - mean_absolute_error: 0.0843 - val_loss: 2.6944 - val_mean_absolute_error: 0.1889
# Epoch 44/300
# 149/149 [==============================] - 0s 60us/step - loss: 2.5972 - mean_absolute_error: 0.0730 - val_loss: 2.5476 - val_mean_absolute_error: 0.1969
# Epoch 45/300
# 149/149 [==============================] - 0s 81us/step - loss: 2.4553 - mean_absolute_error: 0.0808 - val_loss: 2.4233 - val_mean_absolute_error: 0.2146
# Epoch 46/300
# 149/149 [==============================] - 0s 67us/step - loss: 2.3183 - mean_absolute_error: 0.0670 - val_loss: 2.2949 - val_mean_absolute_error: 0.2251
# Epoch 47/300
# 149/149 [==============================] - 0s 74us/step - loss: 2.1940 - mean_absolute_error: 0.0726 - val_loss: 2.1864 - val_mean_absolute_error: 0.2508
# Epoch 48/300
# 149/149 [==============================] - 0s 81us/step - loss: 2.0816 - mean_absolute_error: 0.0739 - val_loss: 2.0912 - val_mean_absolute_error: 0.2422
# Epoch 49/300
# 149/149 [==============================] - 0s 87us/step - loss: 1.9768 - mean_absolute_error: 0.0807 - val_loss: 1.9851 - val_mean_absolute_error: 0.2725
# Epoch 50/300
# 149/149 [==============================] - 0s 67us/step - loss: 1.8715 - mean_absolute_error: 0.0694 - val_loss: 1.8888 - val_mean_absolute_error: 0.2724
# Epoch 51/300
# 149/149 [==============================] - 0s 67us/step - loss: 1.7701 - mean_absolute_error: 0.0576 - val_loss: 1.7967 - val_mean_absolute_error: 0.2817
# Epoch 52/300
# 149/149 [==============================] - 0s 81us/step - loss: 1.6776 - mean_absolute_error: 0.0531 - val_loss: 1.7118 - val_mean_absolute_error: 0.2880
# Epoch 53/300
# 149/149 [==============================] - 0s 60us/step - loss: 1.5986 - mean_absolute_error: 0.0646 - val_loss: 1.6310 - val_mean_absolute_error: 0.2805
# Epoch 54/300
# 149/149 [==============================] - ETA: 0s - loss: 1.5574 - mean_absolute_error: 0.060 - 0s 74us/step - loss: 1.5260 - mean_absolute_error: 0.0822 - val_loss: 1.5454 - val_mean_absolute_error: 0.2660
# Epoch 55/300
# 149/149 [==============================] - 0s 67us/step - loss: 1.4476 - mean_absolute_error: 0.0700 - val_loss: 1.4875 - val_mean_absolute_error: 0.2851
# Epoch 56/300
# 149/149 [==============================] - 0s 81us/step - loss: 1.3713 - mean_absolute_error: 0.0489 - val_loss: 1.4125 - val_mean_absolute_error: 0.2884
# Epoch 57/300
# 149/149 [==============================] - 0s 67us/step - loss: 1.3026 - mean_absolute_error: 0.0446 - val_loss: 1.3590 - val_mean_absolute_error: 0.3043
# Epoch 58/300
# 149/149 [==============================] - 0s 67us/step - loss: 1.2359 - mean_absolute_error: 0.0389 - val_loss: 1.2986 - val_mean_absolute_error: 0.3125
# Epoch 59/300
# 149/149 [==============================] - 0s 81us/step - loss: 1.1781 - mean_absolute_error: 0.0567 - val_loss: 1.2606 - val_mean_absolute_error: 0.3440
# Epoch 60/300
# 149/149 [==============================] - 0s 74us/step - loss: 1.1240 - mean_absolute_error: 0.0541 - val_loss: 1.2096 - val_mean_absolute_error: 0.3491
# Epoch 61/300
# 149/149 [==============================] - 0s 60us/step - loss: 1.0710 - mean_absolute_error: 0.0558 - val_loss: 1.1847 - val_mean_absolute_error: 0.3770
# Epoch 62/300
# 149/149 [==============================] - 0s 67us/step - loss: 1.0207 - mean_absolute_error: 0.0515 - val_loss: 1.1114 - val_mean_absolute_error: 0.3504
# Epoch 63/300
# 149/149 [==============================] - 0s 81us/step - loss: 0.9735 - mean_absolute_error: 0.0564 - val_loss: 1.0577 - val_mean_absolute_error: 0.3363
# Epoch 64/300
# 149/149 [==============================] - 0s 74us/step - loss: 0.9252 - mean_absolute_error: 0.0436 - val_loss: 1.0064 - val_mean_absolute_error: 0.3165
# Epoch 65/300
# 149/149 [==============================] - 0s 67us/step - loss: 0.8882 - mean_absolute_error: 0.0546 - val_loss: 0.9798 - val_mean_absolute_error: 0.3430
# Epoch 66/300
# 149/149 [==============================] - 0s 74us/step - loss: 0.8528 - mean_absolute_error: 0.0627 - val_loss: 0.9300 - val_mean_absolute_error: 0.3052
# Epoch 67/300
# 149/149 [==============================] - 0s 81us/step - loss: 0.8222 - mean_absolute_error: 0.0738 - val_loss: 0.9195 - val_mean_absolute_error: 0.3547
# Epoch 68/300
# 149/149 [==============================] - 0s 74us/step - loss: 0.7910 - mean_absolute_error: 0.0835 - val_loss: 0.8537 - val_mean_absolute_error: 0.2991
# Epoch 69/300
# 149/149 [==============================] - 0s 60us/step - loss: 0.7625 - mean_absolute_error: 0.0978 - val_loss: 0.8386 - val_mean_absolute_error: 0.3283
# Epoch 70/300
# 149/149 [==============================] - 0s 67us/step - loss: 0.7187 - mean_absolute_error: 0.0712 - val_loss: 0.7866 - val_mean_absolute_error: 0.3126
# Epoch 71/300
# 149/149 [==============================] - 0s 74us/step - loss: 0.6808 - mean_absolute_error: 0.0587 - val_loss: 0.7480 - val_mean_absolute_error: 0.2923
# Epoch 72/300
# 149/149 [==============================] - 0s 67us/step - loss: 0.6468 - mean_absolute_error: 0.0454 - val_loss: 0.7075 - val_mean_absolute_error: 0.2895
# Epoch 73/300
# 149/149 [==============================] - 0s 67us/step - loss: 0.6140 - mean_absolute_error: 0.0366 - val_loss: 0.6841 - val_mean_absolute_error: 0.2972
# Epoch 74/300
# 149/149 [==============================] - 0s 81us/step - loss: 0.5851 - mean_absolute_error: 0.0294 - val_loss: 0.6398 - val_mean_absolute_error: 0.2686
# Epoch 75/300
# 149/149 [==============================] - 0s 81us/step - loss: 0.5571 - mean_absolute_error: 0.0282 - val_loss: 0.6123 - val_mean_absolute_error: 0.2676
# Epoch 76/300
# 149/149 [==============================] - 0s 74us/step - loss: 0.5308 - mean_absolute_error: 0.0281 - val_loss: 0.5780 - val_mean_absolute_error: 0.2505
# Epoch 77/300
# 149/149 [==============================] - 0s 60us/step - loss: 0.5057 - mean_absolute_error: 0.0273 - val_loss: 0.5528 - val_mean_absolute_error: 0.2489
# Epoch 78/300
# 149/149 [==============================] - 0s 81us/step - loss: 0.4815 - mean_absolute_error: 0.0272 - val_loss: 0.5275 - val_mean_absolute_error: 0.2449
# Epoch 79/300
# 149/149 [==============================] - 0s 81us/step - loss: 0.4583 - mean_absolute_error: 0.0252 - val_loss: 0.5003 - val_mean_absolute_error: 0.2343
# Epoch 80/300
# 149/149 [==============================] - 0s 81us/step - loss: 0.4364 - mean_absolute_error: 0.0244 - val_loss: 0.4731 - val_mean_absolute_error: 0.2236
# Epoch 81/300
# 149/149 [==============================] - 0s 94us/step - loss: 0.4162 - mean_absolute_error: 0.0277 - val_loss: 0.4461 - val_mean_absolute_error: 0.2068
# Epoch 82/300
# 149/149 [==============================] - 0s 94us/step - loss: 0.3972 - mean_absolute_error: 0.0290 - val_loss: 0.4185 - val_mean_absolute_error: 0.1831
# Epoch 83/300
# 149/149 [==============================] - 0s 114us/step - loss: 0.3782 - mean_absolute_error: 0.0263 - val_loss: 0.3932 - val_mean_absolute_error: 0.1599
# Epoch 84/300
# 149/149 [==============================] - 0s 87us/step - loss: 0.3613 - mean_absolute_error: 0.0268 - val_loss: 0.3705 - val_mean_absolute_error: 0.1428
# Epoch 85/300
# 149/149 [==============================] - 0s 81us/step - loss: 0.3442 - mean_absolute_error: 0.0258 - val_loss: 0.3513 - val_mean_absolute_error: 0.1348
# Epoch 86/300
# 149/149 [==============================] - 0s 74us/step - loss: 0.3282 - mean_absolute_error: 0.0278 - val_loss: 0.3322 - val_mean_absolute_error: 0.1118
# Epoch 87/300
# 149/149 [==============================] - 0s 67us/step - loss: 0.3141 - mean_absolute_error: 0.0291 - val_loss: 0.3169 - val_mean_absolute_error: 0.1116
# Epoch 88/300
# 149/149 [==============================] - 0s 67us/step - loss: 0.2991 - mean_absolute_error: 0.0250 - val_loss: 0.2986 - val_mean_absolute_error: 0.0991
# Epoch 89/300
# 149/149 [==============================] - 0s 74us/step - loss: 0.2841 - mean_absolute_error: 0.0243 - val_loss: 0.2844 - val_mean_absolute_error: 0.0947
# Epoch 90/300
# 149/149 [==============================] - 0s 94us/step - loss: 0.2705 - mean_absolute_error: 0.0241 - val_loss: 0.2712 - val_mean_absolute_error: 0.0962
# Epoch 91/300
# 149/149 [==============================] - 0s 74us/step - loss: 0.2576 - mean_absolute_error: 0.0251 - val_loss: 0.2577 - val_mean_absolute_error: 0.0951
# Epoch 92/300
# 149/149 [==============================] - 0s 67us/step - loss: 0.2449 - mean_absolute_error: 0.0236 - val_loss: 0.2467 - val_mean_absolute_error: 0.0967
# Epoch 93/300
# 149/149 [==============================] - 0s 74us/step - loss: 0.2336 - mean_absolute_error: 0.0255 - val_loss: 0.2372 - val_mean_absolute_error: 0.1030
# Epoch 94/300
# 149/149 [==============================] - 0s 94us/step - loss: 0.2232 - mean_absolute_error: 0.0237 - val_loss: 0.2286 - val_mean_absolute_error: 0.1066
# Epoch 95/300
# 149/149 [==============================] - 0s 74us/step - loss: 0.2142 - mean_absolute_error: 0.0248 - val_loss: 0.2198 - val_mean_absolute_error: 0.1040
# Epoch 96/300
# 149/149 [==============================] - 0s 74us/step - loss: 0.2055 - mean_absolute_error: 0.0243 - val_loss: 0.2110 - val_mean_absolute_error: 0.1060
# Epoch 97/300
# 149/149 [==============================] - 0s 81us/step - loss: 0.1969 - mean_absolute_error: 0.0235 - val_loss: 0.2026 - val_mean_absolute_error: 0.1027
# Epoch 98/300
# 149/149 [==============================] - 0s 60us/step - loss: 0.1894 - mean_absolute_error: 0.0235 - val_loss: 0.1934 - val_mean_absolute_error: 0.0942
# Epoch 99/300
# 149/149 [==============================] - 0s 74us/step - loss: 0.1822 - mean_absolute_error: 0.0235 - val_loss: 0.1865 - val_mean_absolute_error: 0.0940
# Epoch 100/300
# 149/149 [==============================] - 0s 74us/step - loss: 0.1753 - mean_absolute_error: 0.0245 - val_loss: 0.1780 - val_mean_absolute_error: 0.0862
# Epoch 101/300
# 149/149 [==============================] - 0s 74us/step - loss: 0.1686 - mean_absolute_error: 0.0227 - val_loss: 0.1710 - val_mean_absolute_error: 0.0825
# Epoch 102/300
# 149/149 [==============================] - 0s 74us/step - loss: 0.1623 - mean_absolute_error: 0.0236 - val_loss: 0.1649 - val_mean_absolute_error: 0.0838
# Epoch 103/300
# 149/149 [==============================] - 0s 74us/step - loss: 0.1560 - mean_absolute_error: 0.0233 - val_loss: 0.1587 - val_mean_absolute_error: 0.0827
# Epoch 104/300
# 149/149 [==============================] - 0s 67us/step - loss: 0.1501 - mean_absolute_error: 0.0229 - val_loss: 0.1520 - val_mean_absolute_error: 0.0749
# Epoch 105/300
# 149/149 [==============================] - 0s 114us/step - loss: 0.1449 - mean_absolute_error: 0.0219 - val_loss: 0.1474 - val_mean_absolute_error: 0.0754
# Epoch 106/300
# 149/149 [==============================] - 0s 67us/step - loss: 0.1398 - mean_absolute_error: 0.0223 - val_loss: 0.1417 - val_mean_absolute_error: 0.0724
# Epoch 107/300
# 149/149 [==============================] - 0s 67us/step - loss: 0.1346 - mean_absolute_error: 0.0225 - val_loss: 0.1354 - val_mean_absolute_error: 0.0651
# Epoch 108/300
# 149/149 [==============================] - 0s 81us/step - loss: 0.1294 - mean_absolute_error: 0.0214 - val_loss: 0.1313 - val_mean_absolute_error: 0.0712
# Epoch 109/300
# 149/149 [==============================] - 0s 81us/step - loss: 0.1250 - mean_absolute_error: 0.0211 - val_loss: 0.1255 - val_mean_absolute_error: 0.0601
# Epoch 110/300
# 149/149 [==============================] - 0s 74us/step - loss: 0.1203 - mean_absolute_error: 0.0204 - val_loss: 0.1205 - val_mean_absolute_error: 0.0576
# Epoch 111/300
# 149/149 [==============================] - 0s 67us/step - loss: 0.1157 - mean_absolute_error: 0.0202 - val_loss: 0.1167 - val_mean_absolute_error: 0.0615
# Epoch 112/300
# 149/149 [==============================] - 0s 74us/step - loss: 0.1116 - mean_absolute_error: 0.0201 - val_loss: 0.1116 - val_mean_absolute_error: 0.0480
# Epoch 113/300
# 149/149 [==============================] - 0s 74us/step - loss: 0.1079 - mean_absolute_error: 0.0206 - val_loss: 0.1076 - val_mean_absolute_error: 0.0475
# Epoch 114/300
# 149/149 [==============================] - 0s 74us/step - loss: 0.1040 - mean_absolute_error: 0.0198 - val_loss: 0.1039 - val_mean_absolute_error: 0.0493
# Epoch 115/300
# 149/149 [==============================] - 0s 60us/step - loss: 0.1001 - mean_absolute_error: 0.0195 - val_loss: 0.0987 - val_mean_absolute_error: 0.0378
# Epoch 116/300
# 149/149 [==============================] - 0s 74us/step - loss: 0.0964 - mean_absolute_error: 0.0195 - val_loss: 0.0956 - val_mean_absolute_error: 0.0390
# Epoch 117/300
# 149/149 [==============================] - 0s 67us/step - loss: 0.0933 - mean_absolute_error: 0.0189 - val_loss: 0.0927 - val_mean_absolute_error: 0.0381
# Epoch 118/300
# 149/149 [==============================] - 0s 67us/step - loss: 0.0902 - mean_absolute_error: 0.0191 - val_loss: 0.0889 - val_mean_absolute_error: 0.0331
# Epoch 119/300
# 149/149 [==============================] - 0s 67us/step - loss: 0.0867 - mean_absolute_error: 0.0184 - val_loss: 0.0858 - val_mean_absolute_error: 0.0342
# Epoch 120/300
# 149/149 [==============================] - 0s 67us/step - loss: 0.0835 - mean_absolute_error: 0.0193 - val_loss: 0.0822 - val_mean_absolute_error: 0.0333
# Epoch 121/300
# 149/149 [==============================] - 0s 74us/step - loss: 0.0804 - mean_absolute_error: 0.0186 - val_loss: 0.0786 - val_mean_absolute_error: 0.0274
# Epoch 122/300
# 149/149 [==============================] - 0s 74us/step - loss: 0.0772 - mean_absolute_error: 0.0186 - val_loss: 0.0758 - val_mean_absolute_error: 0.0304
# Epoch 123/300
# 149/149 [==============================] - 0s 74us/step - loss: 0.0742 - mean_absolute_error: 0.0194 - val_loss: 0.0731 - val_mean_absolute_error: 0.0303
# Epoch 124/300
# 149/149 [==============================] - 0s 74us/step - loss: 0.0715 - mean_absolute_error: 0.0190 - val_loss: 0.0701 - val_mean_absolute_error: 0.0223
# Epoch 125/300
# 149/149 [==============================] - 0s 74us/step - loss: 0.0690 - mean_absolute_error: 0.0192 - val_loss: 0.0679 - val_mean_absolute_error: 0.0272
# Epoch 126/300
# 149/149 [==============================] - 0s 67us/step - loss: 0.0665 - mean_absolute_error: 0.0191 - val_loss: 0.0648 - val_mean_absolute_error: 0.0226
# Epoch 127/300
# 149/149 [==============================] - 0s 67us/step - loss: 0.0638 - mean_absolute_error: 0.0189 - val_loss: 0.0622 - val_mean_absolute_error: 0.0207
# Epoch 128/300
# 149/149 [==============================] - 0s 81us/step - loss: 0.0616 - mean_absolute_error: 0.0183 - val_loss: 0.0600 - val_mean_absolute_error: 0.0193
# Epoch 129/300
# 149/149 [==============================] - 0s 67us/step - loss: 0.0596 - mean_absolute_error: 0.0186 - val_loss: 0.0579 - val_mean_absolute_error: 0.0196
# Epoch 130/300
# 149/149 [==============================] - 0s 67us/step - loss: 0.0571 - mean_absolute_error: 0.0194 - val_loss: 0.0554 - val_mean_absolute_error: 0.0190
# Epoch 131/300
# 149/149 [==============================] - 0s 67us/step - loss: 0.0551 - mean_absolute_error: 0.0183 - val_loss: 0.0537 - val_mean_absolute_error: 0.0177
# Epoch 132/300
# 149/149 [==============================] - 0s 74us/step - loss: 0.0532 - mean_absolute_error: 0.0187 - val_loss: 0.0518 - val_mean_absolute_error: 0.0188
# Epoch 133/300
# 149/149 [==============================] - 0s 67us/step - loss: 0.0514 - mean_absolute_error: 0.0188 - val_loss: 0.0500 - val_mean_absolute_error: 0.0176
# Epoch 134/300
# 149/149 [==============================] - 0s 67us/step - loss: 0.0497 - mean_absolute_error: 0.0185 - val_loss: 0.0485 - val_mean_absolute_error: 0.0173
# Epoch 135/300
# 149/149 [==============================] - 0s 67us/step - loss: 0.0481 - mean_absolute_error: 0.0186 - val_loss: 0.0471 - val_mean_absolute_error: 0.0178
# Epoch 136/300
# 149/149 [==============================] - 0s 74us/step - loss: 0.0469 - mean_absolute_error: 0.0195 - val_loss: 0.0460 - val_mean_absolute_error: 0.0181
# Epoch 137/300
# 149/149 [==============================] - 0s 67us/step - loss: 0.0456 - mean_absolute_error: 0.0196 - val_loss: 0.0445 - val_mean_absolute_error: 0.0174
# Epoch 138/300
# 149/149 [==============================] - 0s 74us/step - loss: 0.0444 - mean_absolute_error: 0.0187 - val_loss: 0.0432 - val_mean_absolute_error: 0.0162
# Epoch 139/300
# 149/149 [==============================] - 0s 74us/step - loss: 0.0431 - mean_absolute_error: 0.0185 - val_loss: 0.0420 - val_mean_absolute_error: 0.0168
# Epoch 140/300
# 149/149 [==============================] - 0s 74us/step - loss: 0.0420 - mean_absolute_error: 0.0194 - val_loss: 0.0411 - val_mean_absolute_error: 0.0180
# Epoch 141/300
# 149/149 [==============================] - 0s 74us/step - loss: 0.0410 - mean_absolute_error: 0.0191 - val_loss: 0.0400 - val_mean_absolute_error: 0.0158
# Epoch 142/300
# 149/149 [==============================] - 0s 74us/step - loss: 0.0400 - mean_absolute_error: 0.0184 - val_loss: 0.0393 - val_mean_absolute_error: 0.0173
# Epoch 143/300
# 149/149 [==============================] - 0s 74us/step - loss: 0.0390 - mean_absolute_error: 0.0198 - val_loss: 0.0382 - val_mean_absolute_error: 0.0179
# Epoch 144/300
# 149/149 [==============================] - 0s 74us/step - loss: 0.0379 - mean_absolute_error: 0.0190 - val_loss: 0.0368 - val_mean_absolute_error: 0.0159
# Epoch 145/300
# 149/149 [==============================] - 0s 67us/step - loss: 0.0370 - mean_absolute_error: 0.0184 - val_loss: 0.0360 - val_mean_absolute_error: 0.0166
# Epoch 146/300
# 149/149 [==============================] - 0s 81us/step - loss: 0.0361 - mean_absolute_error: 0.0197 - val_loss: 0.0346 - val_mean_absolute_error: 0.0179
# Epoch 147/300
# 149/149 [==============================] - 0s 74us/step - loss: 0.0348 - mean_absolute_error: 0.0192 - val_loss: 0.0336 - val_mean_absolute_error: 0.0155
# Epoch 148/300
# 149/149 [==============================] - 0s 67us/step - loss: 0.0336 - mean_absolute_error: 0.0189 - val_loss: 0.0331 - val_mean_absolute_error: 0.0175
# Epoch 149/300
# 149/149 [==============================] - 0s 74us/step - loss: 0.0329 - mean_absolute_error: 0.0192 - val_loss: 0.0320 - val_mean_absolute_error: 0.0159
# Epoch 150/300
# 149/149 [==============================] - 0s 67us/step - loss: 0.0322 - mean_absolute_error: 0.0185 - val_loss: 0.0316 - val_mean_absolute_error: 0.0166
# Epoch 151/300
# 149/149 [==============================] - 0s 74us/step - loss: 0.0314 - mean_absolute_error: 0.0194 - val_loss: 0.0307 - val_mean_absolute_error: 0.0167
# Epoch 152/300
# 149/149 [==============================] - ETA: 0s - loss: 0.0310 - mean_absolute_error: 0.016 - 0s 81us/step - loss: 0.0307 - mean_absolute_error: 0.0189 - val_loss: 0.0302 - val_mean_absolute_error: 0.0158
# Epoch 153/300
# 149/149 [==============================] - 0s 67us/step - loss: 0.0304 - mean_absolute_error: 0.0187 - val_loss: 0.0297 - val_mean_absolute_error: 0.0161
# Epoch 154/300
# 149/149 [==============================] - 0s 74us/step - loss: 0.0297 - mean_absolute_error: 0.0187 - val_loss: 0.0294 - val_mean_absolute_error: 0.0163
# Epoch 155/300
# 149/149 [==============================] - 0s 67us/step - loss: 0.0294 - mean_absolute_error: 0.0196 - val_loss: 0.0288 - val_mean_absolute_error: 0.0171
# Epoch 156/300
# 149/149 [==============================] - 0s 74us/step - loss: 0.0288 - mean_absolute_error: 0.0191 - val_loss: 0.0281 - val_mean_absolute_error: 0.0161
# Epoch 157/300
# 149/149 [==============================] - 0s 87us/step - loss: 0.0285 - mean_absolute_error: 0.0186 - val_loss: 0.0277 - val_mean_absolute_error: 0.0163
# Epoch 158/300
# 149/149 [==============================] - 0s 67us/step - loss: 0.0280 - mean_absolute_error: 0.0188 - val_loss: 0.0268 - val_mean_absolute_error: 0.0166
# Epoch 159/300
# 149/149 [==============================] - 0s 74us/step - loss: 0.0271 - mean_absolute_error: 0.0188 - val_loss: 0.0268 - val_mean_absolute_error: 0.0168
# Epoch 160/300
# 149/149 [==============================] - 0s 74us/step - loss: 0.0269 - mean_absolute_error: 0.0190 - val_loss: 0.0263 - val_mean_absolute_error: 0.0165
# Epoch 161/300
# 149/149 [==============================] - 0s 74us/step - loss: 0.0265 - mean_absolute_error: 0.0192 - val_loss: 0.0261 - val_mean_absolute_error: 0.0172
# Epoch 162/300
# 149/149 [==============================] - 0s 67us/step - loss: 0.0262 - mean_absolute_error: 0.0190 - val_loss: 0.0256 - val_mean_absolute_error: 0.0159
# Epoch 163/300
# 149/149 [==============================] - 0s 81us/step - loss: 0.0258 - mean_absolute_error: 0.0187 - val_loss: 0.0250 - val_mean_absolute_error: 0.0162
# Epoch 164/300
# 149/149 [==============================] - 0s 81us/step - loss: 0.0254 - mean_absolute_error: 0.0189 - val_loss: 0.0247 - val_mean_absolute_error: 0.0170
# Epoch 165/300
# 149/149 [==============================] - 0s 74us/step - loss: 0.0252 - mean_absolute_error: 0.0187 - val_loss: 0.0244 - val_mean_absolute_error: 0.0164
# Epoch 166/300
# 149/149 [==============================] - 0s 67us/step - loss: 0.0247 - mean_absolute_error: 0.0186 - val_loss: 0.0246 - val_mean_absolute_error: 0.0168
# Epoch 167/300
# 149/149 [==============================] - 0s 74us/step - loss: 0.0247 - mean_absolute_error: 0.0200 - val_loss: 0.0246 - val_mean_absolute_error: 0.0184
# Epoch 168/300
# 149/149 [==============================] - 0s 74us/step - loss: 0.0245 - mean_absolute_error: 0.0193 - val_loss: 0.0238 - val_mean_absolute_error: 0.0158
# Epoch 169/300
# 149/149 [==============================] - 0s 81us/step - loss: 0.0240 - mean_absolute_error: 0.0184 - val_loss: 0.0238 - val_mean_absolute_error: 0.0171
# Epoch 170/300
# 149/149 [==============================] - 0s 67us/step - loss: 0.0238 - mean_absolute_error: 0.0199 - val_loss: 0.0235 - val_mean_absolute_error: 0.0179
# Epoch 171/300
# 149/149 [==============================] - 0s 74us/step - loss: 0.0236 - mean_absolute_error: 0.0188 - val_loss: 0.0231 - val_mean_absolute_error: 0.0157
# Epoch 172/300
# 149/149 [==============================] - 0s 67us/step - loss: 0.0233 - mean_absolute_error: 0.0185 - val_loss: 0.0228 - val_mean_absolute_error: 0.0174
# Epoch 173/300
# 149/149 [==============================] - 0s 67us/step - loss: 0.0230 - mean_absolute_error: 0.0198 - val_loss: 0.0226 - val_mean_absolute_error: 0.0176
# Epoch 174/300
# 149/149 [==============================] - 0s 74us/step - loss: 0.0230 - mean_absolute_error: 0.0189 - val_loss: 0.0224 - val_mean_absolute_error: 0.0159
# Epoch 175/300
# 149/149 [==============================] - 0s 74us/step - loss: 0.0226 - mean_absolute_error: 0.0186 - val_loss: 0.0221 - val_mean_absolute_error: 0.0168
# Epoch 176/300
# 149/149 [==============================] - 0s 67us/step - loss: 0.0223 - mean_absolute_error: 0.0194 - val_loss: 0.0218 - val_mean_absolute_error: 0.0177
# Epoch 177/300
# 149/149 [==============================] - 0s 81us/step - loss: 0.0221 - mean_absolute_error: 0.0189 - val_loss: 0.0216 - val_mean_absolute_error: 0.0164
# Epoch 178/300
# 149/149 [==============================] - 0s 67us/step - loss: 0.0217 - mean_absolute_error: 0.0185 - val_loss: 0.0215 - val_mean_absolute_error: 0.0169
# Epoch 179/300
# 149/149 [==============================] - 0s 74us/step - loss: 0.0217 - mean_absolute_error: 0.0195 - val_loss: 0.0215 - val_mean_absolute_error: 0.0178
# Epoch 180/300
# 149/149 [==============================] - 0s 67us/step - loss: 0.0215 - mean_absolute_error: 0.0190 - val_loss: 0.0211 - val_mean_absolute_error: 0.0165
# Epoch 181/300
# 149/149 [==============================] - 0s 74us/step - loss: 0.0215 - mean_absolute_error: 0.0185 - val_loss: 0.0209 - val_mean_absolute_error: 0.0169
# Epoch 182/300
# 149/149 [==============================] - 0s 74us/step - loss: 0.0213 - mean_absolute_error: 0.0194 - val_loss: 0.0206 - val_mean_absolute_error: 0.0177
# Epoch 183/300
# 149/149 [==============================] - 0s 74us/step - loss: 0.0207 - mean_absolute_error: 0.0196 - val_loss: 0.0203 - val_mean_absolute_error: 0.0167
# Epoch 184/300
# 149/149 [==============================] - 0s 67us/step - loss: 0.0206 - mean_absolute_error: 0.0185 - val_loss: 0.0202 - val_mean_absolute_error: 0.0165
# Epoch 185/300
# 149/149 [==============================] - 0s 81us/step - loss: 0.0207 - mean_absolute_error: 0.0190 - val_loss: 0.0206 - val_mean_absolute_error: 0.0176
# Epoch 186/300
# 149/149 [==============================] - 0s 74us/step - loss: 0.0207 - mean_absolute_error: 0.0190 - val_loss: 0.0202 - val_mean_absolute_error: 0.0167
# Epoch 187/300
# 149/149 [==============================] - 0s 74us/step - loss: 0.0204 - mean_absolute_error: 0.0186 - val_loss: 0.0195 - val_mean_absolute_error: 0.0169
# Epoch 188/300
# 149/149 [==============================] - 0s 67us/step - loss: 0.0200 - mean_absolute_error: 0.0192 - val_loss: 0.0196 - val_mean_absolute_error: 0.0173
# Epoch 189/300
# 149/149 [==============================] - 0s 74us/step - loss: 0.0200 - mean_absolute_error: 0.0186 - val_loss: 0.0193 - val_mean_absolute_error: 0.0164
# Epoch 190/300
# 149/149 [==============================] - 0s 74us/step - loss: 0.0197 - mean_absolute_error: 0.0187 - val_loss: 0.0195 - val_mean_absolute_error: 0.0179
# Epoch 191/300
# 149/149 [==============================] - 0s 67us/step - loss: 0.0197 - mean_absolute_error: 0.0194 - val_loss: 0.0193 - val_mean_absolute_error: 0.0173
# Epoch 192/300
# 149/149 [==============================] - 0s 74us/step - loss: 0.0195 - mean_absolute_error: 0.0188 - val_loss: 0.0189 - val_mean_absolute_error: 0.0167
# Epoch 193/300
# 149/149 [==============================] - 0s 67us/step - loss: 0.0194 - mean_absolute_error: 0.0188 - val_loss: 0.0192 - val_mean_absolute_error: 0.0178
# Epoch 194/300
# 149/149 [==============================] - 0s 74us/step - loss: 0.0193 - mean_absolute_error: 0.0194 - val_loss: 0.0183 - val_mean_absolute_error: 0.0168
# Epoch 195/300
# 149/149 [==============================] - 0s 74us/step - loss: 0.0186 - mean_absolute_error: 0.0187 - val_loss: 0.0184 - val_mean_absolute_error: 0.0175
# Epoch 196/300
# 149/149 [==============================] - 0s 74us/step - loss: 0.0188 - mean_absolute_error: 0.0199 - val_loss: 0.0187 - val_mean_absolute_error: 0.0174
# Epoch 197/300
# 149/149 [==============================] - 0s 67us/step - loss: 0.0189 - mean_absolute_error: 0.0188 - val_loss: 0.0186 - val_mean_absolute_error: 0.0158
# Epoch 198/300
# 149/149 [==============================] - 0s 67us/step - loss: 0.0189 - mean_absolute_error: 0.0189 - val_loss: 0.0188 - val_mean_absolute_error: 0.0184
# Epoch 199/300
# 149/149 [==============================] - 0s 74us/step - loss: 0.0190 - mean_absolute_error: 0.0196 - val_loss: 0.0185 - val_mean_absolute_error: 0.0169
# Epoch 200/300
# 149/149 [==============================] - 0s 74us/step - loss: 0.0189 - mean_absolute_error: 0.0186 - val_loss: 0.0183 - val_mean_absolute_error: 0.0165
# Epoch 201/300
# 149/149 [==============================] - 0s 74us/step - loss: 0.0189 - mean_absolute_error: 0.0189 - val_loss: 0.0185 - val_mean_absolute_error: 0.0181
# Epoch 202/300
# 149/149 [==============================] - 0s 94us/step - loss: 0.0187 - mean_absolute_error: 0.0194 - val_loss: 0.0184 - val_mean_absolute_error: 0.0167
# Epoch 203/300
# 149/149 [==============================] - 0s 67us/step - loss: 0.0189 - mean_absolute_error: 0.0185 - val_loss: 0.0185 - val_mean_absolute_error: 0.0166
# Epoch 204/300
# 149/149 [==============================] - 0s 67us/step - loss: 0.0188 - mean_absolute_error: 0.0201 - val_loss: 0.0187 - val_mean_absolute_error: 0.0182
# Epoch 205/300
# 149/149 [==============================] - 0s 67us/step - loss: 0.0190 - mean_absolute_error: 0.0189 - val_loss: 0.0187 - val_mean_absolute_error: 0.0158
# Epoch 206/300
# 149/149 [==============================] - 0s 67us/step - loss: 0.0190 - mean_absolute_error: 0.0183 - val_loss: 0.0185 - val_mean_absolute_error: 0.0176
# Epoch 207/300
# 149/149 [==============================] - 0s 67us/step - loss: 0.0188 - mean_absolute_error: 0.0200 - val_loss: 0.0189 - val_mean_absolute_error: 0.0179
# Epoch 208/300
# 149/149 [==============================] - 0s 74us/step - loss: 0.0189 - mean_absolute_error: 0.0188 - val_loss: 0.0186 - val_mean_absolute_error: 0.0163
# Epoch 209/300
# 149/149 [==============================] - 0s 74us/step - loss: 0.0189 - mean_absolute_error: 0.0185 - val_loss: 0.0187 - val_mean_absolute_error: 0.0176
# Epoch 210/300
# 149/149 [==============================] - 0s 67us/step - loss: 0.0190 - mean_absolute_error: 0.0199 - val_loss: 0.0188 - val_mean_absolute_error: 0.0183
# Epoch 211/300
# 149/149 [==============================] - 0s 74us/step - loss: 0.0190 - mean_absolute_error: 0.0189 - val_loss: 0.0183 - val_mean_absolute_error: 0.0158
# Epoch 212/300
# 149/149 [==============================] - 0s 74us/step - loss: 0.0188 - mean_absolute_error: 0.0184 - val_loss: 0.0183 - val_mean_absolute_error: 0.0177
# Epoch 213/300
# 149/149 [==============================] - 0s 67us/step - loss: 0.0189 - mean_absolute_error: 0.0198 - val_loss: 0.0185 - val_mean_absolute_error: 0.0177
# Epoch 214/300
# 149/149 [==============================] - 0s 74us/step - loss: 0.0189 - mean_absolute_error: 0.0190 - val_loss: 0.0188 - val_mean_absolute_error: 0.0160
# Epoch 215/300
# 149/149 [==============================] - 0s 67us/step - loss: 0.0191 - mean_absolute_error: 0.0194 - val_loss: 0.0190 - val_mean_absolute_error: 0.0182
# Epoch 216/300
# 149/149 [==============================] - 0s 74us/step - loss: 0.0191 - mean_absolute_error: 0.0192 - val_loss: 0.0186 - val_mean_absolute_error: 0.0165
# Epoch 217/300
# 149/149 [==============================] - 0s 74us/step - loss: 0.0190 - mean_absolute_error: 0.0187 - val_loss: 0.0188 - val_mean_absolute_error: 0.0178
# Epoch 218/300
# 149/149 [==============================] - 0s 81us/step - loss: 0.0190 - mean_absolute_error: 0.0194 - val_loss: 0.0186 - val_mean_absolute_error: 0.0172
# Epoch 219/300
# 149/149 [==============================] - 0s 67us/step - loss: 0.0190 - mean_absolute_error: 0.0190 - val_loss: 0.0184 - val_mean_absolute_error: 0.0170
# Epoch 220/300
# 149/149 [==============================] - 0s 74us/step - loss: 0.0189 - mean_absolute_error: 0.0186 - val_loss: 0.0186 - val_mean_absolute_error: 0.0171
# Epoch 221/300
# 149/149 [==============================] - 0s 74us/step - loss: 0.0190 - mean_absolute_error: 0.0189 - val_loss: 0.0189 - val_mean_absolute_error: 0.0177
# Epoch 222/300
# 149/149 [==============================] - 0s 67us/step - loss: 0.0192 - mean_absolute_error: 0.0191 - val_loss: 0.0190 - val_mean_absolute_error: 0.0171
# Epoch 223/300
# 149/149 [==============================] - 0s 74us/step - loss: 0.0191 - mean_absolute_error: 0.0188 - val_loss: 0.0187 - val_mean_absolute_error: 0.0168
# Epoch 224/300
# 149/149 [==============================] - 0s 74us/step - loss: 0.0190 - mean_absolute_error: 0.0188 - val_loss: 0.0186 - val_mean_absolute_error: 0.0168
# Epoch 225/300
# 149/149 [==============================] - 0s 67us/step - loss: 0.0191 - mean_absolute_error: 0.0187 - val_loss: 0.0188 - val_mean_absolute_error: 0.0172
# Epoch 226/300
# 149/149 [==============================] - 0s 74us/step - loss: 0.0189 - mean_absolute_error: 0.0202 - val_loss: 0.0187 - val_mean_absolute_error: 0.0180
# Epoch 227/300
# 149/149 [==============================] - 0s 67us/step - loss: 0.0190 - mean_absolute_error: 0.0188 - val_loss: 0.0189 - val_mean_absolute_error: 0.0158
# Epoch 228/300
# 149/149 [==============================] - 0s 67us/step - loss: 0.0191 - mean_absolute_error: 0.0185 - val_loss: 0.0187 - val_mean_absolute_error: 0.0180
# Epoch 229/300
# 149/149 [==============================] - 0s 74us/step - loss: 0.0192 - mean_absolute_error: 0.0204 - val_loss: 0.0186 - val_mean_absolute_error: 0.0178
# Epoch 230/300
# 149/149 [==============================] - 0s 74us/step - loss: 0.0192 - mean_absolute_error: 0.0185 - val_loss: 0.0182 - val_mean_absolute_error: 0.0159
# Epoch 231/300
# 149/149 [==============================] - 0s 67us/step - loss: 0.0188 - mean_absolute_error: 0.0186 - val_loss: 0.0186 - val_mean_absolute_error: 0.0174
# Epoch 232/300
# 149/149 [==============================] - 0s 67us/step - loss: 0.0190 - mean_absolute_error: 0.0193 - val_loss: 0.0191 - val_mean_absolute_error: 0.0180
# Epoch 233/300
# 149/149 [==============================] - 0s 74us/step - loss: 0.0192 - mean_absolute_error: 0.0190 - val_loss: 0.0189 - val_mean_absolute_error: 0.0164
# Epoch 234/300
# 149/149 [==============================] - 0s 67us/step - loss: 0.0193 - mean_absolute_error: 0.0188 - val_loss: 0.0190 - val_mean_absolute_error: 0.0179
# Epoch 235/300
# 149/149 [==============================] - ETA: 0s - loss: 0.0190 - mean_absolute_error: 0.015 - 0s 67us/step - loss: 0.0193 - mean_absolute_error: 0.0194 - val_loss: 0.0187 - val_mean_absolute_error: 0.0171
# Epoch 236/300
# 149/149 [==============================] - 0s 67us/step - loss: 0.0190 - mean_absolute_error: 0.0186 - val_loss: 0.0186 - val_mean_absolute_error: 0.0172
# Epoch 237/300
# 149/149 [==============================] - 0s 74us/step - loss: 0.0191 - mean_absolute_error: 0.0191 - val_loss: 0.0186 - val_mean_absolute_error: 0.0183
# Epoch 238/300
# 149/149 [==============================] - 0s 74us/step - loss: 0.0190 - mean_absolute_error: 0.0194 - val_loss: 0.0190 - val_mean_absolute_error: 0.0167
# Epoch 239/300
# 149/149 [==============================] - 0s 67us/step - loss: 0.0192 - mean_absolute_error: 0.0193 - val_loss: 0.0189 - val_mean_absolute_error: 0.0178
# Epoch 240/300
# 149/149 [==============================] - 0s 74us/step - loss: 0.0190 - mean_absolute_error: 0.0190 - val_loss: 0.0188 - val_mean_absolute_error: 0.0165
# Epoch 241/300
# 149/149 [==============================] - 0s 87us/step - loss: 0.0193 - mean_absolute_error: 0.0186 - val_loss: 0.0189 - val_mean_absolute_error: 0.0168
# Epoch 242/300
# 149/149 [==============================] - 0s 74us/step - loss: 0.0192 - mean_absolute_error: 0.0193 - val_loss: 0.0187 - val_mean_absolute_error: 0.0177
# Epoch 243/300
# 149/149 [==============================] - 0s 67us/step - loss: 0.0191 - mean_absolute_error: 0.0189 - val_loss: 0.0188 - val_mean_absolute_error: 0.0162
# Epoch 244/300
# 149/149 [==============================] - 0s 81us/step - loss: 0.0191 - mean_absolute_error: 0.0186 - val_loss: 0.0190 - val_mean_absolute_error: 0.0179
# Epoch 245/300
# 149/149 [==============================] - 0s 74us/step - loss: 0.0191 - mean_absolute_error: 0.0197 - val_loss: 0.0188 - val_mean_absolute_error: 0.0179
# Epoch 246/300
# 149/149 [==============================] - 0s 74us/step - loss: 0.0193 - mean_absolute_error: 0.0195 - val_loss: 0.0190 - val_mean_absolute_error: 0.0174
# Epoch 247/300
# 149/149 [==============================] - 0s 67us/step - loss: 0.0193 - mean_absolute_error: 0.0189 - val_loss: 0.0188 - val_mean_absolute_error: 0.0168
# Epoch 248/300
# 149/149 [==============================] - 0s 81us/step - loss: 0.0191 - mean_absolute_error: 0.0185 - val_loss: 0.0186 - val_mean_absolute_error: 0.0172
# Epoch 249/300
# 149/149 [==============================] - 0s 60us/step - loss: 0.0191 - mean_absolute_error: 0.0193 - val_loss: 0.0190 - val_mean_absolute_error: 0.0176
# Epoch 250/300
# 149/149 [==============================] - 0s 67us/step - loss: 0.0191 - mean_absolute_error: 0.0189 - val_loss: 0.0192 - val_mean_absolute_error: 0.0168
# Epoch 251/300
# 149/149 [==============================] - 0s 67us/step - loss: 0.0193 - mean_absolute_error: 0.0186 - val_loss: 0.0192 - val_mean_absolute_error: 0.0171
# Epoch 252/300
# 149/149 [==============================] - 0s 74us/step - loss: 0.0192 - mean_absolute_error: 0.0196 - val_loss: 0.0189 - val_mean_absolute_error: 0.0180
# Epoch 253/300
# 149/149 [==============================] - 0s 74us/step - loss: 0.0192 - mean_absolute_error: 0.0189 - val_loss: 0.0191 - val_mean_absolute_error: 0.0160
# Epoch 254/300
# 149/149 [==============================] - 0s 67us/step - loss: 0.0193 - mean_absolute_error: 0.0186 - val_loss: 0.0185 - val_mean_absolute_error: 0.0166
# Epoch 255/300
# 149/149 [==============================] - 0s 60us/step - loss: 0.0191 - mean_absolute_error: 0.0190 - val_loss: 0.0188 - val_mean_absolute_error: 0.0182
# Epoch 256/300
# 149/149 [==============================] - 0s 74us/step - loss: 0.0191 - mean_absolute_error: 0.0199 - val_loss: 0.0188 - val_mean_absolute_error: 0.0171
# Epoch 257/300
# 149/149 [==============================] - 0s 67us/step - loss: 0.0192 - mean_absolute_error: 0.0185 - val_loss: 0.0190 - val_mean_absolute_error: 0.0161
# Epoch 258/300
# 149/149 [==============================] - 0s 74us/step - loss: 0.0195 - mean_absolute_error: 0.0195 - val_loss: 0.0192 - val_mean_absolute_error: 0.0179
# Epoch 259/300
# 149/149 [==============================] - 0s 74us/step - loss: 0.0193 - mean_absolute_error: 0.0188 - val_loss: 0.0184 - val_mean_absolute_error: 0.0167
# Epoch 260/300
# 149/149 [==============================] - 0s 67us/step - loss: 0.0189 - mean_absolute_error: 0.0187 - val_loss: 0.0188 - val_mean_absolute_error: 0.0179
# Epoch 261/300
# 149/149 [==============================] - 0s 67us/step - loss: 0.0193 - mean_absolute_error: 0.0193 - val_loss: 0.0189 - val_mean_absolute_error: 0.0165
# Epoch 262/300
# 149/149 [==============================] - 0s 67us/step - loss: 0.0193 - mean_absolute_error: 0.0186 - val_loss: 0.0190 - val_mean_absolute_error: 0.0173
# Epoch 263/300
# 149/149 [==============================] - 0s 74us/step - loss: 0.0192 - mean_absolute_error: 0.0189 - val_loss: 0.0195 - val_mean_absolute_error: 0.0179
# Epoch 264/300
# 149/149 [==============================] - 0s 74us/step - loss: 0.0193 - mean_absolute_error: 0.0193 - val_loss: 0.0188 - val_mean_absolute_error: 0.0171
# Epoch 265/300
# 149/149 [==============================] - 0s 67us/step - loss: 0.0193 - mean_absolute_error: 0.0191 - val_loss: 0.0190 - val_mean_absolute_error: 0.0172
# Epoch 266/300
# 149/149 [==============================] - 0s 74us/step - loss: 0.0194 - mean_absolute_error: 0.0191 - val_loss: 0.0190 - val_mean_absolute_error: 0.0171
# Epoch 267/300
# 149/149 [==============================] - 0s 74us/step - loss: 0.0192 - mean_absolute_error: 0.0187 - val_loss: 0.0188 - val_mean_absolute_error: 0.0170
# Epoch 268/300
# 149/149 [==============================] - 0s 67us/step - loss: 0.0192 - mean_absolute_error: 0.0198 - val_loss: 0.0191 - val_mean_absolute_error: 0.0186
# Epoch 269/300
# 149/149 [==============================] - 0s 67us/step - loss: 0.0195 - mean_absolute_error: 0.0195 - val_loss: 0.0191 - val_mean_absolute_error: 0.0165
# Epoch 270/300
# 149/149 [==============================] - 0s 60us/step - loss: 0.0195 - mean_absolute_error: 0.0188 - val_loss: 0.0189 - val_mean_absolute_error: 0.0174
# Epoch 271/300
# 149/149 [==============================] - 0s 74us/step - loss: 0.0192 - mean_absolute_error: 0.0190 - val_loss: 0.0188 - val_mean_absolute_error: 0.0171
# Epoch 272/300
# 149/149 [==============================] - 0s 67us/step - loss: 0.0193 - mean_absolute_error: 0.0194 - val_loss: 0.0187 - val_mean_absolute_error: 0.0178
# Epoch 273/300
# 149/149 [==============================] - 0s 74us/step - loss: 0.0194 - mean_absolute_error: 0.0190 - val_loss: 0.0191 - val_mean_absolute_error: 0.0162
# Epoch 274/300
# 149/149 [==============================] - 0s 74us/step - loss: 0.0193 - mean_absolute_error: 0.0184 - val_loss: 0.0192 - val_mean_absolute_error: 0.0180
# Epoch 275/300
# 149/149 [==============================] - 0s 81us/step - loss: 0.0194 - mean_absolute_error: 0.0200 - val_loss: 0.0192 - val_mean_absolute_error: 0.0183
# Epoch 276/300
# 149/149 [==============================] - 0s 67us/step - loss: 0.0193 - mean_absolute_error: 0.0191 - val_loss: 0.0192 - val_mean_absolute_error: 0.0167
# Epoch 277/300
# 149/149 [==============================] - 0s 67us/step - loss: 0.0195 - mean_absolute_error: 0.0185 - val_loss: 0.0191 - val_mean_absolute_error: 0.0175
# Epoch 278/300
# 149/149 [==============================] - 0s 74us/step - loss: 0.0195 - mean_absolute_error: 0.0202 - val_loss: 0.0190 - val_mean_absolute_error: 0.0182
# Epoch 279/300
# 149/149 [==============================] - 0s 67us/step - loss: 0.0192 - mean_absolute_error: 0.0192 - val_loss: 0.0190 - val_mean_absolute_error: 0.0159
# Epoch 280/300
# 149/149 [==============================] - 0s 67us/step - loss: 0.0193 - mean_absolute_error: 0.0188 - val_loss: 0.0192 - val_mean_absolute_error: 0.0178
# Epoch 281/300
# 149/149 [==============================] - 0s 67us/step - loss: 0.0195 - mean_absolute_error: 0.0194 - val_loss: 0.0194 - val_mean_absolute_error: 0.0172
# Epoch 282/300
# 149/149 [==============================] - 0s 67us/step - loss: 0.0195 - mean_absolute_error: 0.0189 - val_loss: 0.0192 - val_mean_absolute_error: 0.0173
# Epoch 283/300
# 149/149 [==============================] - 0s 87us/step - loss: 0.0195 - mean_absolute_error: 0.0192 - val_loss: 0.0189 - val_mean_absolute_error: 0.0172
# Epoch 284/300
# 149/149 [==============================] - 0s 81us/step - loss: 0.0192 - mean_absolute_error: 0.0190 - val_loss: 0.0188 - val_mean_absolute_error: 0.0165
# Epoch 285/300
# 149/149 [==============================] - 0s 67us/step - loss: 0.0194 - mean_absolute_error: 0.0193 - val_loss: 0.0192 - val_mean_absolute_error: 0.0186
# Epoch 286/300
# 149/149 [==============================] - 0s 67us/step - loss: 0.0196 - mean_absolute_error: 0.0193 - val_loss: 0.0193 - val_mean_absolute_error: 0.0163
# Epoch 287/300
# 149/149 [==============================] - 0s 67us/step - loss: 0.0196 - mean_absolute_error: 0.0186 - val_loss: 0.0192 - val_mean_absolute_error: 0.0169
# Epoch 288/300
# 149/149 [==============================] - 0s 60us/step - loss: 0.0193 - mean_absolute_error: 0.0191 - val_loss: 0.0188 - val_mean_absolute_error: 0.0177
# Epoch 289/300
# 149/149 [==============================] - 0s 67us/step - loss: 0.0194 - mean_absolute_error: 0.0192 - val_loss: 0.0191 - val_mean_absolute_error: 0.0172
# Epoch 290/300
# 149/149 [==============================] - 0s 67us/step - loss: 0.0194 - mean_absolute_error: 0.0185 - val_loss: 0.0187 - val_mean_absolute_error: 0.0163
# Epoch 291/300
# 149/149 [==============================] - 0s 74us/step - loss: 0.0193 - mean_absolute_error: 0.0191 - val_loss: 0.0190 - val_mean_absolute_error: 0.0177
# Epoch 292/300
# 149/149 [==============================] - 0s 74us/step - loss: 0.0193 - mean_absolute_error: 0.0189 - val_loss: 0.0194 - val_mean_absolute_error: 0.0168
# Epoch 293/300
# 149/149 [==============================] - 0s 67us/step - loss: 0.0196 - mean_absolute_error: 0.0189 - val_loss: 0.0194 - val_mean_absolute_error: 0.0178
# Epoch 294/300
# 149/149 [==============================] - 0s 81us/step - loss: 0.0199 - mean_absolute_error: 0.0191 - val_loss: 0.0193 - val_mean_absolute_error: 0.0170
# Epoch 295/300
# 149/149 [==============================] - 0s 87us/step - loss: 0.0195 - mean_absolute_error: 0.0195 - val_loss: 0.0190 - val_mean_absolute_error: 0.0179
# Epoch 296/300
# 149/149 [==============================] - 0s 74us/step - loss: 0.0192 - mean_absolute_error: 0.0191 - val_loss: 0.0188 - val_mean_absolute_error: 0.0167
# Epoch 297/300
# 149/149 [==============================] - 0s 67us/step - loss: 0.0195 - mean_absolute_error: 0.0187 - val_loss: 0.0190 - val_mean_absolute_error: 0.0177
# Epoch 298/300
# 149/149 [==============================] - 0s 67us/step - loss: 0.0194 - mean_absolute_error: 0.0192 - val_loss: 0.0191 - val_mean_absolute_error: 0.0176
# Epoch 299/300
# 149/149 [==============================] - 0s 67us/step - loss: 0.0194 - mean_absolute_error: 0.0189 - val_loss: 0.0193 - val_mean_absolute_error: 0.0166
# Epoch 300/300
# 149/149 [==============================] - 0s 67us/step - loss: 0.0195 - mean_absolute_error: 0.0189 - val_loss: 0.0191 - val_mean_absolute_error: 0.0177

# %% [markdown]
# ## Evaluate Model Results

# %%
# Plot the mean absolute error for the training data and validation data over the epochs.
plt.plot(run_history.history['mean_absolute_error'], label='MAE (training data)') # [50:]
plt.plot(run_history.history['val_mean_absolute_error'], label='MAE (validation data)') # [50:]
plt.title('MAE for GDP Neural Network Regression')
plt.ylabel('MAE value')
plt.xlabel('No. epoch')
plt.legend(loc="upper right")
fig = plt.gcf()
fig.set_size_inches(12,8)
plt.show()

# %%
# Make predictions using test data.
predictions_test_reg = trained_model.predict(x_test_input)

# Measure the mean absolute error for the test data.
test_mean_abs_error_reg = mean_absolute_error(y_test_rate, predictions_test_reg)
print('Test mean abs error: {0:0.3f}'.format(test_mean_abs_error_reg))
# Out:
# Test mean abs error: 0.010

# %%
# Make predictions using training data.
predictions_training = trained_model.predict(x_train_input)

# Measure the mean absolute error for the training data.
training_mean_abs_error = mean_absolute_error(y_train_rate, predictions_training)
print('Training mean abs error: {0:0.3f}'.format(training_mean_abs_error))

# Make predictions using training data.
predictions_val = trained_model.predict(x_val_input)

# Measure the mean absolute error for the validation data.
val_mean_abs_error = mean_absolute_error(y_val_rate, predictions_val)
print('Validation mean abs error: {0:0.3f}'.format(val_mean_abs_error))
# Out:
# Training mean abs error: 0.010
# Validation mean abs error: 0.018

# %%
predictions_test_reg

# %%
predictions_training

# %%
# Look at the predicted GDP growth rate vs the training growth rates
plt.plot(predictions_training*100.0, label='Training Predictions')
plt.plot(y_train_rate*100.0, label='Training Growth Rate')
plt.title('Predicted Training Growth Rate')
plt.ylabel('MAE value')
plt.xlabel('No. epoch')
plt.legend(loc="upper right")
fig = plt.gcf()
fig.set_size_inches(12,8)
plt.show()

# %% [markdown]
# ## Setup a Hyperparameter Grid Search

# %%
# Run the neural network model repeatedly, doing a grid search of selected hyperparameter values.
# Results will be written to a pandas dataframe so that we can easily analyze the results.
# We will also write output messages to the screen to monitor progress, but go get a beverage 
# of your choice after kicking this off.

#results = []
results = pd.DataFrame(columns=['Desc','Penalty', 'Reg Type', 'Dense Layers', 'Learning Rate', 'Columns',
                                'StdInput', 'Training MAE Min', 'Val MAE Min'])

columnsetall = ['WATERBORNE_PCT', 'RAIL_FRT_PCT', 'RAIL_INTERMOD_PCT', 'TRUCK_PCT', 'AIR_RTMFM_PCT', 'TSI_PCT']
columnset1 = ['RAIL_INTERMOD_PCT', 'AIR_RTMFM_PCT']
columnset2 = ['RAIL_INTERMOD_PCT', 'AIR_RTMFM_PCT', 'TSI_PCT']
columnset3 = ['TRUCK_PCT', 'RAIL_INTERMOD_PCT', 'AIR_RTMFM_PCT', 'TSI_PCT']
columnset4 = ['TSI_PCT']

testcasecounter = 0

for in_dense_layers in [64]:  #16, 32, 64
    for in_reg_type in ["L1"]:
        for in_penalty in [0.000000001]:  #0.1, 0.01, 0.001
            for in_learning_rate in [0.001]:  #0.01, 0.001, 0.0006
                for in_stdinput in [False]:
                    for columnset in [columnset3]: #columnsetall, columnset1, columnset2, columnset3, columnset4]:
                        testcasecounter += 1
                        testcase = '{6}: dense_layers={0}, reg={1}, penalty={2:0.03f},lr={3:0.4f}, stdinput={4}, columns={5}'.format(
                                            in_dense_layers, in_reg_type, in_penalty, in_learning_rate, in_stdinput, columnset, testcasecounter)
                        print(testcase)

                        (trained_model, run_history) = get_nn_model(penalty=in_penalty, reg_type=in_reg_type, dense_layers=in_dense_layers,
                                                                    stdinput=in_stdinput, learning_rate=in_learning_rate, 
                                                                    x_train=x_train[columnset],x_train_std=x_train_std[columnset], 
                                                                    y_train=y_train_rate, x_val=x_val[columnset], 
                                                                    x_val_std=x_val_std[columnset], y_val=y_val_rate)
                        
                        training_mae_min = np.min(run_history.history['mean_absolute_error']) # grab some min values from the run
                        val_mae_min = np.min(run_history.history['val_mean_absolute_error'])
                        print('Training mae min: {0:0.4f}, Val mae min: {1:0.4f}\n'.format(training_mae_min, val_mae_min))

                        results = results.append(pd.Series([testcase, in_penalty, in_reg_type, in_dense_layers, in_learning_rate, columnset,
                                                           in_stdinput, training_mae_min, val_mae_min], index=results.columns ), ignore_index=True)
# Out:
# 1: dense_layers=64, reg=L1, penalty=0.000,lr=0.0010, stdinput=False, columns=['TRUCK_PCT', 'RAIL_INTERMOD_PCT', 'AIR_RTMFM_PCT', 'TSI_PCT']
# Train on 149 samples, validate on 37 samples
# Epoch 1/300
# 149/149 [==============================] - 0s 2ms/step - loss: 8.4184e-04 - mean_absolute_error: 0.0217 - val_loss: 3.9346e-04 - val_mean_absolute_error: 0.0161
# Epoch 2/300
# 149/149 [==============================] - 0s 47us/step - loss: 7.2119e-04 - mean_absolute_error: 0.0187 - val_loss: 4.3504e-04 - val_mean_absolute_error: 0.0172
# Epoch 3/300
# 149/149 [==============================] - 0s 54us/step - loss: 6.5514e-04 - mean_absolute_error: 0.0191 - val_loss: 4.4644e-04 - val_mean_absolute_error: 0.0175
# Epoch 4/300
# 149/149 [==============================] - 0s 54us/step - loss: 6.1704e-04 - mean_absolute_error: 0.0182 - val_loss: 3.9892e-04 - val_mean_absolute_error: 0.0164
# Epoch 5/300
# 149/149 [==============================] - 0s 47us/step - loss: 6.1793e-04 - mean_absolute_error: 0.0181 - val_loss: 4.4208e-04 - val_mean_absolute_error: 0.0176
# Epoch 6/300
# 149/149 [==============================] - 0s 47us/step - loss: 5.8006e-04 - mean_absolute_error: 0.0176 - val_loss: 4.1901e-04 - val_mean_absolute_error: 0.0170
# Epoch 7/300
# 149/149 [==============================] - 0s 67us/step - loss: 5.7389e-04 - mean_absolute_error: 0.0175 - val_loss: 4.3342e-04 - val_mean_absolute_error: 0.0175
# Epoch 8/300
# 149/149 [==============================] - 0s 47us/step - loss: 5.5771e-04 - mean_absolute_error: 0.0172 - val_loss: 4.4396e-04 - val_mean_absolute_error: 0.0177
# Epoch 9/300
# 149/149 [==============================] - 0s 67us/step - loss: 5.4960e-04 - mean_absolute_error: 0.0170 - val_loss: 4.4266e-04 - val_mean_absolute_error: 0.0177
# Epoch 10/300
# 149/149 [==============================] - 0s 47us/step - loss: 5.4601e-04 - mean_absolute_error: 0.0170 - val_loss: 4.5388e-04 - val_mean_absolute_error: 0.0179
# Epoch 11/300
# 149/149 [==============================] - 0s 67us/step - loss: 5.4167e-04 - mean_absolute_error: 0.0171 - val_loss: 4.7776e-04 - val_mean_absolute_error: 0.0183
# Epoch 12/300
# 149/149 [==============================] - 0s 47us/step - loss: 5.2937e-04 - mean_absolute_error: 0.0169 - val_loss: 4.6050e-04 - val_mean_absolute_error: 0.0180
# Epoch 13/300
# 149/149 [==============================] - 0s 54us/step - loss: 5.3657e-04 - mean_absolute_error: 0.0171 - val_loss: 4.6965e-04 - val_mean_absolute_error: 0.0181
# Epoch 14/300
# 149/149 [==============================] - 0s 47us/step - loss: 5.3575e-04 - mean_absolute_error: 0.0171 - val_loss: 4.4827e-04 - val_mean_absolute_error: 0.0177
# Epoch 15/300
# 149/149 [==============================] - 0s 67us/step - loss: 5.1727e-04 - mean_absolute_error: 0.0168 - val_loss: 4.9305e-04 - val_mean_absolute_error: 0.0187
# Epoch 16/300
# 149/149 [==============================] - 0s 47us/step - loss: 5.1852e-04 - mean_absolute_error: 0.0169 - val_loss: 4.4502e-04 - val_mean_absolute_error: 0.0176
# Epoch 17/300
# 149/149 [==============================] - 0s 54us/step - loss: 5.1185e-04 - mean_absolute_error: 0.0167 - val_loss: 4.7701e-04 - val_mean_absolute_error: 0.0183
# Epoch 18/300
# 149/149 [==============================] - 0s 54us/step - loss: 5.5021e-04 - mean_absolute_error: 0.0178 - val_loss: 4.7226e-04 - val_mean_absolute_error: 0.0182
# Epoch 19/300
# 149/149 [==============================] - 0s 47us/step - loss: 5.1980e-04 - mean_absolute_error: 0.0170 - val_loss: 4.3633e-04 - val_mean_absolute_error: 0.0169
# Epoch 20/300
# 149/149 [==============================] - 0s 60us/step - loss: 4.9735e-04 - mean_absolute_error: 0.0162 - val_loss: 5.0081e-04 - val_mean_absolute_error: 0.0188
# Epoch 21/300
# 149/149 [==============================] - 0s 54us/step - loss: 5.5555e-04 - mean_absolute_error: 0.0180 - val_loss: 4.9268e-04 - val_mean_absolute_error: 0.0186
# Epoch 22/300
# 149/149 [==============================] - 0s 47us/step - loss: 4.9338e-04 - mean_absolute_error: 0.0165 - val_loss: 4.2710e-04 - val_mean_absolute_error: 0.0166
# Epoch 23/300
# 149/149 [==============================] - 0s 54us/step - loss: 5.1398e-04 - mean_absolute_error: 0.0168 - val_loss: 4.6527e-04 - val_mean_absolute_error: 0.0180
# Epoch 24/300
# 149/149 [==============================] - 0s 54us/step - loss: 5.1340e-04 - mean_absolute_error: 0.0173 - val_loss: 5.0524e-04 - val_mean_absolute_error: 0.0187
# Epoch 25/300
# 149/149 [==============================] - 0s 54us/step - loss: 4.9187e-04 - mean_absolute_error: 0.0165 - val_loss: 4.3807e-04 - val_mean_absolute_error: 0.0170
# Epoch 26/300
# 149/149 [==============================] - 0s 47us/step - loss: 5.0131e-04 - mean_absolute_error: 0.0167 - val_loss: 4.8703e-04 - val_mean_absolute_error: 0.0183
# Epoch 27/300
# 149/149 [==============================] - 0s 54us/step - loss: 4.8325e-04 - mean_absolute_error: 0.0162 - val_loss: 4.4913e-04 - val_mean_absolute_error: 0.0174
# Epoch 28/300
# 149/149 [==============================] - 0s 60us/step - loss: 4.8419e-04 - mean_absolute_error: 0.0162 - val_loss: 4.6126e-04 - val_mean_absolute_error: 0.0177
# Epoch 29/300
# 149/149 [==============================] - 0s 54us/step - loss: 4.8211e-04 - mean_absolute_error: 0.0164 - val_loss: 4.8700e-04 - val_mean_absolute_error: 0.0183
# Epoch 30/300
# 149/149 [==============================] - 0s 60us/step - loss: 4.8178e-04 - mean_absolute_error: 0.0163 - val_loss: 4.4222e-04 - val_mean_absolute_error: 0.0171
# Epoch 31/300
# 149/149 [==============================] - 0s 47us/step - loss: 4.8378e-04 - mean_absolute_error: 0.0161 - val_loss: 4.9534e-04 - val_mean_absolute_error: 0.0185
# Epoch 32/300
# 149/149 [==============================] - 0s 54us/step - loss: 4.8400e-04 - mean_absolute_error: 0.0164 - val_loss: 4.5081e-04 - val_mean_absolute_error: 0.0173
# Epoch 33/300
# 149/149 [==============================] - 0s 60us/step - loss: 4.7041e-04 - mean_absolute_error: 0.0159 - val_loss: 4.8476e-04 - val_mean_absolute_error: 0.0182
# Epoch 34/300
# 149/149 [==============================] - 0s 54us/step - loss: 4.7425e-04 - mean_absolute_error: 0.0162 - val_loss: 4.5468e-04 - val_mean_absolute_error: 0.0175
# Epoch 35/300
# 149/149 [==============================] - 0s 60us/step - loss: 4.6735e-04 - mean_absolute_error: 0.0161 - val_loss: 4.7819e-04 - val_mean_absolute_error: 0.0181
# Epoch 36/300
# 149/149 [==============================] - 0s 54us/step - loss: 4.6626e-04 - mean_absolute_error: 0.0159 - val_loss: 4.5691e-04 - val_mean_absolute_error: 0.0175
# Epoch 37/300
# 149/149 [==============================] - 0s 54us/step - loss: 4.6239e-04 - mean_absolute_error: 0.0160 - val_loss: 4.7780e-04 - val_mean_absolute_error: 0.0180
# Epoch 38/300
# 149/149 [==============================] - 0s 60us/step - loss: 4.5592e-04 - mean_absolute_error: 0.0158 - val_loss: 4.4957e-04 - val_mean_absolute_error: 0.0173
# Epoch 39/300
# 149/149 [==============================] - 0s 47us/step - loss: 4.6415e-04 - mean_absolute_error: 0.0158 - val_loss: 4.6603e-04 - val_mean_absolute_error: 0.0178
# Epoch 40/300
# 149/149 [==============================] - 0s 54us/step - loss: 4.5676e-04 - mean_absolute_error: 0.0159 - val_loss: 4.8650e-04 - val_mean_absolute_error: 0.0181
# Epoch 41/300
# 149/149 [==============================] - 0s 60us/step - loss: 4.4901e-04 - mean_absolute_error: 0.0157 - val_loss: 4.5485e-04 - val_mean_absolute_error: 0.0172
# Epoch 42/300
# 149/149 [==============================] - 0s 54us/step - loss: 4.5222e-04 - mean_absolute_error: 0.0154 - val_loss: 4.7029e-04 - val_mean_absolute_error: 0.0180
# Epoch 43/300
# 149/149 [==============================] - 0s 60us/step - loss: 4.4736e-04 - mean_absolute_error: 0.0155 - val_loss: 4.4487e-04 - val_mean_absolute_error: 0.0172
# Epoch 44/300
# 149/149 [==============================] - 0s 54us/step - loss: 4.4714e-04 - mean_absolute_error: 0.0156 - val_loss: 4.5654e-04 - val_mean_absolute_error: 0.0175
# Epoch 45/300
# 149/149 [==============================] - 0s 60us/step - loss: 4.4266e-04 - mean_absolute_error: 0.0154 - val_loss: 4.7570e-04 - val_mean_absolute_error: 0.0179
# Epoch 46/300
# 149/149 [==============================] - 0s 47us/step - loss: 4.5645e-04 - mean_absolute_error: 0.0159 - val_loss: 4.5346e-04 - val_mean_absolute_error: 0.0173
# Epoch 47/300
# 149/149 [==============================] - 0s 54us/step - loss: 4.4521e-04 - mean_absolute_error: 0.0155 - val_loss: 4.4517e-04 - val_mean_absolute_error: 0.0169
# Epoch 48/300
# 149/149 [==============================] - 0s 54us/step - loss: 4.3814e-04 - mean_absolute_error: 0.0155 - val_loss: 4.8533e-04 - val_mean_absolute_error: 0.0182
# Epoch 49/300
# 149/149 [==============================] - 0s 47us/step - loss: 4.5251e-04 - mean_absolute_error: 0.0156 - val_loss: 4.4617e-04 - val_mean_absolute_error: 0.0170
# Epoch 50/300
# 149/149 [==============================] - 0s 60us/step - loss: 4.2904e-04 - mean_absolute_error: 0.0153 - val_loss: 4.9141e-04 - val_mean_absolute_error: 0.0183
# Epoch 51/300
# 149/149 [==============================] - 0s 54us/step - loss: 4.4837e-04 - mean_absolute_error: 0.0156 - val_loss: 4.6507e-04 - val_mean_absolute_error: 0.0172
# Epoch 52/300
# 149/149 [==============================] - ETA: 0s - loss: 6.0224e-04 - mean_absolute_error: 0.016 - 0s 54us/step - loss: 4.3715e-04 - mean_absolute_error: 0.0152 - val_loss: 4.7543e-04 - val_mean_absolute_error: 0.0180
# Epoch 53/300
# 149/149 [==============================] - 0s 54us/step - loss: 4.2886e-04 - mean_absolute_error: 0.0152 - val_loss: 4.4556e-04 - val_mean_absolute_error: 0.0172
# Epoch 54/300
# 149/149 [==============================] - 0s 54us/step - loss: 4.2514e-04 - mean_absolute_error: 0.0151 - val_loss: 4.5594e-04 - val_mean_absolute_error: 0.0175
# Epoch 55/300
# 149/149 [==============================] - 0s 81us/step - loss: 4.3365e-04 - mean_absolute_error: 0.0154 - val_loss: 4.4983e-04 - val_mean_absolute_error: 0.0173
# Epoch 56/300
# 149/149 [==============================] - 0s 60us/step - loss: 4.3618e-04 - mean_absolute_error: 0.0153 - val_loss: 4.5300e-04 - val_mean_absolute_error: 0.0172
# Epoch 57/300
# 149/149 [==============================] - 0s 60us/step - loss: 4.2783e-04 - mean_absolute_error: 0.0152 - val_loss: 4.6941e-04 - val_mean_absolute_error: 0.0177
# Epoch 58/300
# 149/149 [==============================] - 0s 54us/step - loss: 4.3568e-04 - mean_absolute_error: 0.0153 - val_loss: 4.4589e-04 - val_mean_absolute_error: 0.0170
# Epoch 59/300
# 149/149 [==============================] - 0s 47us/step - loss: 4.2233e-04 - mean_absolute_error: 0.0151 - val_loss: 4.8315e-04 - val_mean_absolute_error: 0.0181
# Epoch 60/300
# 149/149 [==============================] - 0s 67us/step - loss: 4.1969e-04 - mean_absolute_error: 0.0148 - val_loss: 4.5543e-04 - val_mean_absolute_error: 0.0171
# Epoch 61/300
# 149/149 [==============================] - 0s 54us/step - loss: 4.1391e-04 - mean_absolute_error: 0.0148 - val_loss: 4.3839e-04 - val_mean_absolute_error: 0.0170
# Epoch 62/300
# 149/149 [==============================] - 0s 54us/step - loss: 4.1739e-04 - mean_absolute_error: 0.0149 - val_loss: 4.3658e-04 - val_mean_absolute_error: 0.0170
# Epoch 63/300
# 149/149 [==============================] - 0s 60us/step - loss: 4.1614e-04 - mean_absolute_error: 0.0150 - val_loss: 4.4685e-04 - val_mean_absolute_error: 0.0170
# Epoch 64/300
# 149/149 [==============================] - 0s 54us/step - loss: 4.2165e-04 - mean_absolute_error: 0.0152 - val_loss: 4.5185e-04 - val_mean_absolute_error: 0.0173
# Epoch 65/300
# 149/149 [==============================] - 0s 54us/step - loss: 4.1282e-04 - mean_absolute_error: 0.0147 - val_loss: 4.4869e-04 - val_mean_absolute_error: 0.0170
# Epoch 66/300
# 149/149 [==============================] - 0s 47us/step - loss: 4.0678e-04 - mean_absolute_error: 0.0147 - val_loss: 4.5952e-04 - val_mean_absolute_error: 0.0174
# Epoch 67/300
# 149/149 [==============================] - 0s 47us/step - loss: 4.0374e-04 - mean_absolute_error: 0.0146 - val_loss: 4.4678e-04 - val_mean_absolute_error: 0.0170
# Epoch 68/300
# 149/149 [==============================] - 0s 60us/step - loss: 4.0500e-04 - mean_absolute_error: 0.0145 - val_loss: 4.6972e-04 - val_mean_absolute_error: 0.0177
# Epoch 69/300
# 149/149 [==============================] - 0s 60us/step - loss: 4.1834e-04 - mean_absolute_error: 0.0151 - val_loss: 4.3496e-04 - val_mean_absolute_error: 0.0166
# Epoch 70/300
# 149/149 [==============================] - 0s 47us/step - loss: 4.0617e-04 - mean_absolute_error: 0.0147 - val_loss: 4.5267e-04 - val_mean_absolute_error: 0.0174
# Epoch 71/300
# 149/149 [==============================] - 0s 47us/step - loss: 4.1326e-04 - mean_absolute_error: 0.0149 - val_loss: 4.4908e-04 - val_mean_absolute_error: 0.0172
# Epoch 72/300
# 149/149 [==============================] - 0s 60us/step - loss: 3.9761e-04 - mean_absolute_error: 0.0145 - val_loss: 4.4430e-04 - val_mean_absolute_error: 0.0169
# Epoch 73/300
# 149/149 [==============================] - 0s 54us/step - loss: 3.9817e-04 - mean_absolute_error: 0.0145 - val_loss: 4.5892e-04 - val_mean_absolute_error: 0.0173
# Epoch 74/300
# 149/149 [==============================] - 0s 40us/step - loss: 4.0149e-04 - mean_absolute_error: 0.0147 - val_loss: 4.3494e-04 - val_mean_absolute_error: 0.0168
# Epoch 75/300
# 149/149 [==============================] - 0s 54us/step - loss: 3.9973e-04 - mean_absolute_error: 0.0146 - val_loss: 4.3546e-04 - val_mean_absolute_error: 0.0169
# Epoch 76/300
# 149/149 [==============================] - 0s 54us/step - loss: 3.9457e-04 - mean_absolute_error: 0.0144 - val_loss: 4.3070e-04 - val_mean_absolute_error: 0.0167
# Epoch 77/300
# 149/149 [==============================] - 0s 54us/step - loss: 4.2274e-04 - mean_absolute_error: 0.0152 - val_loss: 4.2539e-04 - val_mean_absolute_error: 0.0166
# Epoch 78/300
# 149/149 [==============================] - 0s 60us/step - loss: 3.9844e-04 - mean_absolute_error: 0.0146 - val_loss: 4.2551e-04 - val_mean_absolute_error: 0.0168
# Epoch 79/300
# 149/149 [==============================] - 0s 47us/step - loss: 3.9477e-04 - mean_absolute_error: 0.0145 - val_loss: 4.2399e-04 - val_mean_absolute_error: 0.0166
# Epoch 80/300
# 149/149 [==============================] - 0s 47us/step - loss: 3.8880e-04 - mean_absolute_error: 0.0143 - val_loss: 4.3414e-04 - val_mean_absolute_error: 0.0166
# Epoch 81/300
# 149/149 [==============================] - 0s 60us/step - loss: 3.8688e-04 - mean_absolute_error: 0.0143 - val_loss: 4.3628e-04 - val_mean_absolute_error: 0.0171
# Epoch 82/300
# 149/149 [==============================] - 0s 54us/step - loss: 3.9393e-04 - mean_absolute_error: 0.0144 - val_loss: 4.2139e-04 - val_mean_absolute_error: 0.0164
# Epoch 83/300
# 149/149 [==============================] - 0s 67us/step - loss: 4.0219e-04 - mean_absolute_error: 0.0148 - val_loss: 4.4345e-04 - val_mean_absolute_error: 0.0172
# Epoch 84/300
# 149/149 [==============================] - 0s 47us/step - loss: 3.9416e-04 - mean_absolute_error: 0.0148 - val_loss: 4.2623e-04 - val_mean_absolute_error: 0.0163
# Epoch 85/300
# 149/149 [==============================] - 0s 60us/step - loss: 3.9364e-04 - mean_absolute_error: 0.0144 - val_loss: 4.2740e-04 - val_mean_absolute_error: 0.0167
# Epoch 86/300
# 149/149 [==============================] - 0s 54us/step - loss: 3.8645e-04 - mean_absolute_error: 0.0144 - val_loss: 4.2576e-04 - val_mean_absolute_error: 0.0166
# Epoch 87/300
# 149/149 [==============================] - 0s 47us/step - loss: 3.8577e-04 - mean_absolute_error: 0.0143 - val_loss: 4.3885e-04 - val_mean_absolute_error: 0.0171
# Epoch 88/300
# 149/149 [==============================] - 0s 54us/step - loss: 3.9672e-04 - mean_absolute_error: 0.0149 - val_loss: 4.3162e-04 - val_mean_absolute_error: 0.0164
# Epoch 89/300
# 149/149 [==============================] - 0s 47us/step - loss: 3.9458e-04 - mean_absolute_error: 0.0144 - val_loss: 4.3712e-04 - val_mean_absolute_error: 0.0168
# Epoch 90/300
# 149/149 [==============================] - 0s 60us/step - loss: 3.7459e-04 - mean_absolute_error: 0.0141 - val_loss: 4.1164e-04 - val_mean_absolute_error: 0.0164
# Epoch 91/300
# 149/149 [==============================] - 0s 54us/step - loss: 3.9442e-04 - mean_absolute_error: 0.0147 - val_loss: 4.5461e-04 - val_mean_absolute_error: 0.0175
# Epoch 92/300
# 149/149 [==============================] - 0s 47us/step - loss: 3.8068e-04 - mean_absolute_error: 0.0143 - val_loss: 4.3693e-04 - val_mean_absolute_error: 0.0166
# Epoch 93/300
# 149/149 [==============================] - 0s 67us/step - loss: 3.7157e-04 - mean_absolute_error: 0.0139 - val_loss: 4.3258e-04 - val_mean_absolute_error: 0.0166
# Epoch 94/300
# 149/149 [==============================] - 0s 54us/step - loss: 3.6708e-04 - mean_absolute_error: 0.0140 - val_loss: 4.1547e-04 - val_mean_absolute_error: 0.0163
# Epoch 95/300
# 149/149 [==============================] - 0s 67us/step - loss: 3.9922e-04 - mean_absolute_error: 0.0147 - val_loss: 4.5063e-04 - val_mean_absolute_error: 0.0173
# Epoch 96/300
# 149/149 [==============================] - 0s 54us/step - loss: 4.1459e-04 - mean_absolute_error: 0.0154 - val_loss: 4.1379e-04 - val_mean_absolute_error: 0.0162
# Epoch 97/300
# 149/149 [==============================] - 0s 60us/step - loss: 3.8429e-04 - mean_absolute_error: 0.0143 - val_loss: 4.2228e-04 - val_mean_absolute_error: 0.0165
# Epoch 98/300
# 149/149 [==============================] - 0s 47us/step - loss: 3.6243e-04 - mean_absolute_error: 0.0139 - val_loss: 4.4562e-04 - val_mean_absolute_error: 0.0171
# Epoch 99/300
# 149/149 [==============================] - 0s 54us/step - loss: 3.6393e-04 - mean_absolute_error: 0.0140 - val_loss: 4.2499e-04 - val_mean_absolute_error: 0.0163
# Epoch 100/300
# 149/149 [==============================] - 0s 54us/step - loss: 3.6192e-04 - mean_absolute_error: 0.0139 - val_loss: 4.3710e-04 - val_mean_absolute_error: 0.0170
# Epoch 101/300
# 149/149 [==============================] - 0s 54us/step - loss: 3.6424e-04 - mean_absolute_error: 0.0140 - val_loss: 4.2205e-04 - val_mean_absolute_error: 0.0164
# Epoch 102/300
# 149/149 [==============================] - 0s 60us/step - loss: 3.7040e-04 - mean_absolute_error: 0.0140 - val_loss: 4.4513e-04 - val_mean_absolute_error: 0.0169
# Epoch 103/300
# 149/149 [==============================] - 0s 60us/step - loss: 3.6008e-04 - mean_absolute_error: 0.0138 - val_loss: 4.0917e-04 - val_mean_absolute_error: 0.0160
# Epoch 104/300
# 149/149 [==============================] - 0s 54us/step - loss: 3.8538e-04 - mean_absolute_error: 0.0144 - val_loss: 4.2913e-04 - val_mean_absolute_error: 0.0168
# Epoch 105/300
# 149/149 [==============================] - 0s 54us/step - loss: 3.5142e-04 - mean_absolute_error: 0.0137 - val_loss: 4.0530e-04 - val_mean_absolute_error: 0.0159
# Epoch 106/300
# 149/149 [==============================] - 0s 54us/step - loss: 3.8416e-04 - mean_absolute_error: 0.0144 - val_loss: 4.3684e-04 - val_mean_absolute_error: 0.0170
# Epoch 107/300
# 149/149 [==============================] - 0s 60us/step - loss: 3.6719e-04 - mean_absolute_error: 0.0144 - val_loss: 4.1705e-04 - val_mean_absolute_error: 0.0161
# Epoch 108/300
# 149/149 [==============================] - 0s 54us/step - loss: 3.5841e-04 - mean_absolute_error: 0.0140 - val_loss: 4.0342e-04 - val_mean_absolute_error: 0.0161
# Epoch 109/300
# 149/149 [==============================] - 0s 60us/step - loss: 3.5422e-04 - mean_absolute_error: 0.0137 - val_loss: 4.0101e-04 - val_mean_absolute_error: 0.0159
# Epoch 110/300
# 149/149 [==============================] - 0s 60us/step - loss: 3.5570e-04 - mean_absolute_error: 0.0138 - val_loss: 4.1078e-04 - val_mean_absolute_error: 0.0161
# Epoch 111/300
# 149/149 [==============================] - ETA: 0s - loss: 2.5866e-04 - mean_absolute_error: 0.012 - 0s 60us/step - loss: 3.6278e-04 - mean_absolute_error: 0.0138 - val_loss: 4.2161e-04 - val_mean_absolute_error: 0.0168
# Epoch 112/300
# 149/149 [==============================] - 0s 60us/step - loss: 3.8426e-04 - mean_absolute_error: 0.0148 - val_loss: 4.0507e-04 - val_mean_absolute_error: 0.0159
# Epoch 113/300
# 149/149 [==============================] - 0s 47us/step - loss: 3.7782e-04 - mean_absolute_error: 0.0140 - val_loss: 4.1748e-04 - val_mean_absolute_error: 0.0165
# Epoch 114/300
# 149/149 [==============================] - 0s 67us/step - loss: 3.4670e-04 - mean_absolute_error: 0.0137 - val_loss: 4.0399e-04 - val_mean_absolute_error: 0.0160
# Epoch 115/300
# 149/149 [==============================] - 0s 47us/step - loss: 3.5527e-04 - mean_absolute_error: 0.0136 - val_loss: 4.2255e-04 - val_mean_absolute_error: 0.0165
# Epoch 116/300
# 149/149 [==============================] - 0s 54us/step - loss: 3.6260e-04 - mean_absolute_error: 0.0144 - val_loss: 4.0542e-04 - val_mean_absolute_error: 0.0160
# Epoch 117/300
# 149/149 [==============================] - 0s 60us/step - loss: 3.4169e-04 - mean_absolute_error: 0.0135 - val_loss: 4.0092e-04 - val_mean_absolute_error: 0.0160
# Epoch 118/300
# 149/149 [==============================] - 0s 54us/step - loss: 3.4174e-04 - mean_absolute_error: 0.0134 - val_loss: 4.0400e-04 - val_mean_absolute_error: 0.0161
# Epoch 119/300
# 149/149 [==============================] - 0s 60us/step - loss: 3.3393e-04 - mean_absolute_error: 0.0133 - val_loss: 4.2164e-04 - val_mean_absolute_error: 0.0166
# Epoch 120/300
# 149/149 [==============================] - 0s 47us/step - loss: 3.3907e-04 - mean_absolute_error: 0.0134 - val_loss: 4.0189e-04 - val_mean_absolute_error: 0.0161
# Epoch 121/300
# 149/149 [==============================] - 0s 54us/step - loss: 3.4142e-04 - mean_absolute_error: 0.0136 - val_loss: 4.0047e-04 - val_mean_absolute_error: 0.0158
# Epoch 122/300
# 149/149 [==============================] - 0s 60us/step - loss: 3.4265e-04 - mean_absolute_error: 0.0136 - val_loss: 4.2619e-04 - val_mean_absolute_error: 0.0165
# Epoch 123/300
# 149/149 [==============================] - 0s 54us/step - loss: 3.4188e-04 - mean_absolute_error: 0.0136 - val_loss: 4.0383e-04 - val_mean_absolute_error: 0.0158
# Epoch 124/300
# 149/149 [==============================] - 0s 54us/step - loss: 3.3565e-04 - mean_absolute_error: 0.0136 - val_loss: 4.1896e-04 - val_mean_absolute_error: 0.0166
# Epoch 125/300
# 149/149 [==============================] - 0s 54us/step - loss: 3.3325e-04 - mean_absolute_error: 0.0134 - val_loss: 4.0573e-04 - val_mean_absolute_error: 0.0161
# Epoch 126/300
# 149/149 [==============================] - 0s 60us/step - loss: 3.2405e-04 - mean_absolute_error: 0.0130 - val_loss: 4.2838e-04 - val_mean_absolute_error: 0.0168
# Epoch 127/300
# 149/149 [==============================] - 0s 54us/step - loss: 3.3650e-04 - mean_absolute_error: 0.0135 - val_loss: 4.1176e-04 - val_mean_absolute_error: 0.0159
# Epoch 128/300
# 149/149 [==============================] - 0s 54us/step - loss: 3.5085e-04 - mean_absolute_error: 0.0139 - val_loss: 4.4216e-04 - val_mean_absolute_error: 0.0168
# Epoch 129/300
# 149/149 [==============================] - 0s 60us/step - loss: 3.5787e-04 - mean_absolute_error: 0.0144 - val_loss: 4.1617e-04 - val_mean_absolute_error: 0.0158
# Epoch 130/300
# 149/149 [==============================] - 0s 47us/step - loss: 3.5591e-04 - mean_absolute_error: 0.0138 - val_loss: 4.2222e-04 - val_mean_absolute_error: 0.0165
# Epoch 131/300
# 149/149 [==============================] - 0s 54us/step - loss: 3.3458e-04 - mean_absolute_error: 0.0134 - val_loss: 3.9880e-04 - val_mean_absolute_error: 0.0161
# Epoch 132/300
# 149/149 [==============================] - 0s 60us/step - loss: 3.1764e-04 - mean_absolute_error: 0.0130 - val_loss: 4.0091e-04 - val_mean_absolute_error: 0.0165
# Epoch 133/300
# 149/149 [==============================] - 0s 54us/step - loss: 3.2044e-04 - mean_absolute_error: 0.0133 - val_loss: 4.0455e-04 - val_mean_absolute_error: 0.0160
# Epoch 134/300
# 149/149 [==============================] - 0s 67us/step - loss: 3.1469e-04 - mean_absolute_error: 0.0130 - val_loss: 4.2204e-04 - val_mean_absolute_error: 0.0162
# Epoch 135/300
# 149/149 [==============================] - 0s 54us/step - loss: 3.2258e-04 - mean_absolute_error: 0.0131 - val_loss: 4.1745e-04 - val_mean_absolute_error: 0.0162
# Epoch 136/300
# 149/149 [==============================] - 0s 60us/step - loss: 3.1596e-04 - mean_absolute_error: 0.0131 - val_loss: 3.9911e-04 - val_mean_absolute_error: 0.0162
# Epoch 137/300
# 149/149 [==============================] - 0s 60us/step - loss: 3.1220e-04 - mean_absolute_error: 0.0130 - val_loss: 4.1351e-04 - val_mean_absolute_error: 0.0163
# Epoch 138/300
# 149/149 [==============================] - 0s 47us/step - loss: 3.1149e-04 - mean_absolute_error: 0.0130 - val_loss: 4.2167e-04 - val_mean_absolute_error: 0.0159
# Epoch 139/300
# 149/149 [==============================] - 0s 54us/step - loss: 3.2401e-04 - mean_absolute_error: 0.0131 - val_loss: 4.1500e-04 - val_mean_absolute_error: 0.0164
# Epoch 140/300
# 149/149 [==============================] - 0s 60us/step - loss: 3.0769e-04 - mean_absolute_error: 0.0129 - val_loss: 4.0750e-04 - val_mean_absolute_error: 0.0161
# Epoch 141/300
# 149/149 [==============================] - 0s 47us/step - loss: 3.0696e-04 - mean_absolute_error: 0.0127 - val_loss: 4.3884e-04 - val_mean_absolute_error: 0.0170
# Epoch 142/300
# 149/149 [==============================] - 0s 60us/step - loss: 3.2459e-04 - mean_absolute_error: 0.0137 - val_loss: 4.1139e-04 - val_mean_absolute_error: 0.0158
# Epoch 143/300
# 149/149 [==============================] - 0s 60us/step - loss: 3.3676e-04 - mean_absolute_error: 0.0136 - val_loss: 4.2167e-04 - val_mean_absolute_error: 0.0164
# Epoch 144/300
# 149/149 [==============================] - 0s 54us/step - loss: 3.1532e-04 - mean_absolute_error: 0.0131 - val_loss: 4.1389e-04 - val_mean_absolute_error: 0.0160
# Epoch 145/300
# 149/149 [==============================] - 0s 47us/step - loss: 3.1527e-04 - mean_absolute_error: 0.0132 - val_loss: 4.0520e-04 - val_mean_absolute_error: 0.0160
# Epoch 146/300
# 149/149 [==============================] - 0s 54us/step - loss: 3.2808e-04 - mean_absolute_error: 0.0133 - val_loss: 4.4187e-04 - val_mean_absolute_error: 0.0168
# Epoch 147/300
# 149/149 [==============================] - 0s 54us/step - loss: 3.5553e-04 - mean_absolute_error: 0.0142 - val_loss: 4.3358e-04 - val_mean_absolute_error: 0.0160
# Epoch 148/300
# 149/149 [==============================] - 0s 60us/step - loss: 3.2006e-04 - mean_absolute_error: 0.0132 - val_loss: 4.6025e-04 - val_mean_absolute_error: 0.0177
# Epoch 149/300
# 149/149 [==============================] - 0s 60us/step - loss: 3.2735e-04 - mean_absolute_error: 0.0137 - val_loss: 4.1930e-04 - val_mean_absolute_error: 0.0162
# Epoch 150/300
# 149/149 [==============================] - 0s 47us/step - loss: 3.0431e-04 - mean_absolute_error: 0.0129 - val_loss: 4.1275e-04 - val_mean_absolute_error: 0.0164
# Epoch 151/300
# 149/149 [==============================] - 0s 54us/step - loss: 2.9027e-04 - mean_absolute_error: 0.0124 - val_loss: 4.1308e-04 - val_mean_absolute_error: 0.0160
# Epoch 152/300
# 149/149 [==============================] - 0s 54us/step - loss: 2.9570e-04 - mean_absolute_error: 0.0127 - val_loss: 4.3028e-04 - val_mean_absolute_error: 0.0166
# Epoch 153/300
# 149/149 [==============================] - 0s 94us/step - loss: 3.0306e-04 - mean_absolute_error: 0.0130 - val_loss: 4.2878e-04 - val_mean_absolute_error: 0.0160
# Epoch 154/300
# 149/149 [==============================] - 0s 60us/step - loss: 3.0918e-04 - mean_absolute_error: 0.0131 - val_loss: 4.2703e-04 - val_mean_absolute_error: 0.0167
# Epoch 155/300
# 149/149 [==============================] - 0s 54us/step - loss: 3.0986e-04 - mean_absolute_error: 0.0130 - val_loss: 4.0377e-04 - val_mean_absolute_error: 0.0160
# Epoch 156/300
# 149/149 [==============================] - 0s 54us/step - loss: 3.1394e-04 - mean_absolute_error: 0.0128 - val_loss: 4.0856e-04 - val_mean_absolute_error: 0.0165
# Epoch 157/300
# 149/149 [==============================] - 0s 60us/step - loss: 2.9242e-04 - mean_absolute_error: 0.0126 - val_loss: 4.2438e-04 - val_mean_absolute_error: 0.0166
# Epoch 158/300
# 149/149 [==============================] - 0s 54us/step - loss: 2.9738e-04 - mean_absolute_error: 0.0127 - val_loss: 4.3652e-04 - val_mean_absolute_error: 0.0163
# Epoch 159/300
# 149/149 [==============================] - 0s 54us/step - loss: 2.9017e-04 - mean_absolute_error: 0.0126 - val_loss: 4.1920e-04 - val_mean_absolute_error: 0.0163
# Epoch 160/300
# 149/149 [==============================] - 0s 54us/step - loss: 2.9306e-04 - mean_absolute_error: 0.0125 - val_loss: 4.1971e-04 - val_mean_absolute_error: 0.0165
# Epoch 161/300
# 149/149 [==============================] - 0s 54us/step - loss: 2.7955e-04 - mean_absolute_error: 0.0122 - val_loss: 4.2202e-04 - val_mean_absolute_error: 0.0162
# Epoch 162/300
# 149/149 [==============================] - 0s 67us/step - loss: 3.0593e-04 - mean_absolute_error: 0.0131 - val_loss: 4.3224e-04 - val_mean_absolute_error: 0.0162
# Epoch 163/300
# 149/149 [==============================] - 0s 47us/step - loss: 3.0477e-04 - mean_absolute_error: 0.0129 - val_loss: 4.6551e-04 - val_mean_absolute_error: 0.0175
# Epoch 164/300
# 149/149 [==============================] - 0s 54us/step - loss: 3.0896e-04 - mean_absolute_error: 0.0132 - val_loss: 4.3555e-04 - val_mean_absolute_error: 0.0162
# Epoch 165/300
# 149/149 [==============================] - 0s 60us/step - loss: 2.9846e-04 - mean_absolute_error: 0.0129 - val_loss: 4.8533e-04 - val_mean_absolute_error: 0.0180
# Epoch 166/300
# 149/149 [==============================] - 0s 54us/step - loss: 3.2392e-04 - mean_absolute_error: 0.0138 - val_loss: 4.4450e-04 - val_mean_absolute_error: 0.0166
# Epoch 167/300
# 149/149 [==============================] - 0s 54us/step - loss: 3.0839e-04 - mean_absolute_error: 0.0130 - val_loss: 4.3557e-04 - val_mean_absolute_error: 0.0167
# Epoch 168/300
# 149/149 [==============================] - 0s 60us/step - loss: 2.8402e-04 - mean_absolute_error: 0.0123 - val_loss: 4.4113e-04 - val_mean_absolute_error: 0.0164
# Epoch 169/300
# 149/149 [==============================] - 0s 60us/step - loss: 2.9713e-04 - mean_absolute_error: 0.0131 - val_loss: 4.3291e-04 - val_mean_absolute_error: 0.0162
# Epoch 170/300
# 149/149 [==============================] - 0s 47us/step - loss: 2.8274e-04 - mean_absolute_error: 0.0124 - val_loss: 4.5281e-04 - val_mean_absolute_error: 0.0168
# Epoch 171/300
# 149/149 [==============================] - 0s 60us/step - loss: 3.2160e-04 - mean_absolute_error: 0.0133 - val_loss: 4.3235e-04 - val_mean_absolute_error: 0.0165
# Epoch 172/300
# 149/149 [==============================] - 0s 67us/step - loss: 2.8598e-04 - mean_absolute_error: 0.0126 - val_loss: 4.3812e-04 - val_mean_absolute_error: 0.0168
# Epoch 173/300
# 149/149 [==============================] - 0s 47us/step - loss: 2.7536e-04 - mean_absolute_error: 0.0123 - val_loss: 4.4458e-04 - val_mean_absolute_error: 0.0163
# Epoch 174/300
# 149/149 [==============================] - 0s 54us/step - loss: 2.6891e-04 - mean_absolute_error: 0.0120 - val_loss: 4.1495e-04 - val_mean_absolute_error: 0.0162
# Epoch 175/300
# 149/149 [==============================] - 0s 67us/step - loss: 2.7212e-04 - mean_absolute_error: 0.0123 - val_loss: 4.2409e-04 - val_mean_absolute_error: 0.0165
# Epoch 176/300
# 149/149 [==============================] - 0s 47us/step - loss: 2.7443e-04 - mean_absolute_error: 0.0124 - val_loss: 4.2864e-04 - val_mean_absolute_error: 0.0161
# Epoch 177/300
# 149/149 [==============================] - 0s 54us/step - loss: 2.8760e-04 - mean_absolute_error: 0.0122 - val_loss: 4.2826e-04 - val_mean_absolute_error: 0.0163
# Epoch 178/300
# 149/149 [==============================] - 0s 60us/step - loss: 2.6625e-04 - mean_absolute_error: 0.0119 - val_loss: 4.3332e-04 - val_mean_absolute_error: 0.0163
# Epoch 179/300
# 149/149 [==============================] - 0s 47us/step - loss: 2.6195e-04 - mean_absolute_error: 0.0118 - val_loss: 4.2139e-04 - val_mean_absolute_error: 0.0161
# Epoch 180/300
# 149/149 [==============================] - 0s 54us/step - loss: 2.6244e-04 - mean_absolute_error: 0.0120 - val_loss: 4.3446e-04 - val_mean_absolute_error: 0.0165
# Epoch 181/300
# 149/149 [==============================] - 0s 54us/step - loss: 2.6646e-04 - mean_absolute_error: 0.0121 - val_loss: 4.2690e-04 - val_mean_absolute_error: 0.0162
# Epoch 182/300
# 149/149 [==============================] - 0s 47us/step - loss: 2.6640e-04 - mean_absolute_error: 0.0121 - val_loss: 4.3246e-04 - val_mean_absolute_error: 0.0169
# Epoch 183/300
# 149/149 [==============================] - 0s 54us/step - loss: 2.5916e-04 - mean_absolute_error: 0.0121 - val_loss: 4.4206e-04 - val_mean_absolute_error: 0.0163
# Epoch 184/300
# 149/149 [==============================] - 0s 47us/step - loss: 2.8317e-04 - mean_absolute_error: 0.0125 - val_loss: 4.2289e-04 - val_mean_absolute_error: 0.0166
# Epoch 185/300
# 149/149 [==============================] - 0s 54us/step - loss: 2.8855e-04 - mean_absolute_error: 0.0126 - val_loss: 4.9588e-04 - val_mean_absolute_error: 0.0177
# Epoch 186/300
# 149/149 [==============================] - 0s 47us/step - loss: 2.9725e-04 - mean_absolute_error: 0.0136 - val_loss: 4.7615e-04 - val_mean_absolute_error: 0.0168
# Epoch 187/300
# 149/149 [==============================] - 0s 54us/step - loss: 3.0520e-04 - mean_absolute_error: 0.0134 - val_loss: 4.5512e-04 - val_mean_absolute_error: 0.0175
# Epoch 188/300
# 149/149 [==============================] - 0s 47us/step - loss: 2.7922e-04 - mean_absolute_error: 0.0123 - val_loss: 4.5606e-04 - val_mean_absolute_error: 0.0165
# Epoch 189/300
# 149/149 [==============================] - 0s 60us/step - loss: 2.9955e-04 - mean_absolute_error: 0.0135 - val_loss: 4.2759e-04 - val_mean_absolute_error: 0.0165
# Epoch 190/300
# 149/149 [==============================] - 0s 54us/step - loss: 3.4180e-04 - mean_absolute_error: 0.0139 - val_loss: 4.7903e-04 - val_mean_absolute_error: 0.0181
# Epoch 191/300
# 149/149 [==============================] - 0s 60us/step - loss: 2.9351e-04 - mean_absolute_error: 0.0135 - val_loss: 4.7989e-04 - val_mean_absolute_error: 0.0171
# Epoch 192/300
# 149/149 [==============================] - 0s 54us/step - loss: 2.8609e-04 - mean_absolute_error: 0.0124 - val_loss: 4.4051e-04 - val_mean_absolute_error: 0.0173
# Epoch 193/300
# 149/149 [==============================] - 0s 54us/step - loss: 2.6095e-04 - mean_absolute_error: 0.0121 - val_loss: 4.3389e-04 - val_mean_absolute_error: 0.0162
# Epoch 194/300
# 149/149 [==============================] - 0s 54us/step - loss: 2.6295e-04 - mean_absolute_error: 0.0121 - val_loss: 4.3262e-04 - val_mean_absolute_error: 0.0164
# Epoch 195/300
# 149/149 [==============================] - 0s 47us/step - loss: 2.5404e-04 - mean_absolute_error: 0.0119 - val_loss: 4.4191e-04 - val_mean_absolute_error: 0.0166
# Epoch 196/300
# 149/149 [==============================] - 0s 54us/step - loss: 2.4363e-04 - mean_absolute_error: 0.0115 - val_loss: 4.5019e-04 - val_mean_absolute_error: 0.0169
# Epoch 197/300
# 149/149 [==============================] - 0s 54us/step - loss: 2.4500e-04 - mean_absolute_error: 0.0117 - val_loss: 4.5347e-04 - val_mean_absolute_error: 0.0165
# Epoch 198/300
# 149/149 [==============================] - 0s 54us/step - loss: 2.4592e-04 - mean_absolute_error: 0.0116 - val_loss: 4.7226e-04 - val_mean_absolute_error: 0.0173
# Epoch 199/300
# 149/149 [==============================] - 0s 54us/step - loss: 2.4401e-04 - mean_absolute_error: 0.0116 - val_loss: 4.5416e-04 - val_mean_absolute_error: 0.0166
# Epoch 200/300
# 149/149 [==============================] - 0s 47us/step - loss: 2.5217e-04 - mean_absolute_error: 0.0119 - val_loss: 5.4481e-04 - val_mean_absolute_error: 0.0191
# Epoch 201/300
# 149/149 [==============================] - 0s 60us/step - loss: 2.9965e-04 - mean_absolute_error: 0.0134 - val_loss: 4.2996e-04 - val_mean_absolute_error: 0.0164
# Epoch 202/300
# 149/149 [==============================] - 0s 54us/step - loss: 2.5269e-04 - mean_absolute_error: 0.0121 - val_loss: 4.4794e-04 - val_mean_absolute_error: 0.0171
# Epoch 203/300
# 149/149 [==============================] - 0s 54us/step - loss: 2.5456e-04 - mean_absolute_error: 0.0118 - val_loss: 4.2892e-04 - val_mean_absolute_error: 0.0164
# Epoch 204/300
# 149/149 [==============================] - 0s 54us/step - loss: 2.4183e-04 - mean_absolute_error: 0.0114 - val_loss: 4.4113e-04 - val_mean_absolute_error: 0.0169
# Epoch 205/300
# 149/149 [==============================] - 0s 60us/step - loss: 2.4305e-04 - mean_absolute_error: 0.0117 - val_loss: 4.4379e-04 - val_mean_absolute_error: 0.0164
# Epoch 206/300
# 149/149 [==============================] - 0s 47us/step - loss: 2.4434e-04 - mean_absolute_error: 0.0118 - val_loss: 4.5752e-04 - val_mean_absolute_error: 0.0170
# Epoch 207/300
# 149/149 [==============================] - 0s 54us/step - loss: 2.4202e-04 - mean_absolute_error: 0.0115 - val_loss: 4.5195e-04 - val_mean_absolute_error: 0.0168
# Epoch 208/300
# 149/149 [==============================] - 0s 54us/step - loss: 2.4360e-04 - mean_absolute_error: 0.0117 - val_loss: 4.5309e-04 - val_mean_absolute_error: 0.0165
# Epoch 209/300
# 149/149 [==============================] - 0s 54us/step - loss: 2.3262e-04 - mean_absolute_error: 0.0113 - val_loss: 4.5674e-04 - val_mean_absolute_error: 0.0171
# Epoch 210/300
# 149/149 [==============================] - 0s 60us/step - loss: 2.2856e-04 - mean_absolute_error: 0.0111 - val_loss: 4.4720e-04 - val_mean_absolute_error: 0.0170
# Epoch 211/300
# 149/149 [==============================] - 0s 54us/step - loss: 2.2740e-04 - mean_absolute_error: 0.0110 - val_loss: 4.4413e-04 - val_mean_absolute_error: 0.0168
# Epoch 212/300
# 149/149 [==============================] - 0s 47us/step - loss: 2.2747e-04 - mean_absolute_error: 0.0112 - val_loss: 4.5902e-04 - val_mean_absolute_error: 0.0170
# Epoch 213/300
# 149/149 [==============================] - 0s 40us/step - loss: 2.2376e-04 - mean_absolute_error: 0.0112 - val_loss: 4.6208e-04 - val_mean_absolute_error: 0.0170
# Epoch 214/300
# 149/149 [==============================] - 0s 54us/step - loss: 2.2444e-04 - mean_absolute_error: 0.0111 - val_loss: 4.5987e-04 - val_mean_absolute_error: 0.0175
# Epoch 215/300
# 149/149 [==============================] - 0s 47us/step - loss: 2.4212e-04 - mean_absolute_error: 0.0116 - val_loss: 4.5602e-04 - val_mean_absolute_error: 0.0167
# Epoch 216/300
# 149/149 [==============================] - 0s 60us/step - loss: 2.1698e-04 - mean_absolute_error: 0.0112 - val_loss: 4.6207e-04 - val_mean_absolute_error: 0.0176
# Epoch 217/300
# 149/149 [==============================] - 0s 60us/step - loss: 2.3890e-04 - mean_absolute_error: 0.0119 - val_loss: 4.5895e-04 - val_mean_absolute_error: 0.0169
# Epoch 218/300
# 149/149 [==============================] - 0s 47us/step - loss: 2.3115e-04 - mean_absolute_error: 0.0114 - val_loss: 4.5382e-04 - val_mean_absolute_error: 0.0167
# Epoch 219/300
# 149/149 [==============================] - 0s 67us/step - loss: 2.3251e-04 - mean_absolute_error: 0.0116 - val_loss: 4.5489e-04 - val_mean_absolute_error: 0.0167
# Epoch 220/300
# 149/149 [==============================] - 0s 54us/step - loss: 2.2736e-04 - mean_absolute_error: 0.0114 - val_loss: 4.7416e-04 - val_mean_absolute_error: 0.0175
# Epoch 221/300
# 149/149 [==============================] - 0s 47us/step - loss: 2.4809e-04 - mean_absolute_error: 0.0121 - val_loss: 4.6855e-04 - val_mean_absolute_error: 0.0170
# Epoch 222/300
# 149/149 [==============================] - 0s 60us/step - loss: 2.4258e-04 - mean_absolute_error: 0.0120 - val_loss: 5.3231e-04 - val_mean_absolute_error: 0.0191
# Epoch 223/300
# 149/149 [==============================] - 0s 54us/step - loss: 2.6332e-04 - mean_absolute_error: 0.0127 - val_loss: 4.5564e-04 - val_mean_absolute_error: 0.0166
# Epoch 224/300
# 149/149 [==============================] - 0s 54us/step - loss: 2.3935e-04 - mean_absolute_error: 0.0121 - val_loss: 4.4790e-04 - val_mean_absolute_error: 0.0166
# Epoch 225/300
# 149/149 [==============================] - 0s 67us/step - loss: 2.2328e-04 - mean_absolute_error: 0.0113 - val_loss: 4.4431e-04 - val_mean_absolute_error: 0.0169
# Epoch 226/300
# 149/149 [==============================] - 0s 47us/step - loss: 2.1131e-04 - mean_absolute_error: 0.0110 - val_loss: 4.6895e-04 - val_mean_absolute_error: 0.0176
# Epoch 227/300
# 149/149 [==============================] - 0s 54us/step - loss: 2.3131e-04 - mean_absolute_error: 0.0117 - val_loss: 5.1413e-04 - val_mean_absolute_error: 0.0179
# Epoch 228/300
# 149/149 [==============================] - 0s 40us/step - loss: 2.3976e-04 - mean_absolute_error: 0.0118 - val_loss: 5.5475e-04 - val_mean_absolute_error: 0.0190
# Epoch 229/300
# 149/149 [==============================] - 0s 54us/step - loss: 2.3564e-04 - mean_absolute_error: 0.0121 - val_loss: 5.5756e-04 - val_mean_absolute_error: 0.0184
# Epoch 230/300
# 149/149 [==============================] - 0s 47us/step - loss: 2.4414e-04 - mean_absolute_error: 0.0120 - val_loss: 6.0277e-04 - val_mean_absolute_error: 0.0201
# Epoch 231/300
# 149/149 [==============================] - 0s 47us/step - loss: 2.9343e-04 - mean_absolute_error: 0.0133 - val_loss: 4.8036e-04 - val_mean_absolute_error: 0.0176
# Epoch 232/300
# 149/149 [==============================] - 0s 60us/step - loss: 2.5991e-04 - mean_absolute_error: 0.0125 - val_loss: 4.6708e-04 - val_mean_absolute_error: 0.0176
# Epoch 233/300
# 149/149 [==============================] - 0s 47us/step - loss: 2.4029e-04 - mean_absolute_error: 0.0114 - val_loss: 4.9790e-04 - val_mean_absolute_error: 0.0177
# Epoch 234/300
# 149/149 [==============================] - 0s 67us/step - loss: 2.1952e-04 - mean_absolute_error: 0.0113 - val_loss: 4.5847e-04 - val_mean_absolute_error: 0.0168
# Epoch 235/300
# 149/149 [==============================] - 0s 54us/step - loss: 2.2066e-04 - mean_absolute_error: 0.0115 - val_loss: 4.6731e-04 - val_mean_absolute_error: 0.0175
# Epoch 236/300
# 149/149 [==============================] - 0s 54us/step - loss: 2.1275e-04 - mean_absolute_error: 0.0110 - val_loss: 4.8883e-04 - val_mean_absolute_error: 0.0174
# Epoch 237/300
# 149/149 [==============================] - 0s 54us/step - loss: 2.1917e-04 - mean_absolute_error: 0.0111 - val_loss: 4.6108e-04 - val_mean_absolute_error: 0.0172
# Epoch 238/300
# 149/149 [==============================] - 0s 54us/step - loss: 2.1462e-04 - mean_absolute_error: 0.0114 - val_loss: 4.6675e-04 - val_mean_absolute_error: 0.0174
# Epoch 239/300
# 149/149 [==============================] - 0s 54us/step - loss: 2.1171e-04 - mean_absolute_error: 0.0110 - val_loss: 5.0647e-04 - val_mean_absolute_error: 0.0174
# Epoch 240/300
# 149/149 [==============================] - 0s 54us/step - loss: 2.3775e-04 - mean_absolute_error: 0.0116 - val_loss: 5.3049e-04 - val_mean_absolute_error: 0.0187
# Epoch 241/300
# 149/149 [==============================] - 0s 47us/step - loss: 2.2794e-04 - mean_absolute_error: 0.0114 - val_loss: 4.6109e-04 - val_mean_absolute_error: 0.0169
# Epoch 242/300
# 149/149 [==============================] - 0s 54us/step - loss: 2.0398e-04 - mean_absolute_error: 0.0110 - val_loss: 4.5849e-04 - val_mean_absolute_error: 0.0171
# Epoch 243/300
# 149/149 [==============================] - 0s 60us/step - loss: 2.0871e-04 - mean_absolute_error: 0.0108 - val_loss: 4.7907e-04 - val_mean_absolute_error: 0.0178
# Epoch 244/300
# 149/149 [==============================] - 0s 47us/step - loss: 2.1007e-04 - mean_absolute_error: 0.0109 - val_loss: 4.6939e-04 - val_mean_absolute_error: 0.0173
# Epoch 245/300
# 149/149 [==============================] - 0s 54us/step - loss: 2.0549e-04 - mean_absolute_error: 0.0111 - val_loss: 4.9482e-04 - val_mean_absolute_error: 0.0180
# Epoch 246/300
# 149/149 [==============================] - 0s 54us/step - loss: 2.1388e-04 - mean_absolute_error: 0.0111 - val_loss: 4.7976e-04 - val_mean_absolute_error: 0.0175
# Epoch 247/300
# 149/149 [==============================] - 0s 47us/step - loss: 1.9743e-04 - mean_absolute_error: 0.0104 - val_loss: 4.8202e-04 - val_mean_absolute_error: 0.0175
# Epoch 248/300
# 149/149 [==============================] - 0s 54us/step - loss: 2.0185e-04 - mean_absolute_error: 0.0107 - val_loss: 4.8675e-04 - val_mean_absolute_error: 0.0173
# Epoch 249/300
# 149/149 [==============================] - 0s 54us/step - loss: 2.0546e-04 - mean_absolute_error: 0.0111 - val_loss: 5.1211e-04 - val_mean_absolute_error: 0.0184
# Epoch 250/300
# 149/149 [==============================] - 0s 54us/step - loss: 2.1377e-04 - mean_absolute_error: 0.0113 - val_loss: 4.6829e-04 - val_mean_absolute_error: 0.0169
# Epoch 251/300
# 149/149 [==============================] - 0s 87us/step - loss: 2.0618e-04 - mean_absolute_error: 0.0111 - val_loss: 4.8153e-04 - val_mean_absolute_error: 0.0171
# Epoch 252/300
# 149/149 [==============================] - 0s 67us/step - loss: 2.1156e-04 - mean_absolute_error: 0.0112 - val_loss: 5.2136e-04 - val_mean_absolute_error: 0.0187
# Epoch 253/300
# 149/149 [==============================] - 0s 47us/step - loss: 2.0876e-04 - mean_absolute_error: 0.0113 - val_loss: 4.8744e-04 - val_mean_absolute_error: 0.0176
# Epoch 254/300
# 149/149 [==============================] - 0s 54us/step - loss: 2.2536e-04 - mean_absolute_error: 0.0112 - val_loss: 4.7547e-04 - val_mean_absolute_error: 0.0170
# Epoch 255/300
# 149/149 [==============================] - 0s 60us/step - loss: 2.1490e-04 - mean_absolute_error: 0.0111 - val_loss: 4.9530e-04 - val_mean_absolute_error: 0.0180
# Epoch 256/300
# 149/149 [==============================] - 0s 54us/step - loss: 1.9906e-04 - mean_absolute_error: 0.0105 - val_loss: 4.7867e-04 - val_mean_absolute_error: 0.0171
# Epoch 257/300
# 149/149 [==============================] - 0s 67us/step - loss: 1.9268e-04 - mean_absolute_error: 0.0106 - val_loss: 4.9776e-04 - val_mean_absolute_error: 0.0176
# Epoch 258/300
# 149/149 [==============================] - 0s 47us/step - loss: 1.8533e-04 - mean_absolute_error: 0.0101 - val_loss: 4.9121e-04 - val_mean_absolute_error: 0.0174
# Epoch 259/300
# 149/149 [==============================] - 0s 54us/step - loss: 1.8636e-04 - mean_absolute_error: 0.0103 - val_loss: 4.8715e-04 - val_mean_absolute_error: 0.0175
# Epoch 260/300
# 149/149 [==============================] - 0s 47us/step - loss: 1.8603e-04 - mean_absolute_error: 0.0103 - val_loss: 4.8026e-04 - val_mean_absolute_error: 0.0173
# Epoch 261/300
# 149/149 [==============================] - 0s 60us/step - loss: 1.9266e-04 - mean_absolute_error: 0.0104 - val_loss: 5.0418e-04 - val_mean_absolute_error: 0.0179
# Epoch 262/300
# 149/149 [==============================] - 0s 60us/step - loss: 1.9451e-04 - mean_absolute_error: 0.0104 - val_loss: 4.7518e-04 - val_mean_absolute_error: 0.0173
# Epoch 263/300
# 149/149 [==============================] - 0s 47us/step - loss: 1.9095e-04 - mean_absolute_error: 0.0108 - val_loss: 4.8396e-04 - val_mean_absolute_error: 0.0174
# Epoch 264/300
# 149/149 [==============================] - 0s 60us/step - loss: 1.8728e-04 - mean_absolute_error: 0.0103 - val_loss: 5.0773e-04 - val_mean_absolute_error: 0.0182
# Epoch 265/300
# 149/149 [==============================] - 0s 54us/step - loss: 2.2387e-04 - mean_absolute_error: 0.0117 - val_loss: 5.2560e-04 - val_mean_absolute_error: 0.0180
# Epoch 266/300
# 149/149 [==============================] - 0s 60us/step - loss: 2.3144e-04 - mean_absolute_error: 0.0113 - val_loss: 4.9871e-04 - val_mean_absolute_error: 0.0181
# Epoch 267/300
# 149/149 [==============================] - 0s 60us/step - loss: 2.0686e-04 - mean_absolute_error: 0.0112 - val_loss: 4.9372e-04 - val_mean_absolute_error: 0.0178
# Epoch 268/300
# 149/149 [==============================] - 0s 47us/step - loss: 2.0533e-04 - mean_absolute_error: 0.0110 - val_loss: 5.1947e-04 - val_mean_absolute_error: 0.0183
# Epoch 269/300
# 149/149 [==============================] - 0s 67us/step - loss: 1.9714e-04 - mean_absolute_error: 0.0106 - val_loss: 5.5719e-04 - val_mean_absolute_error: 0.0196
# Epoch 270/300
# 149/149 [==============================] - 0s 54us/step - loss: 2.0677e-04 - mean_absolute_error: 0.0108 - val_loss: 5.8279e-04 - val_mean_absolute_error: 0.0190
# Epoch 271/300
# 149/149 [==============================] - 0s 60us/step - loss: 1.9925e-04 - mean_absolute_error: 0.0112 - val_loss: 6.5899e-04 - val_mean_absolute_error: 0.0202
# Epoch 272/300
# 149/149 [==============================] - 0s 60us/step - loss: 2.3084e-04 - mean_absolute_error: 0.0122 - val_loss: 5.3298e-04 - val_mean_absolute_error: 0.0181
# Epoch 273/300
# 149/149 [==============================] - 0s 54us/step - loss: 1.9844e-04 - mean_absolute_error: 0.0108 - val_loss: 5.1808e-04 - val_mean_absolute_error: 0.0185
# Epoch 274/300
# 149/149 [==============================] - 0s 54us/step - loss: 1.9243e-04 - mean_absolute_error: 0.0107 - val_loss: 4.7930e-04 - val_mean_absolute_error: 0.0177
# Epoch 275/300
# 149/149 [==============================] - 0s 54us/step - loss: 1.8634e-04 - mean_absolute_error: 0.0103 - val_loss: 4.8724e-04 - val_mean_absolute_error: 0.0173
# Epoch 276/300
# 149/149 [==============================] - 0s 54us/step - loss: 1.7810e-04 - mean_absolute_error: 0.0102 - val_loss: 5.2108e-04 - val_mean_absolute_error: 0.0186
# Epoch 277/300
# 149/149 [==============================] - 0s 60us/step - loss: 1.9730e-04 - mean_absolute_error: 0.0108 - val_loss: 5.2353e-04 - val_mean_absolute_error: 0.0180
# Epoch 278/300
# 149/149 [==============================] - 0s 54us/step - loss: 2.0243e-04 - mean_absolute_error: 0.0112 - val_loss: 5.1799e-04 - val_mean_absolute_error: 0.0182
# Epoch 279/300
# 149/149 [==============================] - 0s 60us/step - loss: 2.0427e-04 - mean_absolute_error: 0.0108 - val_loss: 5.4439e-04 - val_mean_absolute_error: 0.0188
# Epoch 280/300
# 149/149 [==============================] - 0s 74us/step - loss: 1.9377e-04 - mean_absolute_error: 0.0108 - val_loss: 5.2053e-04 - val_mean_absolute_error: 0.0180
# Epoch 281/300
# 149/149 [==============================] - 0s 74us/step - loss: 1.8002e-04 - mean_absolute_error: 0.0104 - val_loss: 5.4107e-04 - val_mean_absolute_error: 0.0190
# Epoch 282/300
# 149/149 [==============================] - 0s 67us/step - loss: 1.8168e-04 - mean_absolute_error: 0.0104 - val_loss: 5.0909e-04 - val_mean_absolute_error: 0.0176
# Epoch 283/300
# 149/149 [==============================] - 0s 60us/step - loss: 2.0116e-04 - mean_absolute_error: 0.0111 - val_loss: 4.8709e-04 - val_mean_absolute_error: 0.0177
# Epoch 284/300
# 149/149 [==============================] - ETA: 0s - loss: 2.1564e-04 - mean_absolute_error: 0.010 - 0s 60us/step - loss: 1.8368e-04 - mean_absolute_error: 0.0103 - val_loss: 5.2290e-04 - val_mean_absolute_error: 0.0181
# Epoch 285/300
# 149/149 [==============================] - 0s 54us/step - loss: 1.8437e-04 - mean_absolute_error: 0.0103 - val_loss: 5.0714e-04 - val_mean_absolute_error: 0.0179
# Epoch 286/300
# 149/149 [==============================] - 0s 54us/step - loss: 1.7371e-04 - mean_absolute_error: 0.0101 - val_loss: 5.4033e-04 - val_mean_absolute_error: 0.0188
# Epoch 287/300
# 149/149 [==============================] - ETA: 0s - loss: 1.6383e-04 - mean_absolute_error: 0.009 - 0s 60us/step - loss: 1.9789e-04 - mean_absolute_error: 0.0107 - val_loss: 5.1717e-04 - val_mean_absolute_error: 0.0179
# Epoch 288/300
# 149/149 [==============================] - 0s 60us/step - loss: 1.9767e-04 - mean_absolute_error: 0.0109 - val_loss: 4.8920e-04 - val_mean_absolute_error: 0.0179
# Epoch 289/300
# 149/149 [==============================] - 0s 54us/step - loss: 1.7725e-04 - mean_absolute_error: 0.0103 - val_loss: 4.7649e-04 - val_mean_absolute_error: 0.0175
# Epoch 290/300
# 149/149 [==============================] - 0s 60us/step - loss: 1.8159e-04 - mean_absolute_error: 0.0102 - val_loss: 5.0565e-04 - val_mean_absolute_error: 0.0175
# Epoch 291/300
# 149/149 [==============================] - 0s 54us/step - loss: 1.7098e-04 - mean_absolute_error: 0.0101 - val_loss: 5.9506e-04 - val_mean_absolute_error: 0.0200
# Epoch 292/300
# 149/149 [==============================] - 0s 54us/step - loss: 2.0781e-04 - mean_absolute_error: 0.0114 - val_loss: 5.2325e-04 - val_mean_absolute_error: 0.0178
# Epoch 293/300
# 149/149 [==============================] - 0s 60us/step - loss: 1.8463e-04 - mean_absolute_error: 0.0106 - val_loss: 5.1610e-04 - val_mean_absolute_error: 0.0180
# Epoch 294/300
# 149/149 [==============================] - 0s 54us/step - loss: 1.9194e-04 - mean_absolute_error: 0.0106 - val_loss: 5.6670e-04 - val_mean_absolute_error: 0.0188
# Epoch 295/300
# 149/149 [==============================] - 0s 60us/step - loss: 1.8369e-04 - mean_absolute_error: 0.0104 - val_loss: 5.4922e-04 - val_mean_absolute_error: 0.0186
# Epoch 296/300
# 149/149 [==============================] - 0s 60us/step - loss: 2.0397e-04 - mean_absolute_error: 0.0114 - val_loss: 5.3142e-04 - val_mean_absolute_error: 0.0187
# Epoch 297/300
# 149/149 [==============================] - 0s 60us/step - loss: 1.9511e-04 - mean_absolute_error: 0.0107 - val_loss: 5.0791e-04 - val_mean_absolute_error: 0.0181
# Epoch 298/300
# 149/149 [==============================] - 0s 54us/step - loss: 2.3232e-04 - mean_absolute_error: 0.0120 - val_loss: 5.8047e-04 - val_mean_absolute_error: 0.0192
# Epoch 299/300
# 149/149 [==============================] - 0s 47us/step - loss: 2.1581e-04 - mean_absolute_error: 0.0114 - val_loss: 5.6974e-04 - val_mean_absolute_error: 0.0195
# Epoch 300/300
# 149/149 [==============================] - 0s 54us/step - loss: 2.0824e-04 - mean_absolute_error: 0.0113 - val_loss: 5.4188e-04 - val_mean_absolute_error: 0.0180
# Training mae min: 0.0101, Val mae min: 0.0158

# %% [markdown]
# ## Analyze the Hyperparameter Grid Search Results

# %%
# Sort the model runs in ascending order by the validation mean absolute value
results.sort_values('Val MAE Min', inplace=True)

# %%
# Take a look at the model configurations in order with best at the top. 
results[['Penalty', 'Reg Type', 'Dense Layers', 'Learning Rate', 'Columns', 'StdInput','Training MAE Min', 'Val MAE Min']]
# Out:
#    Penalty Reg Type Dense Layers  Learning Rate  \
# 0     0.04       L1           64          0.001
#
#                                              Columns StdInput  \
# 0  [TRUCK_PCT, RAIL_INTERMOD_PCT, AIR_RTMFM_PCT, ...    False
#
#    Training MAE Min  Val MAE Min
# 0          0.017734     0.015929

# %%
# Write the results to an Excel file.
#results.to_excel('gdp_output_20200507.xlsx')

# %%
# Create scatter plots for the hyperparameter values.  I am color coding the points for each parameter value on each plot.
# The x and y axis are both the validation mean absolute error.
# This is done to help with visualizing what parameter values scored better.

regcolors = ("red", "blue")
regtype = ("L1", "L2") 

fig, axs = plt.subplots(1, 4, sharex=True, sharey=True)

for ind in results.index:
    regtype_val = results['Reg Type'][ind]
    axs[0].scatter(results['Val MAE Min'][ind], results['Val MAE Min'][ind], 
               c=regcolors[regtype.index(regtype_val)],
               label=regtype_val, alpha=0.7, edgecolors='none')

handles, labels = axs[0].get_legend_handles_labels() #This section of code builds a
by_label = dict(zip(labels, handles))           #unique list of the labels and then uses 
axs[0].legend(by_label.values(), by_label.keys())  #them to build the legend. This is neccessary to
axs[0].set_title('Regularization Type')            #prevent duplicated labels in the legend.
    
densecolors = ("tab:red", "tab:olive", "tab:blue")
densetype = (16, 32, 64)
for ind in results.index:
    densetype_val = results['Dense Layers'][ind]
    #print(densetype_val)
    axs[1].scatter(results['Val MAE Min'][ind], results['Val MAE Min'][ind], 
               c=densecolors[densetype.index(densetype_val)], 
               label=densetype_val, alpha=0.8, edgecolors='none')
    
handles, labels = axs[1].get_legend_handles_labels() #This section of code builds a
by_label = dict(zip(labels, handles))           #unique list of the labels and then uses 
axs[1].legend(by_label.values(), by_label.keys())  #them to build the legend. This is neccessary to
                                               #prevent duplicated labels in the legend.
#https://stackoverflow.com/questions/13588920/stop-matplotlib-repeating-labels-in-legend
axs[1].set_title('Number of Dense Layers')

#Penalty
penaltycolors = ("tab:red", "tab:olive", "tab:blue", "tab:orange", "tab:green",
                 "tab:purple", "tab:brown", "tab:pink", "tab:cyan")       #("tab:red", "tab:olive", "tab:blue")       
penaltytype = (0.08, 0.07, 0.06, 0.05, 0.04, 0.03, 0.02, 0.01, 0.008) #(0.1, 0.01, 0.001)
for ind in results.index:
    penaltytype_val = results['Penalty'][ind]
    axs[2].scatter(results['Val MAE Min'][ind], results['Val MAE Min'][ind],
                   c=penaltycolors[penaltytype.index(penaltytype_val)],
                   label=penaltytype_val, alpha=0.8, edgecolors='none')

handles, labels = axs[2].get_legend_handles_labels() #This section of code builds a
by_label = dict(zip(labels, handles))           #unique list of the labels and then uses 
axs[2].legend(by_label.values(), by_label.keys())  #them to build the legend. This is neccessary to
                                               #prevent duplicated labels in the legend.
axs[2].set_title('Penalty')

#learninr Rate
# for in_learning_rate in [0.01, 0.001, 0.0006]
learnratecolors = ("tab:red", "tab:olive", "tab:blue")       
learnratetype = (0.01, 0.001, 0.0006)
for ind in results.index:
    learnratetype_val = results['Learning Rate'][ind]
    axs[3].scatter(results['Val MAE Min'][ind], results['Val MAE Min'][ind],
                   c=learnratecolors[learnratetype.index(learnratetype_val)],
                   label=learnratetype_val, alpha=0.8, edgecolors='none')

handles, labels = axs[3].get_legend_handles_labels() #This section of code builds a
by_label = dict(zip(labels, handles))           #unique list of the labels and then uses 
axs[3].legend(by_label.values(), by_label.keys())  #them to build the legend. This is neccessary to
                                               #prevent duplicated labels in the legend.
axs[3].set_title('Learning Rate')
    
#ax.legend(loc="upper left")
#fig = plt.gcf()
fig.set_size_inches(20,9)
#plt.show()

# %% [markdown]
# Based on the above charts and from looking at the data:
# -  Reg Type = L1
# -  Dense Layers = 64
# -  Penalty = 0.04
# -  Learning Rate = 0.001
# -  Use raw data instead of normalize data
# -  For input features, use: “TRUCK_PCT”, “RAIL_INTERMOD_PCT”, “AIR_RTMFM_PCT”, “TSI_PCT”
